# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import time
DRIVERPATH="chromedriver"

# %%
driver=webdriver.Chrome(executable_path=DRIVERPATH)

driver.get('https://www.udemy.com/')

# %%
a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-small udlite-btn-secondary udlite-heading-sm udlite-btn-icon udlite-btn-icon-small udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'Artificial Intelligence':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()

# %%
block_=driver.find_elements_by_class_name('course-card--main-content--3xEIw.course-card--has-price-text--1Ikr0')

# %%
block_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="c2ec0237-ff1a-499e-82f8-616431e19b2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="3adf5651-7038-4a8f-8efc-3f7ad428540a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="08cfb7ec-6476-4cf6-94f1-60547d0b73aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="955ea51c-89e2-4fd3-a4df-e3bc4347fc21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="0f508f67-f152-45c9-bddc-619202b37432")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="e658f47f-2993-41b6-9783-8d9878f14a89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="b08e933b-7b29-4946-ae0b-8b864ec691de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="62de704c-6ea1-4e65-890a-2a1903ad870a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="95622dd2-20fb-4a96-b1f0-6532b779e1cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="a45c2e0b-88b1-4c95-b535-f8d1298c32c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="106f9e8a-0d83-4479-a98c-0379e92f6edf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="20ed45b1-1697-4cce-9213-2c8acab9545b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="8b7c9c91-4d66-46a4-8477-1195f613e513")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="eac844e7-9033-4a3a-9c30-b0e0bef93766")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="96223cc6-8897-468b-8362-e2df6cc82158")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="90946b54-2eb4-4f8f-80db-3076712eb391")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="8dbae19d-861b-43b0-88a0-68233d5a3766")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="8a8b46e9-1e97-42be-bf75-419963f4cbea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="e6f42818-2163-4966-babb-df4b06603540")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="39c5e32a-0cf3-40d2-b882-05d9bf12f756")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="d57511e0-1e46-47be-a8e9-932775574d11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="210a0721-f083-47be-8904-0952b8d54418")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="30f77d50-eecc-4a98-97b1-95c8ad2b220e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="b83e5a05-b014-43cf-80f5-057aee002b31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="b880a5b9-9552-456b-8064-24bf303c9e82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="888e3a63-432b-4c61-ac94-a2cbb0a3c1ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="8e8b7846-fe84-4119-9a17-2df65f44771a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="3b81a06f-1f44-4a5f-96f0-e2db49e924b2")>]

# %%
p=block_[1].find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')

# %%
info=[]
for j in block_:
        content=[]
        try:
            title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
            content.append(title.text)
        except:
            content.append('Not Available')
        try:
            tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
            content.append(tagline.text)
        except:
            content.append('Not Available')
        try:
            instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
            content.append(instructor.text)
        except:
            content.append('Not Available')
        try:
            rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
            content.append(rating.text)
        except:
            content.append('Not Available')
        try:
            bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
            content.append('Bestseller')
        except:
            content.append('Not Available')
        try:
            reviews=j.find_element_by_class_name('udlite-text-xs.course-card--reviews-text--12UpL')
            content.append(reviews)
        except:
            content.append('Not Available')
        try:
            otherinfo=j.find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')
            content.append(otherinfo)
        except:
            content.append('Not Available')
            
        info.append(content)

# %%
driver.quit()

# %%
info
# Out:
# [['Artificial Intelligence A-Z™: Learn How To Build An AI',
#   'Combine the power of Data Science, Machine Learning and Deep Learning to create powerful AI for Real-World applications!',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team, SuperDataScience Support, Luka Anicin',
#   '4.3',
#   'Bestseller'],
#  ['Artificial Intelligence: Reinforcement Learning in Python',
#   'Complete guide to Reinforcement Learning, with Stock Trading and Online Advertising Applications',
#   'Lazy Programmer Team, Lazy Programmer Inc.',
#   '4.5',
#   'Bestseller'],
#  ['Machine Learning, Data Science and Deep Learning with Python',
#   'Complete hands-on machine learning tutorial with data science, Tensorflow, artificial intelligence, and neural networks',
#   'Sundog Education by Frank Kane, Frank Kane',
#   '4.5',
#   'Not Available'],
#  ['Artificial Intelligence 2018: Build the Most Powerful AI',
#   'Not Available',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.5',
#   'Not Available'],
#  ['Tensorflow Deep Learning - Data Science in Python',
#   'Not Available',
#   'Minerva Singh',
#   '4.7',
#   'Not Available'],
#  ['Deep Reinforcement Learning 2.0',
#   'Not Available',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.3',
#   'Not Available'],
#  ['Deep Learning Prerequisites: The Numpy Stack in Python (V2+)',
#   'The Numpy, Scipy, Pandas, and Matplotlib stack: prep for deep learning, machine learning, and artificial intelligence',
#   'Lazy Programmer Inc.',
#   '4.5',
#   'Bestseller'],
#  ['Tensorflow 2.0: Deep Learning and Artificial Intelligence',
#   'Neural Networks for Computer Vision, Time Series Forecasting, NLP, GANs, Reinforcement Learning, and More!',
#   'Lazy Programmer Inc., Lazy Programmer Team',
#   '4.6',
#   'Bestseller'],
#  ['Advanced AI: Deep Reinforcement Learning in Python',
#   'The Complete Guide to Mastering Artificial Intelligence using Deep Learning and Neural Networks',
#   'Lazy Programmer Team, Lazy Programmer Inc.',
#   '4.6',
#   'Not Available'],
#  ['Tensorflow 2.0: Deep Learning and Artificial Intelligence',
#   'Not Available',
#   'Lazy Programmer Inc., Lazy Programmer Team',
#   '4.6',
#   'Bestseller'],
#  ["The Beginner's Guide to Artificial Intelligence in Unity.",
#   'Not Available',
#   'Penny de Byl, Penny @Holistic3D.com',
#   '4.6',
#   'Not Available'],
#  ['Artificial Intelligence 2018: Build the Most Powerful AI',
#   'Not Available',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.5',
#   'Not Available'],
#  ['', 'Not Available', '', '', 'Bestseller'],
#  ['', 'Not Available', '', '', 'Bestseller'],
#  ['Artificial Intelligence for Business',
#   'Solve Real World Business Problems with AI Solutions',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.4',
#   'Not Available'],
#  ["The Beginner's Guide to Artificial Intelligence in Unity.",
#   'A practical guide to programming non-player characters for games.',
#   'Penny de Byl, Penny @Holistic3D.com',
#   '4.6',
#   'Not Available'],
#  ['Artificial Intelligence in Web Design Certification',
#   'Learn Incredible Web Design, Development Tools and Platforms using Artificial Intelligence (AI) Technology',
#   'Srinidhi Ranganathan',
#   '4.1',
#   'Not Available'],
#  ['Artificial Intelligence Masterclass',
#   'Enter the new era of Hybrid AI Models optimized by Deep NeuroEvolution, with a complete toolkit of ML, DL & AI models',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.3',
#   'Not Available'],
#  ['Intro to Big Data, Data Science and Artificial Intelligence',
#   'Big Data Technology & Tools for Non-Technical Leaders. Industry expert insights on IoT, AI and Machine Learning for all.',
#   'Julia Mariasova',
#   '4.3',
#   'Not Available'],
#  ['Artificial Intelligence 2018: Build the Most Powerful AI',
#   'Learn, build and implement the most powerful AI model at home. Compete with multi-billion dollars companies using ARS.',
#   'Hadelin de Ponteves, Kirill Eremenko, SuperDataScience Team',
#   '4.5',
#   'Not Available'],
#  ['Artificial Intelligence I: Basics and Games in Java',
#   'A guide how to create smart applications, AI, genetic algorithms, pruning, heuristics and metaheuristics and Tic Tac Toe',
#   'Holczer Balazs',
#   '4.3',
#   'Not Available'],
#  ['Artificial Intelligence & Machine Learning for Business',
#   'The Ultimate Artificial Intelligence & Machine Learning course for CxOs, Managers, Team Leaders and Entrepreneurs',
#   'Analytics Vidhya',
#   '4.3',
#   'Not Available'],
#  ['Artificial Intelligence in Digital Marketing Certification',
#   'Learn Highly Futuristic Digital Marketing Technologies with Artificial Intelligence in 2020',
#   'Srinidhi Ranganathan',
#   '4.0',
#   'Not Available'],
#  ['Artificial Intelligence and Predictive Analysis using Python',
#   'This course is a comprehensive understanding of AI concepts and its application using Python and iPython.',
#   'EDU CBA',
#   '4.9',
#   'Not Available'],
#  ['Introduction to Artificial Intelligence ( AI ) for Managers',
#   'Data Science, Machine Learning, Deep Learning & Neural Networks for Beginners with Scikit-Learn & Python',
#   'Kumaresan Ramanathan',
#   '4.3',
#   'Not Available'],
#  ['Artificial Intelligence II - Hands-On Neural Networks (Java)',
#   'Hopfield networks, neural networks, gradient descent and backpropagation algorithms explained step by step',
#   'Holczer Balazs',
#   '4.4',
#   'Not Available'],
#  ['Artificial Intelligence Expert Certification',
#   'A groundbreaking course that uncovers Artificial Intelligence (AI) powered secretive technologies, tools and websites',
#   'Srinidhi Ranganathan, Saranya Srinidhi',
#   '4.1',
#   'Not Available'],
#  ['PyTorch: Deep Learning and Artificial Intelligence',
#   'Neural Networks for Computer Vision, Time Series Forecasting, NLP, GANs, Reinforcement Learning, and More!',
#   'Lazy Programmer Team, Lazy Programmer Inc.',
#   '4.7',
#   'Bestseller']]

# %%
import selenium
from selenium import webdriver
import time
DRIVERPATH="chromedriver"

driver=webdriver.Chrome(executable_path=DRIVERPATH)

driver.get('https://www.udemy.com/')
a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-small udlite-btn-secondary udlite-heading-sm udlite-btn-icon udlite-btn-icon-small udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'Artificial Intelligence':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()


blocks=[]
content=[]

for i in range(4):
    block_=driver.find_elements_by_class_name('course-card--main-content--3xEIw.course-card--has-price-text--1Ikr0')
    time.sleep(2)
    for j in block_:
        content=[]
        title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
        content.append(title.text)
        tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
        content.append(tagline.text)
        instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
        content.append(instructor.text)
        rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
        content.append(rating.text)
        try:
            bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
            content.append('Bestseller')
        except:
            content.append('Not Available')
        
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(4)
    driver.find_element_by_class_name(next_link).click()
    time.sleep(10)
    
driver.quit()

# %%
block_[1]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9f4093e23a9cb3f4b0191ad83bcc6b3e", element="3adf5651-7038-4a8f-8efc-3f7ad428540a")>

# %%
block_[1].text
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# E:\Python01\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# E:\Python01\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# E:\Python01\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#
# E:\Python01\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# E:\Python01\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# E:\Python01\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# E:\Python01\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# E:\Python01\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# E:\Python01\lib\site-packages\urllib3\connection.py in connect(self)
#     183     def connect(self):
# --> 184         conn = self._new_conn()
#     185         self._prepare_conn(conn)
#
# E:\Python01\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001E26B489408>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-25-71869db93d0f> in <module>
# ----> 1 block_[1].text
#
# E:\Python01\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# E:\Python01\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# E:\Python01\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# E:\Python01\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# E:\Python01\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# E:\Python01\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# E:\Python01\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# E:\Python01\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# E:\Python01\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     718
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#     722             retries.sleep()
#
# E:\Python01\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     434
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#     438         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=49158): Max retries exceeded with url: /session/9f4093e23a9cb3f4b0191ad83bcc6b3e/element/3adf5651-7038-4a8f-8efc-3f7ad428540a/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E26B489408>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %%
block_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="f913f610-9b76-4f76-83d5-3ad042d66886")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="756dd502-c1f3-44f2-8ddf-cf3c81376fe4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="92f0a867-f42c-481c-bf53-2e136b36abe2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="f10fffbf-1a4e-45ba-8683-32678e1d3b20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="9e2becab-201e-4b42-a14c-36d0094bd46f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="f80758b4-1c98-4a36-8bc1-fe0422ad6184")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="c4928645-5116-44c1-806f-25778f29be4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="82ffd0a3-051e-446e-9f46-26e2fa801746")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="2556186e-d373-4df0-8e69-e427f5eac050")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="c9a6390e-55ce-4912-ae58-ddc55733461f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="f313a262-df5e-4b5e-84b2-d63a33366052")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="7576e917-970d-424c-a66a-ef91da673f7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="87317fc6-f5e0-47c8-ba92-27dffc842e8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="1616a8f2-a9c4-4d43-b3c9-ef4b8e4e1926")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="844c549f-3b40-40ac-ba49-bcd41eb50f1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="708398a8-4a0f-4f85-9305-109619170979")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="3b059fdf-82c0-4c85-a577-a36eb73abdd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="393764ec-96ed-4b09-929c-7dcce23bf7f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="f84b91b8-32ed-4e66-8506-13bb87680b1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="ef3ad769-c680-4225-bf79-4010ef1139ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="786e0981-8e4a-4f9f-b595-7c084edf62b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="923855da-9dab-4b1c-b0df-8b536bb3a89f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="c6d7773d-b533-4c1b-8695-5dda1437b15f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="78d76c86-7acf-4925-a316-6d18d6385aa9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="6e457a8e-0463-4fa7-a51d-9fa2647e5619")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="e1d274aa-8e46-46c6-bc5b-10ac2676e393")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="0521e617-396d-4487-a1d5-9ede87d9bc51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dfabfa285adac9d020837444bf1f3cc8", element="92a4925a-5332-455b-8652-d0ec51d775de")>]

# %%
block_[1].text
# Out:
# 'Artificial Intelligence: Reinforcement Learning in Python\nComplete guide to Reinforcement Learning, with Stock Trading and Online Advertising Applications\nLazy Programmer Team, Lazy Programmer Inc.\nRating: 4.5 out of 5\n4.5\n(7,742)\n12.5 total hours\n107 lectures\nIntermediate\nCurrent price\n₹1,920\nBestseller'

# %%
q=block_[1].find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')

# %%
q.text
# Out:
# '12.5 total hours\n107 lectures\nIntermediate'

# %% [markdown]
# ****Final Code for Scraping

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-medium udlite-btn-secondary udlite-btn-round udlite-heading-sm udlite-btn-icon udlite-btn-icon-medium udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'App Development':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()
time.sleep(10)
block_=driver.find_elements_by_class_name('course-card--container--3w8Zm.course-card--large--1BVxY')

time.sleep(3)

info=[]
for i in range(10):
    block_=driver.find_elements_by_class_name('popper--popper--19faV.popper--popper-hover--4YJ5J')
    for j in block_:
            content=[]
            try:
                title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
                content.append(title.text)
            except:
                content.append('Not Available')
            try:
                tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
                content.append(tagline.text)
            except:
                content.append('Not Available')
            try:
                instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
                content.append(instructor.text)
            except:
                content.append('Not Available')
            try:
                rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
                content.append(rating.text)
            except:
                content.append('Not Available')
            try:
                bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
                content.append('Bestseller')
            except:
                content.append('Not Available')
            try:
                reviews=j.find_element_by_class_name('udlite-text-xs.course-card--reviews-text--12UpL')
                content.append(reviews.text)
            except:
                content.append('Not Available')
            try:
                otherinfo=j.find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')
                content.append(otherinfo.text)
            except:
                content.append('Not Available')
            try:
                links=j.find_element_by_tag_name('a').get_attribute('href')
                content.append(links)
            except:
                content.append('Not Available')
            info.append(content)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(4)
    driver.find_element_by_class_name(next_link).click()
    time.sleep(10)
    
driver.quit()

# %%
len(info)
# Out:
# 240

# %%
info
# Out:
# [['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.8',
#   'Bestseller',
#   '(52,220)',
#   '59.5 total hours\n578 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-13-app-development-bootcamp/'],
#  ['iOS 11 & Swift 4 - The Complete iOS App Development Bootcamp',
#   'Learn iOS 11 App Development From Beginning to End. Using Xcode 9 and Swift 4.',
#   'Dr. Angela Yu',
#   '4.7',
#   'Not Available',
#   '(31,308)',
#   '49.5 total hours\n478 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios11-app-development-bootcamp/'],
#  ['Android App Development Masterclass using Kotlin',
#   'Learn Kotlin Android App Development And Become an Android Developer. Incl.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy, David Reidy",
#   '4.4',
#   'Not Available',
#   '(3,780)',
#   '59.5 total hours\n364 lectures\nBeginner',
#   'https://www.udemy.com/course/android-oreo-kotlin-app-masterclass/'],
#  ['The Complete Android Oreo Developer Course - Build 23 Apps!',
#   'Learn Android O App Development using Java & Kotlin - build real apps including Super Mario Run, Whatsapp',
#   'Rob Percival, Nick Walter, Codestars by Rob Percival',
#   '4.4',
#   'Bestseller',
#   '(13,961)',
#   '37.5 total hours\n272 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-android-oreo-developer-course/'],
#  ['The Complete Android App Development',
#   'Learn how to make online games, and apps like Twitter, Pokémon ,Tic Tac Toy, and Find my phone using',
#   'Hussein Alrubaye',
#   '4.2',
#   'Not Available',
#   '(2,891)',
#   '22 total hours\n150 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-tutorial-for-beginners/'],
#  ['The Complete Android N Developer Course',
#   'Learn Android App Development with Android 7 Nougat by building real apps including Uber, Whatsapp and',
#   'Rob Percival, Marc Stock, Codestars by Rob Percival',
#   '4.4',
#   'Not Available',
#   '(27,050)',
#   '32.5 total hours\n272 lectures\nAll Levels',
#   'https://www.udemy.com/course/complete-android-n-developer-course/'],
#  ['Flutter & Dart - The Complete Flutter App Development Course',
#   "Build Flutter iOS and Android Apps with a Single Codebase: Learn Google's Flutter Mobile Development",
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.5',
#   'Not Available',
#   '(3,849)',
#   '26 total hours\n358 lectures\nAll Levels',
#   'https://www.udemy.com/course/flutter-dart-the-complete-flutter-app-development-course/'],
#  ['Android Java Masterclass - Become an App Developer',
#   'Improve your career options by learning Android app Development.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy",
#   '4.5',
#   'Not Available',
#   '(8,707)',
#   '60.5 total hours\n338 lectures\nAll Levels',
#   'https://www.udemy.com/course/master-android-7-nougat-java-app-development-step-by-step/'],
#  ['The Complete Android App Development Masterclass: Build Apps',
#   'Create Real World Applications using Java and Become A Professional Android App Developer From Scratch',
#   'Meisam Mansourzadeh, Joe Parys',
#   '4.5',
#   'Not Available',
#   '(600)',
#   '39.5 total hours\n116 lectures\nAll Levels',
#   'https://www.udemy.com/course/androidappcourse/'],
#  ['Mobile App Development with PhoneGap',
#   'Create Apps for iOS and Android with HTML5 and Javascript',
#   'Framework Television Inc.',
#   '4.4',
#   'Bestseller',
#   '(512)',
#   '5.5 total hours\n61 lectures\nIntermediate',
#   'https://www.udemy.com/course/mobile-app-development-with-phonegap/'],
#  ['Android O & Java - The Complete Android Development Bootcamp',
#   'Learn Android O app development from beginning to end.',
#   'Philipp Muellauer',
#   '4.5',
#   'Not Available',
#   '(6,958)',
#   '21 total hours\n289 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-with-java/'],
#  ['SwiftUI Masterclass: iOS 14 App Development with Swift 5',
#   'The Complete iOS 14 App Development Course with SwiftUI 2 From Beginner to Advanced App Developer with',
#   'Robert Petras',
#   '4.5',
#   'Bestseller',
#   '(654)',
#   '20.5 total hours\n116 lectures\nAll Levels',
#   'https://www.udemy.com/course/swiftui-masterclass-course-ios-development-with-swift/'],
#  ['State of the Art Android App Development in Kotlin',
#   'Using Kotlin, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.7',
#   'Not Available',
#   '(223)',
#   '6.5 total hours\n51 lectures\nAll Levels',
#   'https://www.udemy.com/course/stateoftheartandroid/'],
#  ['Android App Development using Kotlin',
#   'Develop Android apps in Kotlin and publish it to Play Store',
#   'Smartherd Developers',
#   '4.2',
#   'Not Available',
#   '(630)',
#   '3.5 total hours\n27 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-using-kotlin/'],
#  ['The Complete Flutter App Development Course for Android, iOS',
#   'A Complete Guide to the Flutter Framework for building native iOS and Android apps with single code base',
#   'Smartherd Developers',
#   '4.1',
#   'Not Available',
#   '(1,153)',
#   '4.5 total hours\n33 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-flutter-app-development-course-for-android-ios/'],
#  ['The Complete Android & Java Developer Course - Build 21 Apps',
#   'Learn Android Development, Java & Android Studio from Scratch in 5 Weeks. Build a Diary App & more',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher, Fahd Sheraz',
#   '4.4',
#   'Not Available',
#   '(6,152)',
#   '34.5 total hours\n229 lectures\nAll Levels',
#   'https://www.udemy.com/course/complete-android-developer-course/'],
#  ['To-Do App & Clean Architecture -Android Development - Kotlin',
#   'Develop a Fully Functional To-Do app in Kotlin - ROOM, Navigation Component, LiveData, ViewModel, Data',
#   'Stefan Jovanovic',
#   '4.8',
#   'Not Available',
#   '(112)',
#   '4 total hours\n50 lectures\nIntermediate',
#   'https://www.udemy.com/course/to-do-app-clean-architecture-android-development-kotlin/'],
#  ['The complete Java Android App development Bootcamp 2020',
#   'Learn Android development fundamentals and start creating your own Android applications',
#   'Maid Rondić',
#   '4.4',
#   'Not Available',
#   '(180)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-android-app-development-from-scratch-with-java/'],
#  ['Android App Development For Beginners: Make a full app!',
#   'Become an App Developer!',
#   'Nick Marcenelle',
#   '4.2',
#   'Not Available',
#   '(567)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'https://www.udemy.com/course/androidforbeginners/'],
#  ['Android App Development. LIVE and in REAL TIME.',
#   'Android App Development Sessions are LIVE & UNEDITED.',
#   'Grant Klimaytys',
#   '4.9',
#   'Not Available',
#   '(4)',
#   '22 total hours\n45 lectures\nIntermediate',
#   'https://www.udemy.com/course/buildit-coding-a-published-android-app-in-real-time/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['Modern Android App Development Bootcamp With Kotlin 2020',
#   'Learn Android App Development With Kotlin From the Beginning All the Way to Advanced Topic With the Most',
#   'Abd Alwahab',
#   '4.3',
#   'Not Available',
#   '(517)',
#   '35.5 total hours\n274 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-android-development-bootcamp-2019/'],
#  ['Testing iOS Apps - Behavior Driven Development Using Swift',
#   'Learn Unit Testing, Test Driven Development and Behavior Driven Development in iOS Using Swift Language',
#   'Mohammad Azam',
#   '4.6',
#   'Not Available',
#   '(48)',
#   '7.5 total hours\n69 lectures\nAll Levels',
#   'https://www.udemy.com/course/testing-ios-apps-behavior-driven-development-using-swift/'],
#  ['Android App Development Bootcamp 2020 - Android 10 (Q)',
#   'Android App Development for complete beginners, learn Java & Kotlin, make real working apps, become an',
#   'Vin Norman',
#   '4.7',
#   'Not Available',
#   '(113)',
#   '18 total hours\n105 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-android-developer-bootcamp/'],
#  ['iOS 12 Swift 4.2 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.5',
#   'Not Available',
#   '(321)',
#   '55.5 total hours\n525 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-12-app-development-bootcamp/'],
#  ['iOS 10 iPhone App Development: Learn the Basics in 2 hours',
#   'Build a fully functioning App and run it on your own personal iPhone',
#   'Michael Harrison',
#   '4.6',
#   'Not Available',
#   '(201)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'https://www.udemy.com/course/bucketlist-1-create-an-app-and-put-it-on-your-own-iphone/'],
#  ['Android App Development For Beginners',
#   'Step by step android development and Java tutorials included',
#   'Nazir Hakim',
#   '4.1',
#   'Not Available',
#   '(115)',
#   '3.5 total hours\n31 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-for-beginner/'],
#  ['Learning Path: Android: Test-Driven Android App Development',
#   'See the first steps to building fast and dynamic Android apps employing test-driven development',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(47)',
#   '10 total hours\n70 lectures\nBeginner',
#   'https://www.udemy.com/course/learning-path-android-test-driven-android-app-development/'],
#  ['Mobile App Development with Android (2015)',
#   "You'll create a real world social networking application! All of Android's core concepts in a production level project!",
#   '3D BUZZ Programming and Digital Art training',
#   '4.1',
#   'Not Available',
#   '(228)',
#   '40.5 total hours\n91 lectures\nIntermediate',
#   'https://www.udemy.com/course/mobile-app-development-with-android-2015/'],
#  ['iOS Development - Create 4 Quiz Apps with Swift 3 & iOS 10',
#   'In this course we will develop 4 different quiz apps together and go into great detail for every step',
#   'Johannes Ruof, Timothy Meixner',
#   '4.2',
#   'Not Available',
#   '(127)',
#   '5 total hours\n31 lectures\nIntermediate',
#   'https://www.udemy.com/course/ios-development-create-4-quiz-apps-with-swift-3-ios-10/'],
#  ['Introduction to Programming and App Development',
#   'for Android and iOS',
#   'Hesam Samimi',
#   '3.7',
#   'Not Available',
#   '(121)',
#   '19.5 total hours\n69 lectures\nAll Levels',
#   'https://www.udemy.com/course/intro-programming-and-app-development/'],
#  ['Android P& Kotlin -Complete Android App Development Bootcamp',
#   'Learn Android Development from beginning to End Using Android Studio 3 and Android P',
#   'Bita Mirshafiee',
#   '3.8',
#   'Not Available',
#   '(207)',
#   '26.5 total hours\n248 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-p-kotlin-complete-android-app-development-bootcamp/'],
#  ['Intermediate Mobile App Development (Swift 3, iPhone iOS10)',
#   "Gain the proficiency to start a career as an iOS developer with Swift 3 & Xcode 8 (learn 10 different iPhone API's)",
#   'Dee Aliyu Odumosu',
#   '4.8',
#   'Not Available',
#   '(15)',
#   '5.5 total hours\n83 lectures\nIntermediate',
#   'https://www.udemy.com/course/intermediate-mobile-app-development-swift-3-iphone-ios10/'],
#  ['Beginners Android App Development Course Stepwise-Classroom',
#   'Here is detailed android app development course for true learners.',
#   'codekul Simplest way of Learning Programming, Aniruddha Kudalkar',
#   '4.3',
#   'Not Available',
#   '(109)',
#   '19.5 total hours\n104 lectures\nAll Levels',
#   'https://www.udemy.com/course/codekul-android-online-course-training/'],
#  ['iOS 9 App Development For Beginners',
#   'Get started developing Apple apps with iOS 9 and Xcode 7.',
#   'Stone River eLearning',
#   '4.6',
#   'Not Available',
#   '(76)',
#   '7 total hours\n62 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-9-app-development-for-beginners/'],
#  ['State of the Art Android app development in Java',
#   'Using Java, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.6',
#   'Not Available',
#   '(17)',
#   '7.5 total hours\n55 lectures\nAll Levels',
#   'https://www.udemy.com/course/javaandroidapp/'],
#  ['iOS 10 & Swift 3: From Beginner to Paid Professional™',
#   'The most comprehensive course on iOS development - become a master of app development',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.3',
#   'Not Available',
#   '(13,624)',
#   '71 total hours\n266 lectures\nAll Levels',
#   'https://www.udemy.com/course/devslopes-ios10/'],
#  ['Intro to Shopify App Development with React, Node & GraphQL',
#   'Learn Shopify App Development with React, Node.js, Koa, GraphQL, Apollo, Next.js, Polaris, Shopify ScriptTag',
#   'Working With Shopify',
#   '4.0',
#   'Not Available',
#   '(227)',
#   '4 total hours\n31 lectures\nAll Levels',
#   'https://www.udemy.com/course/shopify-app-development/'],
#  ['Android Development: Make Apps without Coding or Experience',
#   'Create a Fully Functional Professional Mobile App without Coding or Experience and in less than a day',
#   'Educational Engineering Team, Ashraf Said',
#   '3.6',
#   'Not Available',
#   '(498)',
#   '1 total hour\n16 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-development-make-apps-without-coding-or-experience/'],
#  ['Mobile App Development: Make iOS & Android Apps Without Code',
#   'Quickly produce quality iOS and Android apps without learning any code.',
#   'Cameron Wills',
#   '3.7',
#   'Not Available',
#   '(133)',
#   '1.5 total hours\n20 lectures\nAll Levels',
#   'https://www.udemy.com/course/mobile-app-development-make-ios-and-android-apps-without-code/'],
#  ['Android App Development: Create a Spotify Clone',
#   'Stream your music collection and learn how to play and control music on Android',
#   'Grant Klimaytys',
#   '3.8',
#   'Not Available',
#   '(132)',
#   '6 total hours\n58 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-create-a-spotify-clone/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['Android & iOS Development - How To Hire a Good App Developer',
#   '10 Steps To Bring Your App Idea To Life Without Writing Code!',
#   'Dante Varnado Moore',
#   '4.7',
#   'Not Available',
#   '(6)',
#   '1 total hour\n15 lectures\nAll Levels',
#   'https://www.udemy.com/course/how-to-create-an-app/'],
#  ['iOS Development Crash Course - Beginners to Publishing App',
#   'Create iOS Apps and Publish it to App Store.',
#   'Shaping Edge, Three Millennials',
#   '4.7',
#   'Not Available',
#   '(19)',
#   '3 total hours\n15 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-development-crash-course/'],
#  ['Android app Development Bootcamp Java and kotlin',
#   'Learn Core Java & Kotlin and make gaming Apps using UNITY 3D, also learn how to make backend applications',
#   'Mohammed Khan, Mohammed Khan',
#   '4.4',
#   'Not Available',
#   '(39)',
#   '22 total hours\n106 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-android-development-bootcamp-java-and-kotlin/'],
#  ['Mobile App Development for Beginners (Swift 3, iPhone iOS10)',
#   'iPhone (iOS 10) app development. The complete development course.',
#   'Dee Aliyu Odumosu',
#   '4.4',
#   'Not Available',
#   '(236)',
#   '33 total hours\n327 lectures\nBeginner',
#   'https://www.udemy.com/course/make-me-an-iphone-app-developer-beginner-series/'],
#  ['Complete Flutter development - build 14 ios and android apps',
#   'Includes API handling, database projects, Firebase and BLOC',
#   'Igneus Technologies',
#   '4.6',
#   'Not Available',
#   '(152)',
#   '19 total hours\n118 lectures\nAll Levels',
#   'https://www.udemy.com/course/complete-flutter-development/'],
#  ['The Complete iOS11 Swift4 Development Course - Build 28 Apps',
#   'Use Xcode 9 & Swift 4 to make great apps.',
#   'Dee Aliyu Odumosu',
#   '4.0',
#   'Not Available',
#   '(347)',
#   '43 total hours\n512 lectures\nBeginner',
#   'https://www.udemy.com/course/the-complete-ios-11-course/'],
#  ['Android App Development Course Build 5 Real Android App',
#   'In This Android Course You Will Build Job Portal Android App, Expense Manager Android App,Online Store',
#   'Yazdani Chowdhury',
#   '3.7',
#   'Not Available',
#   '(145)',
#   '14.5 total hours\n126 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-course-build-5-real-android-app/'],
#  ['Project-Based iOS 10 App Development - Build a Real App',
#   'Become a professional iOS App Developer by building beautiful Real-World apps',
#   'Sebastian Dobrincu',
#   '4.6',
#   'Not Available',
#   '(10)',
#   '1 total hour\n14 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-8-app/'],
#  ['iOS App Development For Complete & Utter Coding Beginners',
#   'iOS App Development Made Simple for Non Coders. No Experience Needed. Level Up Your Skills Today.',
#   'Grant Klimaytys',
#   '4.6',
#   'Not Available',
#   '(47)',
#   '2.5 total hours\n23 lectures\nBeginner',
#   'https://www.udemy.com/course/ios-app-development-for-complete-and-utter-coding-beginners/'],
#  ['iOS Development - App Monetization for Swift 3 & iOS 10',
#   'We learn about AdMob, the Facebook Audience Network, In App Purchases and other ways to monetize our',
#   'Johannes Ruof, Timothy Meixner',
#   '4.5',
#   'Not Available',
#   '(48)',
#   '3.5 total hours\n25 lectures\nIntermediate',
#   'https://www.udemy.com/course/ios-development-app-monetization-for-swift-3-ios-10/'],
#  ['The Complete Android 10 & Kotlin Development Masterclass',
#   'Learn Android 10 App Development From Beginner to Advanced Developer.',
#   'Denis Panjuta, Tutorials.eu by Denis Panjuta',
#   '4.6',
#   'Bestseller',
#   '(1,818)',
#   '45.5 total hours\n289 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-kotlin-developer/'],
#  ['Running a Mobile App Dev Business: The Complete Guide',
#   'Learn how to start and grow a mobile app development business. Get up & running in less than 1 week.',
#   'Evan Kimbrell',
#   '4.7',
#   'Bestseller',
#   '(1,047)',
#   '17 total hours\n91 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-guide-to-running-a-mobile-app-dev-business/'],
#  ['Hybrid Mobile App Development with Ionic',
#   'Leveraging AngularJS, CSS, HTML5, and Apache Cordova in the Ionic Framework',
#   'Infinite Skills',
#   '3.7',
#   'Not Available',
#   '(60)',
#   '3 total hours\n52 lectures\nAll Levels',
#   'https://www.udemy.com/course/hybrid-mobile-app-development-with-ionic/'],
#  ['How To Use Git Branches To Speed Up Android App Development',
#   'Learn How To Use Git Branching Model Effectively To Make You Develop Android Apps Easier And Faster',
#   'Skill Centric',
#   '4.3',
#   'Not Available',
#   '(10)',
#   '1 total hour\n29 lectures\nIntermediate',
#   'https://www.udemy.com/course/how-to-use-git-branches-to-speed-up-android-app-development/'],
#  ['Professional iOS App Development with Swift',
#   'Learn how to build a fully customised iOS app from scratch in 10 steps',
#   'Brian Advent',
#   '4.5',
#   'Not Available',
#   '(77)',
#   '4 total hours\n37 lectures\nIntermediate',
#   'https://www.udemy.com/course/real-world-ios-app-in-10-days/'],
#  ['How to make a Social Networking app -Android App Development',
#   'Take your first step towards your next big idea by learning social networking android app development',
#   'Kapil Bhattarai',
#   '4.3',
#   'Not Available',
#   '(93)',
#   '19.5 total hours\n179 lectures\nAll Levels',
#   'https://www.udemy.com/course/social-networking-android-app-development-from-scratch/'],
#  ['Xamarin Android - A Master Guide to App Development in C#',
#   'Complete Xamarin.Android Reference for Building Apps in C#.',
#   'Grant Klimaytys',
#   '4.4',
#   'Not Available',
#   '(360)',
#   '7.5 total hours\n77 lectures\nAll Levels',
#   'https://www.udemy.com/course/xamarin-android-a-master-guide-to-mobile-app-development/'],
#  ['Learning App Development in iOS 8',
#   'Learn the skills required to become a iOS developer. An easy to follow course that teaches key fundamental skills',
#   'Infinite Skills',
#   '4.6',
#   'Not Available',
#   '(6)',
#   '6.5 total hours\n70 lectures\nAll Levels',
#   'https://www.udemy.com/course/learning-app-development-in-ios-8/'],
#  ['Android app development for beginners (with Kotlin)',
#   'Kotlin Android Apps Development (Beginner to advanced)',
#   'Beh Kh.',
#   '4.5',
#   'Not Available',
#   '(64)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-q-app-development-with-kotlin-beginner-to-advanced/'],
#  ['iOS 12 & Swift 5 - App Design, UI/UX plus Development',
#   'The three-in-one course that teaches app design, UI/UX and iOS development.',
#   'Gwinyai Nyatsoka',
#   '4.3',
#   'Bestseller',
#   '(748)',
#   '80.5 total hours\n493 lectures\nBeginner',
#   'https://www.udemy.com/course/app-design-uiux-plus-ios-development/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['Flutter & Dart Development For Building iOS and Android Apps',
#   'Flutter is created by Google and is the future of all iOS and Android applications. It is powered by the Dart language',
#   'Frahaan Hussain',
#   '4.6',
#   'Not Available',
#   '(499)',
#   '10 total hours\n125 lectures\nAll Levels',
#   'https://www.udemy.com/course/flutter-mobile-development/'],
#  ['The Complete iOS 10 & Swift 3 Developer Course',
#   'Learn iOS App Development by building 21 iOS apps using Swift 3 & Xcode 8.',
#   'Rob Percival, Codestars by Rob Percival',
#   '4.5',
#   'Not Available',
#   '(10,764)',
#   '30 total hours\n222 lectures\nAll Levels',
#   'https://www.udemy.com/course/complete-ios-10-developer-course/'],
#  ['Windows Phone Mobile App Development',
#   'Learn how to create mobile apps for the Windows Store. Real-life project examples.',
#   'Tiffany Ford',
#   '4.3',
#   'Not Available',
#   '(14)',
#   '2 total hours\n18 lectures\nBeginner',
#   'https://www.udemy.com/course/windows-phone-mobile-app-development/'],
#  ['Learn Android App Development & Promote Your App like a Pro',
#   'Learn how to create a Productivity Android App and how to rank #1 in Play Store and get 1,000,000 downloads',
#   'Val Okafor, Alex Genadinik Teaching Assistant',
#   '4.1',
#   'Not Available',
#   '(46)',
#   '14.5 total hours\n111 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-in-3-days-1000000-downloads/'],
#  ['Unity Android Game & App Development - Build 10 Games & Apps',
#   'Learn Android Game Development With Unity & Android App Development With MIT App Inventor, Build 10 Android',
#   'Raja Biswas, Charger Games',
#   '3.6',
#   'Not Available',
#   '(222)',
#   '22 total hours\n147 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-unity-game-development-android-app-development/'],
#  ['Mobile App Development with Titanium Studio by Jason Foster',
#   "Develop apps for Android, Blackberry, iOS, and HTML using a single code base with Titanium Studio's classic",
#   'Jason Foster',
#   '4.4',
#   'Not Available',
#   '(31)',
#   '9 total hours\n62 lectures\nAll Levels',
#   'https://www.udemy.com/course/mobile-app-development-with-titanium-studio-by-jason-foster/'],
#  ['Learn Android App Development using Java from Scratch',
#   'Hands on Projects included',
#   'Shubham Garg',
#   '4.5',
#   'Not Available',
#   '(6)',
#   '1.5 total hours\n5 lectures\nBeginner',
#   'https://www.udemy.com/course/learn-android-app-development-using-java-from-scratch/'],
#  ['Android Q App Development Mastery Course - Build 20+ Apps',
#   'Complete Android App Development Course using Java & Android Studio.',
#   'Kapil Bhattarai',
#   '4.5',
#   'Not Available',
#   '(30)',
#   '20.5 total hours\n190 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-masterclass/'],
#  ['Android Development for Beginners: Your first app in 2 hours',
#   'Learn Android app development step-by-step from hands-on senior android developer',
#   'Vadims Savjolovs',
#   '3.9',
#   'Not Available',
#   '(134)',
#   '2 total hours\n37 lectures\nBeginner',
#   'https://www.udemy.com/course/android_development_for_beginners/'],
#  ['Learn Mobile App Development with Ionic Framework',
#   'Create professional mobile apps using the Ionic Framework',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '4.3',
#   'Not Available',
#   '(71)',
#   '3.5 total hours\n31 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-mobile-app-deveopment-with-ionic-framework/'],
#  ['Android Studio Masterclass - APP DEVELOPMENT COURSE',
#   'Learn Android App Development using ANDROID STUDIO & JAVA JDK .',
#   'Sagar Kundu',
#   '4.4',
#   'Not Available',
#   '(52)',
#   '10.5 total hours\n52 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-course-with-android-studio/'],
#  ['Mixed Language App Development with Objective-C and Swift',
#   'Effective Development for Cocoa and Cocoa Touch with Xcode',
#   'Infinite Skills',
#   '4.3',
#   'Not Available',
#   '(9)',
#   '7 total hours\n89 lectures\nIntermediate',
#   'https://www.udemy.com/course/mixed-language-app-development-with-objective-c-and-swift/'],
#  ['Low-code app development on the Creatio platform',
#   'Learn to create applications without programming skills with low-code platform',
#   'Creatio (formerly bpm’online)',
#   '4.5',
#   'Not Available',
#   '(60)',
#   '8.5 total hours\n56 lectures\nBeginner',
#   'https://www.udemy.com/course/creatio-low-code-app-development/'],
#  ['Android and Apple App Development: Beginner to Pro',
#   'Never developed an app before? Learn Android and Apple development, learn Java and Swift.',
#   'Stone River eLearning',
#   '4.5',
#   'Not Available',
#   '(50)',
#   '42 total hours\n504 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-and-apple-app-development-beginner-to-pro/'],
#  ['How To Make An Android App Without Knowing Development',
#   'Learn A Simple And Efficient Method For Android Apps Development Without Knowing How To Code.',
#   'Sorin Constantin, Emily S. Lima',
#   '4.3',
#   'Not Available',
#   '(54)',
#   '3 total hours\n14 lectures\nAll Levels',
#   'https://www.udemy.com/course/how-to-make-an-android-app-without-knowing-development/'],
#  ['Learning Android Apps Development from Scratch',
#   'Learn how to create your first Android Application and Publish it to google play store. With all the details from A to Z',
#   'Sarah Alenzei',
#   '3.9',
#   'Not Available',
#   '(14)',
#   '2.5 total hours\n16 lectures\nAll Levels',
#   'https://www.udemy.com/course/learning-android-apps-development-from-scratch/'],
#  ['Learn Javascript Web App Development -Build A Calculator App',
#   'Javascript for Front End Web Development - Build Your Own Calculator App Using Javascript, HTML5 & CSS',
#   'DigiFisk (Programming is fun)',
#   '4.7',
#   'Not Available',
#   '(99)',
#   '4 total hours\n35 lectures\nAll Levels',
#   'https://www.udemy.com/course/create-a-calculator-web-app-with-javascript-html-css/'],
#  ["Learn Apple's IOS App Development with Swift from scratch",
#   "An absolute beginner's quick introduction to creating apps for Apple's devices",
#   'Bluelime Learning Solutions',
#   '3.9',
#   'Not Available',
#   '(13)',
#   '3 total hours\n31 lectures\nBeginner',
#   'https://www.udemy.com/course/learn-apples-ios-app-development-with-swift-from-scratch/'],
#  ['Android Development Course Build TopNote App Using Firebase',
#   'Build Complete Android App With Firebase Database, Learn How To Develop Complex Android App, Become Master',
#   'Yazdani Chowdhury',
#   '4.2',
#   'Not Available',
#   '(16)',
#   '3 total hours\n13 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-development-course-build-topnote-app-using-firebase/'],
#  ['Android App Development using Android Studio - Advance',
#   'Learn Mobile App Development on Android Platform using Android SDK, Integration with Back End, Sample',
#   'Sisoft Learning',
#   '4.2',
#   'Not Available',
#   '(65)',
#   '17.5 total hours\n102 lectures\nAll Levels',
#   'https://www.udemy.com/course/sisoft-android-app-development-advance/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['Xamarin iOS - A Master Guide to App Development in C#',
#   'Complete Xamarin.iOS Reference for Building iOS Apps in C#.',
#   'Grant Klimaytys',
#   '4.0',
#   'Not Available',
#   '(271)',
#   '7.5 total hours\n95 lectures\nAll Levels',
#   'https://www.udemy.com/course/xamarin-ios-the-master-guide/'],
#  ['iOS App Development With Corona SDK - Mobile Apps Made Easy',
#   'Learn how to create mobile apps for iOS and Android the easy way.',
#   'Infinite Skills',
#   '4.4',
#   'Not Available',
#   '(26)',
#   '4 total hours\n39 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-app-development-with-corona-sdk-mobile-apps-made-easy/'],
#  ['iOS app development for absolute beginners!',
#   'iOS app development made easy! Navigate Xcode, swift, gain confidence in mobile development!',
#   'Yehuda Oren Cohen',
#   '4.2',
#   'Not Available',
#   '(64)',
#   '1.5 total hours\n12 lectures\nBeginner',
#   'https://www.udemy.com/course/for-kids-creating-iphone-apps/'],
#  ['Advanced Table View iOS App Development with Swift & Xcode',
#   'Learn Programmatic Auto Layout, UITableView, Protocols & Delegates, Custom Cells, NSAttributedString, UIKit & Swift.',
#   'Max Nelson',
#   '4.1',
#   'Not Available',
#   '(49)',
#   '6 total hours\n60 lectures\nAll Levels',
#   'https://www.udemy.com/course/tableviews/'],
#  ['Android App & Game Development :Build 6 Android Apps & Games',
#   'Android App Development Without Coding For Beginners Build Android Apps With Appinventor 2 Learn Android',
#   'Raja Biswas, Charger Games',
#   '4.1',
#   'Not Available',
#   '(58)',
#   '2.5 total hours\n50 lectures\nBeginner',
#   'https://www.udemy.com/course/create-android-apps-in-minutes/'],
#  ['IONIC 4 App Development to Deployment',
#   'Once Done with Development we will publish app to Stores.',
#   'Awais Jamil',
#   '4.6',
#   'Not Available',
#   '(8)',
#   '3 total hours\n24 lectures\nIntermediate',
#   'https://www.udemy.com/course/mobile-app-from-development-to-deployment-ionic-4/'],
#  ['App Development Without Coding Masterclass - Level 101',
#   'In this masterclass course students will learn how to build mobile and web applications without coding.',
#   'Mark Piller',
#   '4.5',
#   'Not Available',
#   '(4)',
#   '6.5 total hours\n32 lectures\nBeginner',
#   'https://www.udemy.com/course/build-mobile-app-without-coding-masterclass-level-101/'],
#  ['Cross-platform Desktop App Development for Windows Mac Linux',
#   'Create a multiplatform desktop applications which runs on Mac, Windows and Linux with one single code base',
#   'Adria Jimenez',
#   '4.7',
#   'Not Available',
#   '(46)',
#   '7 total hours\n67 lectures\nIntermediate',
#   'https://www.udemy.com/course/cross-platform-desktop-app-development-windows-mac-linux/'],
#  ['Android Development: Android App Development From Scratch',
#   'Learn Android App development with Android Oreo. Use Android Studio like a pro.',
#   'Oak Academy',
#   '4.0',
#   'Not Available',
#   '(86)',
#   '18 total hours\n130 lectures\nBeginner',
#   'https://www.udemy.com/course/android-development-android-app-development-from-scratch/'],
#  ['Learn Android App Development and How to Build Apps with AWS',
#   'Learn the Fundamentals of Android App Development and how to build Android Apps with Amazon Web Services',
#   'Matrix Tech',
#   '4.1',
#   'Not Available',
#   '(60)',
#   '7 total hours\n46 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-build-your-first-app/'],
#  ['iOS 13 & Swift 5—The Complete iOS App Development Course',
#   'Master iOS development in iOS 13 with Swift 5.',
#   'Josh Arnold',
#   '4.2',
#   'Not Available',
#   '(7)',
#   '5 total hours\n29 lectures\nAll Levels',
#   'https://www.udemy.com/course/become-a-pro-ios-developer-in-less-than-5-hours/'],
#  ['Android App Development: Easy and Quick Programming',
#   'App development. Programming Language',
#   'Stone River eLearning',
#   '4.1',
#   'Not Available',
#   '(43)',
#   '9 total hours\n121 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-easy-and-quick-programming/'],
#  ['Android App Development with Kotlin',
#   'Using Kotlin, build an Android application from scratch, style it, and publish it on Google Play Store',
#   'Packt Publishing',
#   '5.0',
#   'Not Available',
#   '(2)',
#   '3 total hours\n28 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-with-kotlin/'],
#  ['Mobile App development for beginners - Android and Apple',
#   'Create and deploy an app to a device',
#   'Bluelime Learning Solutions',
#   '3.7',
#   'Not Available',
#   '(31)',
#   '6.5 total hours\n60 lectures\nBeginner',
#   'https://www.udemy.com/course/mobile-app-development-for-beginners-android-and-apple/'],
#  ['Apple TV App & Game Development for tvOS',
#   'Everything you need to know to build apps and games for the Apple TV on tvOS including TVML, Swift, and',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.6',
#   'Not Available',
#   '(389)',
#   '16 total hours\n83 lectures\nBeginner',
#   'https://www.udemy.com/course/apple-tv/'],
#  ['Android App Development with Dependencies',
#   'A Complete Course on Android App Development with Android Dependencies',
#   'The Apps Firm',
#   '3.8',
#   'Not Available',
#   '(27)',
#   '1.5 total hours\n32 lectures\nIntermediate',
#   'https://www.udemy.com/course/android-dependencies-bootcamp/'],
#  ['Android project base app development course build (Real App)',
#   'this android course you will build real world project.you will learn how to build advanced android app',
#   'Yazdani Chowdhury',
#   '3.6',
#   'Not Available',
#   '(83)',
#   '5 total hours\n44 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-project-base-app-development-course-build-real-app/'],
#  ['The Complete Android R + Java Developer Course™ : 2020',
#   "In this course, you'll learn Android Development and get to build your own Android R apps by using Java",
#   'Morteza Kordi',
#   '4.5',
#   'Not Available',
#   '(3,675)',
#   '167 total hours\n678 lectures\nAll Levels',
#   'https://www.udemy.com/course/java-android-complete-guide/'],
#  ['Android App Development: Mobile App Development & Java',
#   'Android App Development & Java Programming: Mobile App Development & Design, Build Android Apps, Android',
#   'Easy Learn',
#   '2.8',
#   'Not Available',
#   '(177)',
#   '4.5 total hours\n29 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-mobile-app-development-java/'],
#  ['SwiftUI Development - iOS 13 & Swift 5 App Development',
#   'Learn iOS app development with SwiftUI using MVVM Architecture, REST API, Observer Pattern, View composing',
#   'Gaurav Parvadiya',
#   '4.1',
#   'Not Available',
#   '(9)',
#   '4 total hours\n36 lectures\nAll Levels',
#   'https://www.udemy.com/course/swiftui-development-bootcamp-complete-ios-app-development/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['App Development: Tutorial for Building Apps for Businesses',
#   'Creating apps for local businesses is extremely lucrative.',
#   'Ira Turner',
#   '3.6',
#   'Not Available',
#   '(7)',
#   '2 total hours\n26 lectures\nAll Levels',
#   'https://www.udemy.com/course/app-development-tutorial-for-building-apps-for-businesses/'],
#  ['Machine Learning for Android App development Using ML Kit',
#   'Add intelligent features to your Android apps with ML Kit',
#   'Packt Publishing',
#   '3.5',
#   'Not Available',
#   '(20)',
#   '2 total hours\n22 lectures\nIntermediate',
#   'https://www.udemy.com/course/machine-learning-for-android-app-development-using-ml-kit/'],
#  ['How to Outsource your iPhone App Development the Proper Way',
#   'Have you heard all the horror stories from outsourcing? Here are the EXACT steps to do it right - save TIME and MONEY!',
#   'Adarsh Menon',
#   '4.6',
#   'Not Available',
#   '(3)',
#   '4 total hours\n39 lectures\nAll Levels',
#   'https://www.udemy.com/course/how-to-make-an-iphone-app-through-outsourcing/'],
#  ['Android App Development for Beginners',
#   'Hands-on Android Development course for Beginners - Create your app by the end of the course',
#   'Anu Khanchandani',
#   '3.7',
#   'Not Available',
#   '(8)',
#   '5.5 total hours\n28 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-android-programming-by-example/'],
#  ['Business App Development in Dynamics 365 for Non-Programmers',
#   'Build useful apps for mobile and the web using the PowerApp platform from Microsoft',
#   'Packt Publishing',
#   '4.5',
#   'Not Available',
#   '(17)',
#   '3.5 total hours\n28 lectures\nBeginner',
#   'https://www.udemy.com/course/business-app-development-in-dynamics-365-for-non-programmers/'],
#  ['Learn App Development with Docker',
#   'The Ultimate Course to Master Development and Management of Web Apps on Docker',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '3.5',
#   'Not Available',
#   '(142)',
#   '4.5 total hours\n23 lectures\nBeginner',
#   'https://www.udemy.com/course/learn-app-development-with-docker/'],
#  ['Complete Unity® and Android Development: Build Games & Apps',
#   'Learn to code & build beginner Android apps! And make a Legend of Zenda game in Unity®.',
#   'Mammoth Interactive, John Bura',
#   '4.4',
#   'Not Available',
#   '(257)',
#   '40.5 total hours\n402 lectures\nBeginner',
#   'https://www.udemy.com/course/complete-unity-and-android-development-build-games-and-apps/'],
#  ['Kotlin for Android Development : Develop an App with Kotlin',
#   'Develop a Real World Weather App Using Kotlin for Android Development',
#   'Concept Courses \u206f\u206f\u206f\u206f\u206f, Ted Horyczun',
#   '3.5',
#   'Not Available',
#   '(141)',
#   '1 total hour\n24 lectures\nBeginner',
#   'https://www.udemy.com/course/kotlin-for-android-development-development/'],
#  ['Beginner Introduction to Mobile App development with Xamarin',
#   'Build cross-platform apps for IOS, Android or Windows using Xamarin',
#   'Bluelime Learning Solutions',
#   '3.9',
#   'Not Available',
#   '(43)',
#   '3.5 total hours\n41 lectures\nBeginner',
#   'https://www.udemy.com/course/beginner-introduction-to-mobile-app-development-with-xamarin/'],
#  ['iOS App Development',
#   'Publish your apps to the itunes store!',
#   'Travis .',
#   '4.1',
#   'Not Available',
#   '(3)',
#   '29 total mins\n15 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-to-publish-your-ios-apps-for-free/'],
#  ['Mobile App Development & App Design for iOS & Android 2020',
#   'Design and program iOS and Android app with social media (facebook and twitter).',
#   'Invedion ™',
#   '3.2',
#   'Not Available',
#   '(23)',
#   '11.5 total hours\n44 lectures\nAll Levels',
#   'https://www.udemy.com/course/advanced-app-development-and-design-course-for-ios-and-android/'],
#  ["I Want to Create an App But Don't Know Where to Start!",
#   'Understand the myriad of app development tools, technologies and frameworks, regardless if you are a',
#   'Gary Kind',
#   '4.3',
#   'Not Available',
#   '(63)',
#   '1 total hour\n11 lectures\nAll Levels',
#   'https://www.udemy.com/course/i-want-to-create-an-app-but-dont-know-where-to-start/'],
#  ['Android N: From Beginner to Paid Professional',
#   'Comprehensive Android Nougat app development',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.0',
#   'Not Available',
#   '(2,203)',
#   '25 total hours\n93 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-android/'],
#  ['Python Django Web Development: To-Do App',
#   'Learn Database Driven Web Development With Django and Python!',
#   'John Elder',
#   '4.6',
#   'Not Available',
#   '(880)',
#   '2 total hours\n34 lectures\nBeginner',
#   'https://www.udemy.com/course/python-django-web-development-to-do-app/'],
#  ['Oracle Apex - Web App Development',
#   'Build enterprise apps 20 x faster with 100 x less code.',
#   'Vijay Thapa',
#   '4.3',
#   'Not Available',
#   '(37)',
#   '2 total hours\n14 lectures\nIntermediate',
#   'https://www.udemy.com/course/oracle-apex-web-app-development/'],
#  ['Build Real Android Apps: Android App Development with Java',
#   'Learn Java & Android App development with Android Oreo.',
#   'Oak Academy',
#   '5.0',
#   'Not Available',
#   '(2)',
#   '26 total hours\n201 lectures\nBeginner',
#   'https://www.udemy.com/course/build-real-android-apps-android-app-development-with-java/'],
#  ['Full Stack Web (Angular) and Mobile (Ionic) App Development',
#   'Step by step implementation with Spring Boot 2.1.4, Angular 7, Ionic 4 (ios, android, windows), hibernate, liquibase',
#   'Senol Atac',
#   '4.2',
#   'Not Available',
#   '(5)',
#   '3.5 total hours\n54 lectures\nAll Levels',
#   'https://www.udemy.com/course/full-stack-web-and-multiplatform-mobile-app-development/'],
#  ['Android App Development Course',
#   'Learn Android App Development Cours with Android 9 (Pie) Build real Apps like Uber , Whatsapp, Google',
#   'Zeeshan Mehdi',
#   '3.5',
#   'Not Available',
#   '(72)',
#   '15.5 total hours\n49 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-course/'],
#  ['Real World Android App Development Course Build 10 App',
#   'This Android App Development Course is for Developing Expense Manager Android App Note Book Android App',
#   'Yazdani Chowdhury',
#   '3.4',
#   'Not Available',
#   '(34)',
#   '13 total hours\n86 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-apps-development-using-java-and-kotlin/'],
#  ['Complete Firebase Tutorial for Android App Development',
#   'Learn how to use firebase services for android app development with practical example.',
#   'Janhavi Sawant',
#   '3.4',
#   'Not Available',
#   '(36)',
#   '4.5 total hours\n15 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-firebase-authentication-realtime-database-fcm-crashlytics/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['iOS Development - Adding In-App Purchasing To iOS Apps',
#   'Learn How To Add In-App Purchasing Into Your iOS Application.',
#   'Infinite Skills',
#   '3.7',
#   'Not Available',
#   '(4)',
#   '1 total hour\n16 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-inapp-purchase/'],
#  ['Create Android & iOS Apps Without Coding',
#   'Amazing Android and iOS App Development Without Coding or programming',
#   'Khalid Hamadeh',
#   '4.0',
#   'Not Available',
#   '(27)',
#   '2 total hours\n31 lectures\nAll Levels',
#   'https://www.udemy.com/course/create-stunning-apps-without-coding/'],
#  ['Android App Development – Making Your First App with Eclipse',
#   'Beginners guide to make an Android app with Eclipse IDE with sound effects, menu, and a splash screen',
#   'Andrew Durtka',
#   '3.7',
#   'Not Available',
#   '(4)',
#   '2 total hours\n22 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-app-development-making-your-first-app-with-eclipse/'],
#  ['Decentralized App Development with Blockchain-Novice to Pro!',
#   'Build decentralized gaming application using Ethereum! Blockchain projects which establish security using Hyperledger.',
#   'Packt Publishing',
#   '4.3',
#   'Not Available',
#   '(17)',
#   '12.5 total hours\n116 lectures\nBeginner',
#   'https://www.udemy.com/course/decentralized-app-development-with-blockchain-novice-to-pro/'],
#  ['Quick Guide to iOS App Development - Novice to Pro!: 4-in-1',
#   'Build a custom web browser, a local Notepad app, and an iTunes movies browser using iOS 11 and Swift',
#   'Packt Publishing',
#   '4.7',
#   'Not Available',
#   '(2)',
#   '14.5 total hours\n137 lectures\nBeginner',
#   'https://www.udemy.com/course/quick-guide-to-ios-app-development-novice-to-pro-4-in-1/'],
#  ['Beginner Mobile App Development with Appcelerator Titanium',
#   'Learn to develop native iPhone, Android, Blackberry, and Mobile Web apps with Open Source tools.',
#   'Szymon Machajewski',
#   '3.3',
#   'Not Available',
#   '(19)',
#   '3.5 total hours\n19 lectures\nAll Levels',
#   'https://www.udemy.com/course/mobile-phone-development/'],
#  ['iOS app development: Swift 5 fundamentals for beginners',
#   'Learn the basics of Swift 5 to create iOS 13 App for the iPad and iPhone today!',
#   'Sam Saunders',
#   '4.5',
#   'Not Available',
#   '(2)',
#   '3.5 total hours\n34 lectures\nBeginner',
#   'https://www.udemy.com/course/ios-swift-beginner/'],
# ...
#   'https://www.udemy.com/course/cocos_2d/'],
#  ['Mastering iOS Development - Integrate iOS Apps With iCloud',
#   'Program Your iOS Apps To integrate With iCloud.',
#   'Infinite Skills',
#   '4.0',
#   'Not Available',
#   '(2)',
#   '1.5 total hours\n18 lectures\nAll Levels',
#   'https://www.udemy.com/course/integrate-ios-apps-with-icloud/'],
#  ['Full Stack App Development with Spring 5 and Angular: 3-in-1',
#   'Build amazingly beautiful apps combining the power of two hottest frameworks Angular 6 with Spring 5!',
#   'Packt Publishing',
#   '4.0',
#   'Not Available',
#   '(16)',
#   '8.5 total hours\n82 lectures\nIntermediate',
#   'https://www.udemy.com/course/full-stack-app-development-with-spring-5-and-angular-3-in-1/'],
#  ['Java: Enterprise App Development with Java 9: 4-in-1',
#   'Build modern and scalable enterprise applications using Java 9 and Java EE 8 to become a professional Java developer!',
#   'Packt Publishing',
#   '3.6',
#   'Not Available',
#   '(5)',
#   '9 total hours\n62 lectures\nBeginner',
#   'https://www.udemy.com/course/java-enterprise-app-development-with-java-9-4-in-1/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['Introduction to Android Development for beginners',
#   'Create an Android App step by step from scratch',
#   'Bluelime Learning Solutions',
#   '4.2',
#   'Not Available',
#   '(120)',
#   '8 total hours\n70 lectures\nBeginner',
#   'https://www.udemy.com/course/introduction-to-android-development-for-beginners/'],
#  ['Serverless Apps Development with Azure Functions and Node.js',
#   'Build effective, scalable, Node.js applications and deploy them on the cloud',
#   'Packt Publishing',
#   '3.7',
#   'Not Available',
#   '(10)',
#   '6.5 total hours\n62 lectures\nBeginner',
#   'https://www.udemy.com/course/serverless-apps-development-with-azure-functions-and-nodejs/'],
#  ['The Complete Android Developer Course : From Zero to Hero',
#   'Improve your career options by learning Android app Development. Master Android Studio',
#   'SunLight Team',
#   '4.3',
#   'Not Available',
#   '(72)',
#   '4.5 total hours\n36 lectures\nBeginner',
#   'https://www.udemy.com/course/the-complete-android-developer-course-from-zero-to-hero/'],
#  ['Progressive Web App Development: A Complete Guide: 2-in-1',
#   'Simplify your application development and deployment by creating apps with improved capabilities',
#   'Packt Publishing',
#   '3.9',
#   'Not Available',
#   '(3)',
#   '9.5 total hours\n78 lectures\nBeginner',
#   'https://www.udemy.com/course/progressive-web-app-development-a-complete-guide-2-in-1/'],
#  ['Android P with Machine Learning apps - 26+ projects in total',
#   'Master Android development with latest tech stack like Firebase, Sqlite, Machine Leaning etc',
#   'Igneus Technologies',
#   '4.5',
#   'Not Available',
#   '(176)',
#   '19.5 total hours\n127 lectures\nAll Levels',
#   'https://www.udemy.com/course/android-p-with-machine-learning-apps/'],
#  ['iOS 12: Learn to Code & Build Real iOS 12 Apps in Swift 4.2',
#   'Master iOS 12 development with Swift 4.2 building full-stack apps in this brand new course. Incl.',
#   'Caleb Stultz, Jonathan Burgoyne',
#   '4.7',
#   'Not Available',
#   '(822)',
#   '52 total hours\n256 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios-12-learn-to-code/'],
#  ['Kotlin Android Development Masterclass',
#   'Learn Kotlin, Android Development, Android Studio & IntelliJ IDEA from Scratch.',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.1',
#   'Not Available',
#   '(808)',
#   '32.5 total hours\n224 lectures\nAll Levels',
#   'https://www.udemy.com/course/kotlin-android-developer-masterclass/'],
#  ['Code a Swift iOS To Do List App, UIKit, CoreData, Table View',
#   'Learn Widely Used Concepts and Best Practices Used in Modern Day iOS Development to Hone Your Craft and',
#   'Max Nelson',
#   '4.4',
#   'Not Available',
#   '(149)',
#   '9.5 total hours\n72 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios11swift4todolist/'],
#  ['Complete iOS 10 development Bootcamp',
#   'A complete app design process and development with swift 3, xcode 8, SketchApp and Firebase for ios 10',
#   'Igneus Technologies',
#   '4.1',
#   'Not Available',
#   '(174)',
#   '26.5 total hours\n151 lectures\nAll Levels',
#   'https://www.udemy.com/course/complete-ios-10-design-and-development-bootcamp/'],
#  ['Learn to Build a Professional App in Android',
#   'A Hands on Approach to Android App Development for Professionals',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '4.3',
#   'Not Available',
#   '(20)',
#   '3.5 total hours\n17 lectures\nAll Levels',
#   'https://www.udemy.com/course/learn-to-build-a-professional-app-in-android/'],
#  ['Learning Path: Laravel: Modern App Development with Laravel',
#   'Grasp everything you need to know to get started with Laravel',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(6)',
#   '9 total hours\n49 lectures\nIntermediate',
#   'https://www.udemy.com/course/learning-path-laravel-modern-app-development-with-laravel/'],
#  ['Hands-On App Development with Ionic',
#   'This hands-on course teaches you to build reactive, scalable, and dynamic cross-platform apps using Ionic',
#   'Packt Publishing',
#   '4.1',
#   'Not Available',
#   '(2)',
#   '6 total hours\n38 lectures\nBeginner',
#   'https://www.udemy.com/course/hands-on-app-development-with-ionic/'],
#  ['Make Social Networking App like Instagram - Kotlin, Firebase',
#   'Create Social Network App like Instagram, Facebook & snapchat clone - Android Studio Kotlin Development',
#   'Coding Cafe',
#   '4.2',
#   'Not Available',
#   '(21)',
#   '15 total hours\n34 lectures\nAll Levels',
#   'https://www.udemy.com/course/make-social-networking-app-like-instagram-kotlin-firebase/'],
#  ["The Android developer's journey",
#   'Android App Development via Android Studio, the Java object-oriented programming language, together with',
#   'Richard Goodman, Codestars by Rob Percival',
#   '4.1',
#   'Not Available',
#   '(154)',
#   '14 total hours\n114 lectures\nBeginner',
#   'https://www.udemy.com/course/the-android-developers-journey/'],
#  ['Make Whatsapp Stickers App in Android Studio - No Coding',
#   'Whatsapp Stickers Android App Development, Without Knowledge of Coding - Android Studio Project',
#   'Shuja Sardar',
#   '4.9',
#   'Not Available',
#   '(4)',
#   '35 total mins\n20 lectures\nAll Levels',
#   'https://www.udemy.com/course/whatsapp-stickers-app-development-in-android-studio/'],
#  ['Meteor: Full Stack JavaScript, MongoDB & App Development',
#   'Meteor Framework, Full Stack Javascript & Mongodb: App Development, SQL, CSS & HTML, MeteorJS, Front',
#   'Easy Learn',
#   '1.6',
#   'Not Available',
#   '(112)',
#   '4.5 total hours\n44 lectures\nAll Levels',
#   'https://www.udemy.com/course/meteor-full-stack-javascript-mongodb-app-development/'],
#  ['How to Make a Freaking iPhone App - iOS 11 and Swift 4',
#   'iPhone App Development from scratch. Learn how to make iOS apps using Xcode 9.',
#   'Nick Walter',
#   '4.7',
#   'Not Available',
#   '(477)',
#   '16.5 total hours\n143 lectures\nBeginner',
#   'https://www.udemy.com/course/how-to-make-a-freaking-iphone-app-ios-11-and-swift-4-xcode-9/'],
#  ['LEARNING PATH: Electron: App Development with Electron',
#   'Efficiently build, package, and distribute your Electron applications',
#   'Packt Publishing',
#   '3.3',
#   'Not Available',
#   '(19)',
#   '6 total hours\n55 lectures\nIntermediate',
#   'https://www.udemy.com/course/learning-path-electron-app-development-with-electron/'],
#  ['Swift 3 - Master Swift Development From Scratch',
#   'Then learn building iOS10 Apps or Server Side Swift Apps.',
#   'Nikant Vohra',
#   '4.5',
#   'Not Available',
#   '(181)',
#   '6.5 total hours\n63 lectures\nAll Levels',
#   'https://www.udemy.com/course/swift-development/'],
#  ['Blockchain Development: Convert An App To A Dapp (2020)',
#   'Learn How To Make A Decentralized Blockchain App Using Ethereum & Solidity From A Centralized MERN App',
#   'Masnad Nehith',
#   '4.6',
#   'Not Available',
#   '(69)',
#   '4 total hours\n78 lectures\nBeginner',
#   'https://www.udemy.com/course/blockchain-development-convert-an-app-to-a-dapp/'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://business.udemy.com/request-demo/?ref=ufb_header&mx_pg=search-results&locale=en_US'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/teaching/?ref=teach_header'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'https://www.udemy.com/cart/'],
#  ['The App Developer Bootcamp',
#   'Learn the basics of Swift and Xcode for app development quick and fast.',
#   'Online Training Plus',
#   '4.7',
#   'Not Available',
#   '(20)',
#   '6 total hours\n27 lectures\nBeginner',
#   'https://www.udemy.com/course/the-app-developer-bootcamp/'],
#  ['Beginners Swift Programming For iOS Development',
#   'Learn how to program with iOS Apps with Swift. A easy to follow course for the beginner',
#   'Infinite Skills',
#   '4.7',
#   'Not Available',
#   '(9)',
#   '3 total hours\n49 lectures\nAll Levels',
#   'https://www.udemy.com/course/beginners-swift-programming-for-ios-development/'],
#  ['Windows 10 C++ App Development for Startups - C++ Simplified',
#   'Learn C++ From Scratch - Go from zero programming to building 2 Windows 10 C++ apps!',
#   'Augmented Startups, Rajiv Desai',
#   '2.7',
#   'Not Available',
#   '(19)',
#   '3 total hours\n21 lectures\nBeginner',
#   'https://www.udemy.com/course/the-complete-windows-10-c-course-and-build-2-apps/'],
#  ['The Complete RxJava 2 For Android Development Masterclass',
#   'Architect Android Apps With Rx Java 2 , MVVM, Room DB, Retrofit 2 & Dagger 2.',
#   'Anushka Madusanka',
#   '4.4',
#   'Bestseller',
#   '(561)',
#   '6.5 total hours\n103 lectures\nAll Levels',
#   'https://www.udemy.com/course/rxjavarxandroid-bootcamp-reactivex-for-android-developers/'],
#  ['The Complete Android and IOS App Game Development',
#   'Learn how to make online games without knowing how to code',
#   'Ambioris Martinez',
#   '2.5',
#   'Not Available',
#   '(1)',
#   '5 total hours\n15 lectures\nBeginner',
#   'https://www.udemy.com/course/how-to-make-app-games-from-start-to-finish/'],
#  ['The Complete Android Oreo Tutorial - Make 30 Apps',
#   'Android 7.1 development: Become an Android developer, by making more than 30 Android mobile apps.',
#   'Sriyank Siddhartha',
#   '3.7',
#   'Not Available',
#   '(486)',
#   '17.5 total hours\n141 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-android-tutorial-for-beginners/'],
#  ['Intermediate iOS - Complex and Advanced iPhone Apps',
#   'Use Xcode and Swift 4 to take your app development skills to the next level',
#   'Nick Walter, Mohammad Azam',
#   '4.7',
#   'Not Available',
#   '(159)',
#   '12.5 total hours\n63 lectures\nAll Levels',
#   'https://www.udemy.com/course/intermediate-ios-11-complex-and-advanced-iphone-apps/'],
#  ['Swift 4 and iOS 11: Building a Store Front App (App Only)',
#   '*** FREE Update to Swift 4 and iOS 11 *** Swift iOS development: Developing eCommerce type application',
#   'Andi Setiyadi',
#   '4.4',
#   'Not Available',
#   '(23)',
#   '16 total hours\n50 lectures\nBeginner',
#   'https://www.udemy.com/course/pirate-bay-ios-swift-3-development-app-only/'],
#  ['Web Application Development - Learn by Building 3 Web Apps',
#   'Use the power of HTML5 and jQuery to develop 3 Latest Web Apps!',
#   'Akshay Nagpal',
#   '3.6',
#   'Not Available',
#   '(19)',
#   '1.5 total hours\n29 lectures\nBeginner',
#   'https://www.udemy.com/course/build-3-web-applications-in-90-minutes/'],
#  ['Flutter Web Development Course Build Complete FlutterWeb App',
#   'Flutter Web development Course Will Teach You-How To Build Complete Web App Using Flutter,Flutter Web',
#   'Yazdani Chowdhury',
#   '2.7',
#   'Not Available',
#   '(286)',
#   '2 total hours\n10 lectures\nAll Levels',
#   'https://www.udemy.com/course/flutter-web-development-course-build-complete-flutterweb-app/'],
#  ['The Complete Web Developer Course 2.0',
#   'Learn Web Development by building 25 websites and mobile apps using HTML, CSS, Javascript, PHP, Python',
#   'Rob Percival, Codestars by Rob Percival',
#   '4.5',
#   'Not Available',
#   '(63,878)',
#   '30.5 total hours\n309 lectures\nAll Levels',
#   'https://www.udemy.com/course/the-complete-web-developer-course-2/'],
#  ['The Ultimate iOS 10, Xcode 8 Developer course. Build 30 apps',
#   'Learn to become a virtuosic developer with the most comprehensive iOS development course ever produced',
#   'Mammoth Interactive, John Bura',
#   '4.4',
#   'Not Available',
#   '(249)',
#   '102.5 total hours\n300 lectures\nAll Levels',
#   'https://www.udemy.com/course/ios10developer/'],
#  ['The Complete iOS SDK Development Course - be job-ready!',
#   'Integrate Facebook, AdMob, Amazon, Google Sign-in and other 3rd party iOS SDKs into your apps Xcode 10',
#   'Codestars by Rob Percival, Rob Percival, Dee Aliyu Odumosu',
#   '4.3',
#   'Not Available',
#   '(41)',
#   '7.5 total hours\n126 lectures\nBeginner',
#   'https://www.udemy.com/course/ios-sdk-course/'],
#  ['Beast Android Development: Advanced Android UI',
#   'Learn to implement Firebase as your apps back-end.',
#   'Beast Android Development',
#   '3.2',
#   'Not Available',
#   '(172)',
#   '12 total hours\n53 lectures\nIntermediate',
#   'https://www.udemy.com/course/build-an-advance-android-app/'],
#  ['Android App Development for Complete Beginners',
#   'A gentle introduction to building your first Android App',
#   'Lee Falin',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '38 total mins\n9 lectures\nBeginner',
#   'https://www.udemy.com/course/android-app-development-for-complete-beginners/'],
#  ['Introduction to Android Development with Kotlin',
#   'Learn Android development basics with Kotlin by creating an app from scratch that gets data from GitHub',
#   'Linero Tech, Humberto Linero',
#   '4.9',
#   'Not Available',
#   '(3)',
#   '2 total hours\n13 lectures\nBeginner',
#   'https://www.udemy.com/course/introduction-to-android-development-with-kotlin/'],
#  ['iOS 14, Swift 5 & SwiftUI - The iOS Development Starter Kit',
#   'Build 12 iOS Apps from scratch & learn the basics of Swift 5, iOS 14 App Development in Xcode 12, and',
#   'Swift Starter Kit',
#   '4.6',
#   'Not Available',
#   '(22)',
#   '7 total hours\n102 lectures\nBeginner',
#   'https://www.udemy.com/course/swift-starter-kit/'],
#  ['Introduction to App Development & Game Development',
#   'Best way to understand the fundamentals of App & Game Development',
#   'Moonshot Jr',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '1 total hour\n6 lectures\nBeginner',
#   'https://www.udemy.com/course/introduction-to-app-development-game-development/'],
#  ['Android N: Professional Android N App Development: 2-in-1',
#   'Learn to build your own exciting Android apps!',
#   'Packt Publishing',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '7 total hours\n68 lectures\nBeginner',
#   'https://www.udemy.com/course/android-n-professional-android-n-app-development-2-in-1/'],
#  ['Ruby On Rails Web Development: To-Do List App',
#   'Learn Ruby On Rails The Fast And Easy Way!',
#   'John Elder',
#   '4.3',
#   'Not Available',
#   '(60)',
#   '3 total hours\n40 lectures\nBeginner',
#   'https://www.udemy.com/course/ruby-on-rails-to-do-list-app/']]

# %%
import pandas as pd
Data=pd.DataFrame(info,columns=['Title','HeadLine','Instructors','Rating','Tags','Reviews','AddInfo','Links'])

# %%
Data[Data['Title']=='Not Available'].index
Data.drop(Data[Data['Title']=='Not Available'].index,axis=0,inplace=True)

# %%
Data.reset_index(inplace=True)
Data.drop('index',axis=1,inplace=True)

# %%
Data['Title'].nunique()
# Out:
# 200

# %%
list(Data.Links)
# Out:
# ['https://www.udemy.com/course/ios-13-app-development-bootcamp/',
#  'https://www.udemy.com/course/ios11-app-development-bootcamp/',
#  'https://www.udemy.com/course/android-oreo-kotlin-app-masterclass/',
#  'https://www.udemy.com/course/the-complete-android-oreo-developer-course/',
#  'https://www.udemy.com/course/android-tutorial-for-beginners/',
#  'https://www.udemy.com/course/complete-android-n-developer-course/',
#  'https://www.udemy.com/course/flutter-dart-the-complete-flutter-app-development-course/',
#  'https://www.udemy.com/course/master-android-7-nougat-java-app-development-step-by-step/',
#  'https://www.udemy.com/course/androidappcourse/',
#  'https://www.udemy.com/course/mobile-app-development-with-phonegap/',
#  'https://www.udemy.com/course/android-app-development-with-java/',
#  'https://www.udemy.com/course/swiftui-masterclass-course-ios-development-with-swift/',
#  'https://www.udemy.com/course/stateoftheartandroid/',
#  'https://www.udemy.com/course/android-app-development-using-kotlin/',
#  'https://www.udemy.com/course/the-complete-flutter-app-development-course-for-android-ios/',
#  'https://www.udemy.com/course/complete-android-developer-course/',
#  'https://www.udemy.com/course/to-do-app-clean-architecture-android-development-kotlin/',
#  'https://www.udemy.com/course/learn-android-app-development-from-scratch-with-java/',
#  'https://www.udemy.com/course/androidforbeginners/',
#  'https://www.udemy.com/course/buildit-coding-a-published-android-app-in-real-time/',
#  'https://www.udemy.com/course/the-android-development-bootcamp-2019/',
#  'https://www.udemy.com/course/testing-ios-apps-behavior-driven-development-using-swift/',
#  'https://www.udemy.com/course/the-complete-android-developer-bootcamp/',
#  'https://www.udemy.com/course/ios-12-app-development-bootcamp/',
#  'https://www.udemy.com/course/bucketlist-1-create-an-app-and-put-it-on-your-own-iphone/',
#  'https://www.udemy.com/course/android-app-development-for-beginner/',
#  'https://www.udemy.com/course/learning-path-android-test-driven-android-app-development/',
#  'https://www.udemy.com/course/mobile-app-development-with-android-2015/',
#  'https://www.udemy.com/course/ios-development-create-4-quiz-apps-with-swift-3-ios-10/',
#  'https://www.udemy.com/course/intro-programming-and-app-development/',
#  'https://www.udemy.com/course/android-p-kotlin-complete-android-app-development-bootcamp/',
#  'https://www.udemy.com/course/intermediate-mobile-app-development-swift-3-iphone-ios10/',
#  'https://www.udemy.com/course/codekul-android-online-course-training/',
#  'https://www.udemy.com/course/ios-9-app-development-for-beginners/',
#  'https://www.udemy.com/course/javaandroidapp/',
#  'https://www.udemy.com/course/devslopes-ios10/',
#  'https://www.udemy.com/course/shopify-app-development/',
#  'https://www.udemy.com/course/android-development-make-apps-without-coding-or-experience/',
#  'https://www.udemy.com/course/mobile-app-development-make-ios-and-android-apps-without-code/',
#  'https://www.udemy.com/course/android-app-development-create-a-spotify-clone/',
#  'https://www.udemy.com/course/how-to-create-an-app/',
#  'https://www.udemy.com/course/ios-development-crash-course/',
#  'https://www.udemy.com/course/the-complete-android-development-bootcamp-java-and-kotlin/',
#  'https://www.udemy.com/course/make-me-an-iphone-app-developer-beginner-series/',
#  'https://www.udemy.com/course/complete-flutter-development/',
#  'https://www.udemy.com/course/the-complete-ios-11-course/',
#  'https://www.udemy.com/course/android-app-development-course-build-5-real-android-app/',
#  'https://www.udemy.com/course/ios-8-app/',
#  'https://www.udemy.com/course/ios-app-development-for-complete-and-utter-coding-beginners/',
#  'https://www.udemy.com/course/ios-development-app-monetization-for-swift-3-ios-10/',
#  'https://www.udemy.com/course/android-kotlin-developer/',
#  'https://www.udemy.com/course/the-complete-guide-to-running-a-mobile-app-dev-business/',
#  'https://www.udemy.com/course/hybrid-mobile-app-development-with-ionic/',
#  'https://www.udemy.com/course/how-to-use-git-branches-to-speed-up-android-app-development/',
#  'https://www.udemy.com/course/real-world-ios-app-in-10-days/',
#  'https://www.udemy.com/course/social-networking-android-app-development-from-scratch/',
#  'https://www.udemy.com/course/xamarin-android-a-master-guide-to-mobile-app-development/',
#  'https://www.udemy.com/course/learning-app-development-in-ios-8/',
#  'https://www.udemy.com/course/android-q-app-development-with-kotlin-beginner-to-advanced/',
#  'https://www.udemy.com/course/app-design-uiux-plus-ios-development/',
#  'https://www.udemy.com/course/flutter-mobile-development/',
#  'https://www.udemy.com/course/complete-ios-10-developer-course/',
#  'https://www.udemy.com/course/windows-phone-mobile-app-development/',
#  'https://www.udemy.com/course/android-app-development-in-3-days-1000000-downloads/',
#  'https://www.udemy.com/course/learn-unity-game-development-android-app-development/',
#  'https://www.udemy.com/course/mobile-app-development-with-titanium-studio-by-jason-foster/',
#  'https://www.udemy.com/course/learn-android-app-development-using-java-from-scratch/',
#  'https://www.udemy.com/course/android-app-development-masterclass/',
#  'https://www.udemy.com/course/android_development_for_beginners/',
#  'https://www.udemy.com/course/learn-mobile-app-deveopment-with-ionic-framework/',
#  'https://www.udemy.com/course/android-app-development-course-with-android-studio/',
#  'https://www.udemy.com/course/mixed-language-app-development-with-objective-c-and-swift/',
#  'https://www.udemy.com/course/creatio-low-code-app-development/',
#  'https://www.udemy.com/course/android-and-apple-app-development-beginner-to-pro/',
#  'https://www.udemy.com/course/how-to-make-an-android-app-without-knowing-development/',
#  'https://www.udemy.com/course/learning-android-apps-development-from-scratch/',
#  'https://www.udemy.com/course/create-a-calculator-web-app-with-javascript-html-css/',
#  'https://www.udemy.com/course/learn-apples-ios-app-development-with-swift-from-scratch/',
#  'https://www.udemy.com/course/android-development-course-build-topnote-app-using-firebase/',
#  'https://www.udemy.com/course/sisoft-android-app-development-advance/',
#  'https://www.udemy.com/course/xamarin-ios-the-master-guide/',
#  'https://www.udemy.com/course/ios-app-development-with-corona-sdk-mobile-apps-made-easy/',
#  'https://www.udemy.com/course/for-kids-creating-iphone-apps/',
#  'https://www.udemy.com/course/tableviews/',
#  'https://www.udemy.com/course/create-android-apps-in-minutes/',
#  'https://www.udemy.com/course/mobile-app-from-development-to-deployment-ionic-4/',
#  'https://www.udemy.com/course/build-mobile-app-without-coding-masterclass-level-101/',
#  'https://www.udemy.com/course/cross-platform-desktop-app-development-windows-mac-linux/',
#  'https://www.udemy.com/course/android-development-android-app-development-from-scratch/',
#  'https://www.udemy.com/course/android-app-development-build-your-first-app/',
#  'https://www.udemy.com/course/become-a-pro-ios-developer-in-less-than-5-hours/',
#  'https://www.udemy.com/course/android-app-development-easy-and-quick-programming/',
#  'https://www.udemy.com/course/android-app-development-with-kotlin/',
#  'https://www.udemy.com/course/mobile-app-development-for-beginners-android-and-apple/',
#  'https://www.udemy.com/course/apple-tv/',
#  'https://www.udemy.com/course/android-dependencies-bootcamp/',
#  'https://www.udemy.com/course/android-project-base-app-development-course-build-real-app/',
#  'https://www.udemy.com/course/java-android-complete-guide/',
#  'https://www.udemy.com/course/android-app-development-mobile-app-development-java/',
#  'https://www.udemy.com/course/swiftui-development-bootcamp-complete-ios-app-development/',
#  'https://www.udemy.com/course/app-development-tutorial-for-building-apps-for-businesses/',
#  'https://www.udemy.com/course/machine-learning-for-android-app-development-using-ml-kit/',
#  'https://www.udemy.com/course/how-to-make-an-iphone-app-through-outsourcing/',
#  'https://www.udemy.com/course/learn-android-programming-by-example/',
#  'https://www.udemy.com/course/business-app-development-in-dynamics-365-for-non-programmers/',
#  'https://www.udemy.com/course/learn-app-development-with-docker/',
#  'https://www.udemy.com/course/complete-unity-and-android-development-build-games-and-apps/',
#  'https://www.udemy.com/course/kotlin-for-android-development-development/',
#  'https://www.udemy.com/course/beginner-introduction-to-mobile-app-development-with-xamarin/',
#  'https://www.udemy.com/course/learn-to-publish-your-ios-apps-for-free/',
#  'https://www.udemy.com/course/advanced-app-development-and-design-course-for-ios-and-android/',
#  'https://www.udemy.com/course/i-want-to-create-an-app-but-dont-know-where-to-start/',
#  'https://www.udemy.com/course/learn-android/',
#  'https://www.udemy.com/course/python-django-web-development-to-do-app/',
#  'https://www.udemy.com/course/oracle-apex-web-app-development/',
#  'https://www.udemy.com/course/build-real-android-apps-android-app-development-with-java/',
#  'https://www.udemy.com/course/full-stack-web-and-multiplatform-mobile-app-development/',
#  'https://www.udemy.com/course/android-app-development-course/',
#  'https://www.udemy.com/course/android-apps-development-using-java-and-kotlin/',
#  'https://www.udemy.com/course/android-app-firebase-authentication-realtime-database-fcm-crashlytics/',
#  'https://www.udemy.com/course/ios-inapp-purchase/',
#  'https://www.udemy.com/course/create-stunning-apps-without-coding/',
#  'https://www.udemy.com/course/android-app-development-making-your-first-app-with-eclipse/',
#  'https://www.udemy.com/course/decentralized-app-development-with-blockchain-novice-to-pro/',
#  'https://www.udemy.com/course/quick-guide-to-ios-app-development-novice-to-pro-4-in-1/',
#  'https://www.udemy.com/course/mobile-phone-development/',
#  'https://www.udemy.com/course/ios-swift-beginner/',
#  'https://www.udemy.com/course/java-enterprise-application-development-with-java-ee-8/',
#  'https://www.udemy.com/course/ios-7-development-adding-push-notification-to-ios-apps/',
#  'https://www.udemy.com/course/mobile-app-entrepreneur-a-practical-lessons/',
#  'https://www.udemy.com/course/unity-3d-android-game-development-/',
#  'https://www.udemy.com/course/android-app-development-course-build-tds-app-using-firebase/',
#  'https://www.udemy.com/course/a-practical-guide-to-app-development-with-scala/',
#  'https://www.udemy.com/course/flutter-app-development-for-beginners/',
#  'https://www.udemy.com/course/android-app-development-for-beginners/',
#  'https://www.udemy.com/course/create-awesome-apps-with-flutter/',
#  'https://www.udemy.com/course/how-to-make-a-freaking-iphone-app-ios-10-swift-3-xcode-8/',
#  'https://www.udemy.com/course/android-app-development-with-rest-api-creation-integration/',
#  'https://www.udemy.com/course/configuringsharepoint2013server/',
#  'https://www.udemy.com/course/app-development-with-asp-net-core-mvc/',
#  'https://www.udemy.com/course/android-app-development-essential-training/',
#  'https://www.udemy.com/course/android-office-task-management-app-using-firebasereal-app/',
#  'https://www.udemy.com/course/the-complete-android-10-developer-course-mastering-android/',
#  'https://www.udemy.com/course/dart-flutter-the-complete-mobile-apps-development-course/',
#  'https://www.udemy.com/course/android-development-course-learn-android-oreo-from-scratch/',
#  'https://www.udemy.com/course/windows-iot/',
#  'https://www.udemy.com/course/aws-serverless-app-development-with-aws-3-in-1/',
#  'https://www.udemy.com/course/learn-android-the-easy-way-build-a-real-app/',
#  'https://www.udemy.com/course/learn-react-native-cross-platfrom/',
#  'https://www.udemy.com/course/complete-android-app-development-course-without-coding/',
#  'https://www.udemy.com/course/learn-full-swift-course-xcode-ios-programming/',
#  'https://www.udemy.com/course/apple-watch-app-development-for-beginners/',
#  'https://www.udemy.com/course/build-your-first-ios-app-in-swift/',
#  'https://www.udemy.com/course/unit-testing-ios-mobile-app/',
#  'https://www.udemy.com/course/android-daily-shopping-list-app-using-firebaseproject-base/',
#  'https://www.udemy.com/course/modern-app-development-with-c-8-and-net-core-30/',
#  'https://www.udemy.com/course/cocos_2d/',
#  'https://www.udemy.com/course/integrate-ios-apps-with-icloud/',
#  'https://www.udemy.com/course/full-stack-app-development-with-spring-5-and-angular-3-in-1/',
#  'https://www.udemy.com/course/java-enterprise-app-development-with-java-9-4-in-1/',
#  'https://www.udemy.com/course/introduction-to-android-development-for-beginners/',
#  'https://www.udemy.com/course/serverless-apps-development-with-azure-functions-and-nodejs/',
#  'https://www.udemy.com/course/the-complete-android-developer-course-from-zero-to-hero/',
#  'https://www.udemy.com/course/progressive-web-app-development-a-complete-guide-2-in-1/',
#  'https://www.udemy.com/course/android-p-with-machine-learning-apps/',
#  'https://www.udemy.com/course/ios-12-learn-to-code/',
#  'https://www.udemy.com/course/kotlin-android-developer-masterclass/',
#  'https://www.udemy.com/course/ios11swift4todolist/',
#  'https://www.udemy.com/course/complete-ios-10-design-and-development-bootcamp/',
#  'https://www.udemy.com/course/learn-to-build-a-professional-app-in-android/',
#  'https://www.udemy.com/course/learning-path-laravel-modern-app-development-with-laravel/',
#  'https://www.udemy.com/course/hands-on-app-development-with-ionic/',
#  'https://www.udemy.com/course/make-social-networking-app-like-instagram-kotlin-firebase/',
#  'https://www.udemy.com/course/the-android-developers-journey/',
#  'https://www.udemy.com/course/whatsapp-stickers-app-development-in-android-studio/',
#  'https://www.udemy.com/course/meteor-full-stack-javascript-mongodb-app-development/',
#  'https://www.udemy.com/course/how-to-make-a-freaking-iphone-app-ios-11-and-swift-4-xcode-9/',
#  'https://www.udemy.com/course/learning-path-electron-app-development-with-electron/',
#  'https://www.udemy.com/course/swift-development/',
#  'https://www.udemy.com/course/blockchain-development-convert-an-app-to-a-dapp/',
#  'https://www.udemy.com/course/the-app-developer-bootcamp/',
#  'https://www.udemy.com/course/beginners-swift-programming-for-ios-development/',
#  'https://www.udemy.com/course/the-complete-windows-10-c-course-and-build-2-apps/',
#  'https://www.udemy.com/course/rxjavarxandroid-bootcamp-reactivex-for-android-developers/',
#  'https://www.udemy.com/course/how-to-make-app-games-from-start-to-finish/',
#  'https://www.udemy.com/course/the-complete-android-tutorial-for-beginners/',
#  'https://www.udemy.com/course/intermediate-ios-11-complex-and-advanced-iphone-apps/',
#  'https://www.udemy.com/course/pirate-bay-ios-swift-3-development-app-only/',
#  'https://www.udemy.com/course/build-3-web-applications-in-90-minutes/',
#  'https://www.udemy.com/course/flutter-web-development-course-build-complete-flutterweb-app/',
#  'https://www.udemy.com/course/the-complete-web-developer-course-2/',
#  'https://www.udemy.com/course/ios10developer/',
#  'https://www.udemy.com/course/ios-sdk-course/',
#  'https://www.udemy.com/course/build-an-advance-android-app/',
#  'https://www.udemy.com/course/android-app-development-for-complete-beginners/',
#  'https://www.udemy.com/course/introduction-to-android-development-with-kotlin/',
#  'https://www.udemy.com/course/swift-starter-kit/',
#  'https://www.udemy.com/course/introduction-to-app-development-game-development/',
#  'https://www.udemy.com/course/android-n-professional-android-n-app-development-2-in-1/',
#  'https://www.udemy.com/course/ruby-on-rails-to-do-list-app/']

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time
DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)

what_to_learn=[]
for i in list(Data.Links):
    print(i)
    driver.get(i)
    try:
        l=driver.find_element_by_class_name('unstyled-list.udlite-block-list.what-you-will-learn--objectives-list--2cWZN').text
        what_to_learn.append(l)
    except:
        what_to_learn.append('Not Available')
# Out:
# https://www.udemy.com/course/ios-13-app-development-bootcamp/
# https://www.udemy.com/course/ios11-app-development-bootcamp/
# https://www.udemy.com/course/android-oreo-kotlin-app-masterclass/
# https://www.udemy.com/course/the-complete-android-oreo-developer-course/
# https://www.udemy.com/course/android-tutorial-for-beginners/
# https://www.udemy.com/course/complete-android-n-developer-course/
# https://www.udemy.com/course/flutter-dart-the-complete-flutter-app-development-course/
# https://www.udemy.com/course/master-android-7-nougat-java-app-development-step-by-step/
# https://www.udemy.com/course/androidappcourse/
# https://www.udemy.com/course/mobile-app-development-with-phonegap/
# https://www.udemy.com/course/android-app-development-with-java/
# https://www.udemy.com/course/swiftui-masterclass-course-ios-development-with-swift/
# https://www.udemy.com/course/stateoftheartandroid/
# https://www.udemy.com/course/android-app-development-using-kotlin/
# https://www.udemy.com/course/the-complete-flutter-app-development-course-for-android-ios/
# https://www.udemy.com/course/complete-android-developer-course/
# https://www.udemy.com/course/to-do-app-clean-architecture-android-development-kotlin/
# https://www.udemy.com/course/learn-android-app-development-from-scratch-with-java/
# https://www.udemy.com/course/androidforbeginners/
# https://www.udemy.com/course/buildit-coding-a-published-android-app-in-real-time/
# https://www.udemy.com/course/the-android-development-bootcamp-2019/
# https://www.udemy.com/course/testing-ios-apps-behavior-driven-development-using-swift/
# https://www.udemy.com/course/the-complete-android-developer-bootcamp/
# https://www.udemy.com/course/ios-12-app-development-bootcamp/
# https://www.udemy.com/course/bucketlist-1-create-an-app-and-put-it-on-your-own-iphone/
# https://www.udemy.com/course/android-app-development-for-beginner/
# https://www.udemy.com/course/learning-path-android-test-driven-android-app-development/
# https://www.udemy.com/course/mobile-app-development-with-android-2015/
# https://www.udemy.com/course/ios-development-create-4-quiz-apps-with-swift-3-ios-10/
# https://www.udemy.com/course/intro-programming-and-app-development/
# https://www.udemy.com/course/android-p-kotlin-complete-android-app-development-bootcamp/
# https://www.udemy.com/course/intermediate-mobile-app-development-swift-3-iphone-ios10/
# https://www.udemy.com/course/codekul-android-online-course-training/
# https://www.udemy.com/course/ios-9-app-development-for-beginners/
# https://www.udemy.com/course/javaandroidapp/
# https://www.udemy.com/course/devslopes-ios10/
# https://www.udemy.com/course/shopify-app-development/
# https://www.udemy.com/course/android-development-make-apps-without-coding-or-experience/
# https://www.udemy.com/course/mobile-app-development-make-ios-and-android-apps-without-code/
# https://www.udemy.com/course/android-app-development-create-a-spotify-clone/
# https://www.udemy.com/course/how-to-create-an-app/
# https://www.udemy.com/course/ios-development-crash-course/
# https://www.udemy.com/course/the-complete-android-development-bootcamp-java-and-kotlin/
# https://www.udemy.com/course/make-me-an-iphone-app-developer-beginner-series/
# https://www.udemy.com/course/complete-flutter-development/
# https://www.udemy.com/course/the-complete-ios-11-course/
# https://www.udemy.com/course/android-app-development-course-build-5-real-android-app/
# https://www.udemy.com/course/ios-8-app/
# https://www.udemy.com/course/ios-app-development-for-complete-and-utter-coding-beginners/
# https://www.udemy.com/course/ios-development-app-monetization-for-swift-3-ios-10/
# https://www.udemy.com/course/android-kotlin-developer/
# https://www.udemy.com/course/the-complete-guide-to-running-a-mobile-app-dev-business/
# https://www.udemy.com/course/hybrid-mobile-app-development-with-ionic/
# https://www.udemy.com/course/how-to-use-git-branches-to-speed-up-android-app-development/
# https://www.udemy.com/course/real-world-ios-app-in-10-days/
# https://www.udemy.com/course/social-networking-android-app-development-from-scratch/
# https://www.udemy.com/course/xamarin-android-a-master-guide-to-mobile-app-development/
# https://www.udemy.com/course/learning-app-development-in-ios-8/
# https://www.udemy.com/course/android-q-app-development-with-kotlin-beginner-to-advanced/
# https://www.udemy.com/course/app-design-uiux-plus-ios-development/
# https://www.udemy.com/course/flutter-mobile-development/
# https://www.udemy.com/course/complete-ios-10-developer-course/
# https://www.udemy.com/course/windows-phone-mobile-app-development/
# https://www.udemy.com/course/android-app-development-in-3-days-1000000-downloads/
# https://www.udemy.com/course/learn-unity-game-development-android-app-development/
# https://www.udemy.com/course/mobile-app-development-with-titanium-studio-by-jason-foster/
# https://www.udemy.com/course/learn-android-app-development-using-java-from-scratch/
# https://www.udemy.com/course/android-app-development-masterclass/
# https://www.udemy.com/course/android_development_for_beginners/
# https://www.udemy.com/course/learn-mobile-app-deveopment-with-ionic-framework/
# https://www.udemy.com/course/android-app-development-course-with-android-studio/
# https://www.udemy.com/course/mixed-language-app-development-with-objective-c-and-swift/
# https://www.udemy.com/course/creatio-low-code-app-development/
# https://www.udemy.com/course/android-and-apple-app-development-beginner-to-pro/
# https://www.udemy.com/course/how-to-make-an-android-app-without-knowing-development/
# https://www.udemy.com/course/learning-android-apps-development-from-scratch/
# https://www.udemy.com/course/create-a-calculator-web-app-with-javascript-html-css/
# https://www.udemy.com/course/learn-apples-ios-app-development-with-swift-from-scratch/
# https://www.udemy.com/course/android-development-course-build-topnote-app-using-firebase/
# https://www.udemy.com/course/sisoft-android-app-development-advance/
# https://www.udemy.com/course/xamarin-ios-the-master-guide/
# https://www.udemy.com/course/ios-app-development-with-corona-sdk-mobile-apps-made-easy/
# https://www.udemy.com/course/for-kids-creating-iphone-apps/
# https://www.udemy.com/course/tableviews/
# https://www.udemy.com/course/create-android-apps-in-minutes/
# https://www.udemy.com/course/mobile-app-from-development-to-deployment-ionic-4/
# https://www.udemy.com/course/build-mobile-app-without-coding-masterclass-level-101/
# https://www.udemy.com/course/cross-platform-desktop-app-development-windows-mac-linux/
# https://www.udemy.com/course/android-development-android-app-development-from-scratch/
# https://www.udemy.com/course/android-app-development-build-your-first-app/
# https://www.udemy.com/course/become-a-pro-ios-developer-in-less-than-5-hours/
# https://www.udemy.com/course/android-app-development-easy-and-quick-programming/
# https://www.udemy.com/course/android-app-development-with-kotlin/
# https://www.udemy.com/course/mobile-app-development-for-beginners-android-and-apple/
# https://www.udemy.com/course/apple-tv/
# https://www.udemy.com/course/android-dependencies-bootcamp/
# https://www.udemy.com/course/android-project-base-app-development-course-build-real-app/
# https://www.udemy.com/course/java-android-complete-guide/
# https://www.udemy.com/course/android-app-development-mobile-app-development-java/
# https://www.udemy.com/course/swiftui-development-bootcamp-complete-ios-app-development/
# https://www.udemy.com/course/app-development-tutorial-for-building-apps-for-businesses/
# https://www.udemy.com/course/machine-learning-for-android-app-development-using-ml-kit/
# https://www.udemy.com/course/how-to-make-an-iphone-app-through-outsourcing/
# https://www.udemy.com/course/learn-android-programming-by-example/
# https://www.udemy.com/course/business-app-development-in-dynamics-365-for-non-programmers/
# https://www.udemy.com/course/learn-app-development-with-docker/
# https://www.udemy.com/course/complete-unity-and-android-development-build-games-and-apps/
# https://www.udemy.com/course/kotlin-for-android-development-development/
# https://www.udemy.com/course/beginner-introduction-to-mobile-app-development-with-xamarin/
# https://www.udemy.com/course/learn-to-publish-your-ios-apps-for-free/
# https://www.udemy.com/course/advanced-app-development-and-design-course-for-ios-and-android/
# https://www.udemy.com/course/i-want-to-create-an-app-but-dont-know-where-to-start/
# https://www.udemy.com/course/learn-android/
# https://www.udemy.com/course/python-django-web-development-to-do-app/
# https://www.udemy.com/course/oracle-apex-web-app-development/
# https://www.udemy.com/course/build-real-android-apps-android-app-development-with-java/
# https://www.udemy.com/course/full-stack-web-and-multiplatform-mobile-app-development/
# https://www.udemy.com/course/android-app-development-course/
# https://www.udemy.com/course/android-apps-development-using-java-and-kotlin/
# https://www.udemy.com/course/android-app-firebase-authentication-realtime-database-fcm-crashlytics/
# https://www.udemy.com/course/ios-inapp-purchase/
# https://www.udemy.com/course/create-stunning-apps-without-coding/
# https://www.udemy.com/course/android-app-development-making-your-first-app-with-eclipse/
# https://www.udemy.com/course/decentralized-app-development-with-blockchain-novice-to-pro/
# https://www.udemy.com/course/quick-guide-to-ios-app-development-novice-to-pro-4-in-1/
# https://www.udemy.com/course/mobile-phone-development/
# https://www.udemy.com/course/ios-swift-beginner/
# https://www.udemy.com/course/java-enterprise-application-development-with-java-ee-8/
# https://www.udemy.com/course/ios-7-development-adding-push-notification-to-ios-apps/
# https://www.udemy.com/course/mobile-app-entrepreneur-a-practical-lessons/
# https://www.udemy.com/course/unity-3d-android-game-development-/
# https://www.udemy.com/course/android-app-development-course-build-tds-app-using-firebase/
# https://www.udemy.com/course/a-practical-guide-to-app-development-with-scala/
# https://www.udemy.com/course/flutter-app-development-for-beginners/
# https://www.udemy.com/course/android-app-development-for-beginners/
# https://www.udemy.com/course/create-awesome-apps-with-flutter/
# https://www.udemy.com/course/how-to-make-a-freaking-iphone-app-ios-10-swift-3-xcode-8/
# https://www.udemy.com/course/android-app-development-with-rest-api-creation-integration/
# https://www.udemy.com/course/configuringsharepoint2013server/
# https://www.udemy.com/course/app-development-with-asp-net-core-mvc/
# https://www.udemy.com/course/android-app-development-essential-training/
# https://www.udemy.com/course/android-office-task-management-app-using-firebasereal-app/
# https://www.udemy.com/course/the-complete-android-10-developer-course-mastering-android/
# https://www.udemy.com/course/dart-flutter-the-complete-mobile-apps-development-course/
# https://www.udemy.com/course/android-development-course-learn-android-oreo-from-scratch/
# https://www.udemy.com/course/windows-iot/
# https://www.udemy.com/course/aws-serverless-app-development-with-aws-3-in-1/
# https://www.udemy.com/course/learn-android-the-easy-way-build-a-real-app/
# https://www.udemy.com/course/learn-react-native-cross-platfrom/
# https://www.udemy.com/course/complete-android-app-development-course-without-coding/
# https://www.udemy.com/course/learn-full-swift-course-xcode-ios-programming/
# https://www.udemy.com/course/apple-watch-app-development-for-beginners/
# https://www.udemy.com/course/build-your-first-ios-app-in-swift/
# https://www.udemy.com/course/unit-testing-ios-mobile-app/
# https://www.udemy.com/course/android-daily-shopping-list-app-using-firebaseproject-base/
# https://www.udemy.com/course/modern-app-development-with-c-8-and-net-core-30/
# https://www.udemy.com/course/cocos_2d/
# https://www.udemy.com/course/integrate-ios-apps-with-icloud/
# https://www.udemy.com/course/full-stack-app-development-with-spring-5-and-angular-3-in-1/
# https://www.udemy.com/course/java-enterprise-app-development-with-java-9-4-in-1/
# https://www.udemy.com/course/introduction-to-android-development-for-beginners/
# https://www.udemy.com/course/serverless-apps-development-with-azure-functions-and-nodejs/
# https://www.udemy.com/course/the-complete-android-developer-course-from-zero-to-hero/
# https://www.udemy.com/course/progressive-web-app-development-a-complete-guide-2-in-1/
# https://www.udemy.com/course/android-p-with-machine-learning-apps/
# https://www.udemy.com/course/ios-12-learn-to-code/
# https://www.udemy.com/course/kotlin-android-developer-masterclass/
# https://www.udemy.com/course/ios11swift4todolist/
# https://www.udemy.com/course/complete-ios-10-design-and-development-bootcamp/
# https://www.udemy.com/course/learn-to-build-a-professional-app-in-android/
# https://www.udemy.com/course/learning-path-laravel-modern-app-development-with-laravel/
# https://www.udemy.com/course/hands-on-app-development-with-ionic/
# https://www.udemy.com/course/make-social-networking-app-like-instagram-kotlin-firebase/
# https://www.udemy.com/course/the-android-developers-journey/
# https://www.udemy.com/course/whatsapp-stickers-app-development-in-android-studio/
# https://www.udemy.com/course/meteor-full-stack-javascript-mongodb-app-development/
# https://www.udemy.com/course/how-to-make-a-freaking-iphone-app-ios-11-and-swift-4-xcode-9/
# https://www.udemy.com/course/learning-path-electron-app-development-with-electron/
# https://www.udemy.com/course/swift-development/
# https://www.udemy.com/course/blockchain-development-convert-an-app-to-a-dapp/
# https://www.udemy.com/course/the-app-developer-bootcamp/
# https://www.udemy.com/course/beginners-swift-programming-for-ios-development/
# https://www.udemy.com/course/the-complete-windows-10-c-course-and-build-2-apps/
# https://www.udemy.com/course/rxjavarxandroid-bootcamp-reactivex-for-android-developers/
# https://www.udemy.com/course/how-to-make-app-games-from-start-to-finish/
# https://www.udemy.com/course/the-complete-android-tutorial-for-beginners/
# https://www.udemy.com/course/intermediate-ios-11-complex-and-advanced-iphone-apps/
# https://www.udemy.com/course/pirate-bay-ios-swift-3-development-app-only/
# https://www.udemy.com/course/build-3-web-applications-in-90-minutes/
# https://www.udemy.com/course/flutter-web-development-course-build-complete-flutterweb-app/
# https://www.udemy.com/course/the-complete-web-developer-course-2/
# https://www.udemy.com/course/ios10developer/
# https://www.udemy.com/course/ios-sdk-course/
# https://www.udemy.com/course/build-an-advance-android-app/
# https://www.udemy.com/course/android-app-development-for-complete-beginners/
# https://www.udemy.com/course/introduction-to-android-development-with-kotlin/
# https://www.udemy.com/course/swift-starter-kit/
# https://www.udemy.com/course/introduction-to-app-development-game-development/
# https://www.udemy.com/course/android-n-professional-android-n-app-development-2-in-1/
# https://www.udemy.com/course/ruby-on-rails-to-do-list-app/

# %%
len(what_to_learn)
# Out:
# 200

# %%
b=[]
for i in what_to_learn:
    c=[]
    c.append(i)
    b.append(c)

# %%
what=pd.Series(b,name='Description')

# %%
what
# Out:
# 0      [Be able to build any app you want\nStart your...
# 1      [Be able to build any app you want\nCraft a po...
# 2      [Learn the core Android app development and Ko...
# 3      [Make pretty much any Android app you like (yo...
# 4      [Build Your First Mobile App\nBuild Real-world...
#                              ...
# 195    [To understand the basics of Android developme...
# 196    [Swift 5 Programming\niOS 14 App Development\n...
# 197    [Basics of App Development\nBasics of Game Dev...
# 198    [Get to brace with latest techniques in androi...
# 199    [Build Web Apps With Ruby On Rails\nBuild Your...
# Name: Description, Length: 200, dtype: object

# %%
temp=pd.concat([Data,what],axis=1)

# %%
temp
temp.to_excel('App_dev_desc.xlsx')

# %%
print(Data['Links'])
Data.to_excel('App_dev_links.xlsx')
# Out:
# 0      https://www.udemy.com/course/ios-13-app-develo...
# 1      https://www.udemy.com/course/ios11-app-develop...
# 2      https://www.udemy.com/course/android-oreo-kotl...
# 3      https://www.udemy.com/course/the-complete-andr...
# 4      https://www.udemy.com/course/android-tutorial-...
#                              ...
# 195    https://www.udemy.com/course/introduction-to-a...
# 196      https://www.udemy.com/course/swift-starter-kit/
# 197    https://www.udemy.com/course/introduction-to-a...
# 198    https://www.udemy.com/course/android-n-profess...
# 199    https://www.udemy.com/course/ruby-on-rails-to-...
# Name: Links, Length: 200, dtype: object

# %%
l=driver.find_element_by_class_name('unstyled-list.udlite-block-list.what-you-will-learn--objectives-list--2cWZN')

# %%
l.text
# Out:
# 'Be able to build any app you want\nCraft a portfolio of apps to apply for junior developer jobs\nBuild fully-fledged apps for your startup or business\nWork as a freelance iOS developer\nMaster creating Augmented Reality apps using Apple’s new ARKit\nCreate your first Machine Learning app using Apple’s new CoreML'

# %%
ai_courses=pd.read_csv('WebDevCourses.csv')

# %%
ai_courses
# Out:
#                                                  Title  \
# 0                           The Web Developer Bootcamp
# 1          Angular - The Complete Guide (2020 Edition)
# 2           The Complete 2020 Web Development Bootcamp
# 3    The Complete JavaScript Course 2020: Build Rea...
# 4                The Complete Web Developer Course 2.0
# ..                                                 ...
# 155               Learn Nodejs by building 12 projects
# 156  Django 3 - Full Stack Websites with Python Web...
# 157          Complete guide to ASP.NET Core MVC (v3.1)
# 158  Learn OAuth 2.0 - Get started as an API Securi...
# 159  Learn Bootstrap By Building Projects - Include...
#
#                                               HeadLine  \
# 0    The only course you need to learn web developm...
# 1    Master Angular 10 (formerly "Angular 2") and b...
# 2    Become a full-stack web developer with just on...
# 3    Master JavaScript with the most complete cours...
# 4    Learn Web Development by building 25 websites ...
# ..                                                 ...
# 155  Become an Expert Nodejs Developer While Buildi...
# 156  Build 3 stunning websites, learn Back and Fron...
# 157  Build real world application using ASP.NET Cor...
# 158  Just imagine what could happen to YOUR profess...
# 159  Master Responsive Web Development Using Bootst...
#
#                                     Instructors  Rating           Tags  \
# 0                                   Colt Steele     4.7  Not Available
# 1                      Maximilian Schwarzmüller     4.6     Bestseller
# 2                                 Dr. Angela Yu     4.7     Bestseller
# 3                             Jonas Schmedtmann     4.6     Bestseller
# 4       Rob Percival, Codestars by Rob Percival     4.5  Not Available
# ..                                          ...     ...            ...
# 155  Eduonix Learning Solutions, Eduonix-Tech .     4.2  Not Available
# 156                                 Nick Walter     4.6  Not Available
# 157                               Bhrugen Patel     4.4  Not Available
# 158                              Matthias Biehl     4.2     Bestseller
# 159  Eduonix Learning Solutions, Eduonix-Tech .     3.8  Not Available
#
#        Reviews                                     AddInfo
# 0    -1,82,487    47 total hours\n405 lectures\nAll Levels
# 1    -1,29,516  33.5 total hours\n455 lectures\nAll Levels
# 2      -86,729    54 total hours\n469 lectures\nAll Levels
# 3      -83,060    28 total hours\n166 lectures\nAll Levels
# 4      -63,041  30.5 total hours\n308 lectures\nAll Levels
# ..         ...                                         ...
# 155     -1,839   12.5 total hours\n72 lectures\nAll Levels
# 156     -1,777      8.5 total hours\n78 lectures\nBeginner
# 157     -1,771  23 total hours\n358 lectures\nIntermediate
# 158     -1,766      4 total hours\n49 lectures\nAll Levels
# 159     -1,751    31 total hours\n231 lectures\nAll Levels
#
# [160 rows x 7 columns]

# %%
ai_courses['Title'].nunique()
# Out:
# 75

# %%
Data.drop_duplicates(['Title'],keep='first',inplace=True)

# %%
ai_courses
# Out:
#     Index                                              Title  \
# 0       0  Artificial Intelligence A-Z™: Learn How To Bui...
# 1       1  Artificial Intelligence: Reinforcement Learnin...
# 2       2  Machine Learning, Data Science and Deep Learni...
# 3       3  Artificial Intelligence 2018: Build the Most P...
# 4       4  Tensorflow Deep Learning - Data Science in Python
# ..    ...                                                ...
# 87     87  Artificial Intelligence for Civil Engineers: P...
# 88     88  Advanced Artificial Intelligence in Digital Ma...
# 89     89                Artificial Intelligence Terminology
# 90     90  Easy Filmmaking: Artificial Intelligence in Fi...
# 91     91  Learn To Gain Writing Skills Using Artificial ...
#
#                                              HeadLine  \
# 0   Combine the power of Data Science, Machine Lea...
# 1   Complete guide to Reinforcement Learning, with...
# 2   Complete hands-on machine learning tutorial wi...
# 3                                       Not Available
# 4                                       Not Available
# ..                                                ...
# 87  Welcome to the Future of Civil Engineering pow...
# 88  Learn Mind-Blowing Artificial Intelligence (AI...
# 89                     How much do you know about AI?
# 90  Make outstanding films and videos by learning ...
# 91           Towards Compiling a WOW Content likewise
#
#                                           Instructors  Rating           Tags  \
# 0   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.3     Bestseller
# 1          Lazy Programmer Team, Lazy Programmer Inc.     4.5     Bestseller
# 2          Sundog Education by Frank Kane, Frank Kane     4.5  Not Available
# 3   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.5  Not Available
# 4                                       Minerva Singh     4.7  Not Available
# ..                                                ...     ...            ...
# 87             Srinidhi Ranganathan, Saranya Srinidhi     3.9  Not Available
# 88             Srinidhi Ranganathan, Saranya Srinidhi     4.1  Not Available
# 89                                 Andrew Magdy Kamal     3.8  Not Available
# 90            Paul Jenkins, Paul Jenkins' Brilliantio     4.1  Not Available
# 91                               Dr. Dheeraj Mehrotra     4.1  Not Available
#
#     Reviews                                       AddInfo
# 0   -16,292    16.5 total hours\n120 lectures\nAll Levels
# 1    -7,742  12.5 total hours\n107 lectures\nIntermediate
# 2   -22,508      14.5 total hours\n111 lectures\nBeginner
# 3      -800                                 Not Available
# 4      -155                                 Not Available
# ..      ...                                           ...
# 87     -207            1 total hour\n9 lectures\nBeginner
# 88      -75          2 total hours\n11 lectures\nBeginner
# 89       -7                    82 questions\nIntermediate
# 90      -29        2 total hours\n14 lectures\nAll Levels
# 91      -15         1 total hour\n12 lectures\nAll Levels
#
# [75 rows x 8 columns]

# %%
ai_courses.reset_index()
# Out:
#     index  Index                                              Title  \
# 0       0      0  Artificial Intelligence A-Z™: Learn How To Bui...
# 1       1      1  Artificial Intelligence: Reinforcement Learnin...
# 2       2      2  Machine Learning, Data Science and Deep Learni...
# 3       3      3  Artificial Intelligence 2018: Build the Most P...
# 4       4      4  Tensorflow Deep Learning - Data Science in Python
# ..    ...    ...                                                ...
# 70     87     87  Artificial Intelligence for Civil Engineers: P...
# 71     88     88  Advanced Artificial Intelligence in Digital Ma...
# 72     89     89                Artificial Intelligence Terminology
# 73     90     90  Easy Filmmaking: Artificial Intelligence in Fi...
# 74     91     91  Learn To Gain Writing Skills Using Artificial ...
#
#                                              HeadLine  \
# 0   Combine the power of Data Science, Machine Lea...
# 1   Complete guide to Reinforcement Learning, with...
# 2   Complete hands-on machine learning tutorial wi...
# 3                                       Not Available
# 4                                       Not Available
# ..                                                ...
# 70  Welcome to the Future of Civil Engineering pow...
# 71  Learn Mind-Blowing Artificial Intelligence (AI...
# 72                     How much do you know about AI?
# 73  Make outstanding films and videos by learning ...
# 74           Towards Compiling a WOW Content likewise
#
#                                           Instructors  Rating           Tags  \
# 0   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.3     Bestseller
# 1          Lazy Programmer Team, Lazy Programmer Inc.     4.5     Bestseller
# 2          Sundog Education by Frank Kane, Frank Kane     4.5  Not Available
# 3   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.5  Not Available
# 4                                       Minerva Singh     4.7  Not Available
# ..                                                ...     ...            ...
# 70             Srinidhi Ranganathan, Saranya Srinidhi     3.9  Not Available
# 71             Srinidhi Ranganathan, Saranya Srinidhi     4.1  Not Available
# 72                                 Andrew Magdy Kamal     3.8  Not Available
# 73            Paul Jenkins, Paul Jenkins' Brilliantio     4.1  Not Available
# 74                               Dr. Dheeraj Mehrotra     4.1  Not Available
#
#     Reviews                                       AddInfo
# 0   -16,292    16.5 total hours\n120 lectures\nAll Levels
# 1    -7,742  12.5 total hours\n107 lectures\nIntermediate
# 2   -22,508      14.5 total hours\n111 lectures\nBeginner
# 3      -800                                 Not Available
# 4      -155                                 Not Available
# ..      ...                                           ...
# 70     -207            1 total hour\n9 lectures\nBeginner
# 71      -75          2 total hours\n11 lectures\nBeginner
# 72       -7                    82 questions\nIntermediate
# 73      -29        2 total hours\n14 lectures\nAll Levels
# 74      -15         1 total hour\n12 lectures\nAll Levels
#
# [75 rows x 9 columns]

# %%
ai_courses
# Out:
#     Index                                              Title  \
# 0       0  Artificial Intelligence A-Z™: Learn How To Bui...
# 1       1  Artificial Intelligence: Reinforcement Learnin...
# 2       2  Machine Learning, Data Science and Deep Learni...
# 3       3  Artificial Intelligence 2018: Build the Most P...
# 4       4  Tensorflow Deep Learning - Data Science in Python
# ..    ...                                                ...
# 87     87  Artificial Intelligence for Civil Engineers: P...
# 88     88  Advanced Artificial Intelligence in Digital Ma...
# 89     89                Artificial Intelligence Terminology
# 90     90  Easy Filmmaking: Artificial Intelligence in Fi...
# 91     91  Learn To Gain Writing Skills Using Artificial ...
#
#                                              HeadLine  \
# 0   Combine the power of Data Science, Machine Lea...
# 1   Complete guide to Reinforcement Learning, with...
# 2   Complete hands-on machine learning tutorial wi...
# 3                                       Not Available
# 4                                       Not Available
# ..                                                ...
# 87  Welcome to the Future of Civil Engineering pow...
# 88  Learn Mind-Blowing Artificial Intelligence (AI...
# 89                     How much do you know about AI?
# 90  Make outstanding films and videos by learning ...
# 91           Towards Compiling a WOW Content likewise
#
#                                           Instructors  Rating           Tags  \
# 0   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.3     Bestseller
# 1          Lazy Programmer Team, Lazy Programmer Inc.     4.5     Bestseller
# 2          Sundog Education by Frank Kane, Frank Kane     4.5  Not Available
# 3   Hadelin de Ponteves, Kirill Eremenko, SuperDat...     4.5  Not Available
# 4                                       Minerva Singh     4.7  Not Available
# ..                                                ...     ...            ...
# 87             Srinidhi Ranganathan, Saranya Srinidhi     3.9  Not Available
# 88             Srinidhi Ranganathan, Saranya Srinidhi     4.1  Not Available
# 89                                 Andrew Magdy Kamal     3.8  Not Available
# 90            Paul Jenkins, Paul Jenkins' Brilliantio     4.1  Not Available
# 91                               Dr. Dheeraj Mehrotra     4.1  Not Available
#
#     Reviews                                       AddInfo
# 0   -16,292    16.5 total hours\n120 lectures\nAll Levels
# 1    -7,742  12.5 total hours\n107 lectures\nIntermediate
# 2   -22,508      14.5 total hours\n111 lectures\nBeginner
# 3      -800                                 Not Available
# 4      -155                                 Not Available
# ..      ...                                           ...
# 87     -207            1 total hour\n9 lectures\nBeginner
# 88      -75          2 total hours\n11 lectures\nBeginner
# 89       -7                    82 questions\nIntermediate
# 90      -29        2 total hours\n14 lectures\nAll Levels
# 91      -15         1 total hour\n12 lectures\nAll Levels
#
# [75 rows x 8 columns]

# %%
ai_courses.to_csv('AIcourses.csv')

# %%
Data.to_csv('appdevCourses.csv')

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-small udlite-btn-secondary udlite-heading-sm udlite-btn-icon udlite-btn-icon-small udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'App Development':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()
time.sleep(10)
block_=driver.find_elements_by_class_name('course-card--container--3w8Zm.course-card--large--1BVxY')

# %%
block_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="04a0b794-b9ce-4dbf-b4b5-05990daf8bb2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="6cec0b7c-3631-4a46-8af4-b711389ed2f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="88a62024-01e9-4e7b-adb9-34312acb130e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="f0b04ff4-12d5-42dc-b075-78d12df96d24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="e856f56a-cb19-4685-8eff-d362e5c77944")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="3a7ef48b-dc92-416f-b27a-dd07185a1442")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="9f7b5ed4-499f-46c8-a3dd-94980be63add")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="94e2c76e-0ce7-4375-a43b-44c1e18ad3bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="06c3bb8a-4ba6-438d-a5e3-d34834dec1d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="30d07d49-6f7d-4f55-9f09-a781c617bf78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="7046598f-1f2e-46bc-830d-19008bc30989")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="a05f60bd-dbdd-4231-86a1-e6fd48c35569")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="98894ba1-16d1-4766-8deb-88355107e8e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="9721f66f-a95e-4116-9996-f7958208b9b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="cc02dca7-333c-4fa1-a2b9-337a5216195c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="d5ec23ed-4818-451a-9bdb-d341da0b94d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="528df5cd-9f5a-4a64-b673-1e260d86e5c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="966d8e7c-32a8-43b8-893d-c82ba7e04781")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="bec56b49-8ddb-424b-9a6f-419d140e40c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="e680e41b-aa6a-4bfc-8a49-e2a4d8db1c79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="916f166a-535e-4e76-ae55-495a51753eb7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="c977fc81-aa62-4ccc-bd06-2579a44174e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e54f7fa5f14e7397bfc9ea99d4f1a6e7", element="69941118-8402-4208-915b-c6b1cfb21a8b")>]

# %%
print(block_[0].get_attribute('href'))
# Out:
# None

# %%
print(block_[0].text)
# Out:
# iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp
# From Beginner to iOS App Developer with Just One Course!
# Dr. Angela Yu
# Rating: 4.8 out of 5
# 4.8
# (51,565)
# 59.5 total hours
# 578 lectures
# All Levels
# Current price
# ₹490
# Original Price
# ₹8,640
# Bestseller

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

# %%
block_=driver.find_elements_by_class_name('udlite-custom-focus-visible.browse-course-card--link--3KIkQ')

# %%
block_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="56458760-d08c-4b14-936a-23b9a6aec7f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="7dd8808f-70cb-49ee-a128-6f4a47a0a9ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="43ef64e9-a33e-44ee-aff6-89ec5b95f7b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="552143ab-c218-4289-bbe2-52bf92fbd9f0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="f328120f-b9dc-4f22-9c94-8070c424ff4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="6e0ccb89-5ea1-4fd9-a7d2-972baff81e2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="cb30e6d7-b3cc-4ead-9201-30b3d884fce5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="b796b698-a404-4edf-b481-63a9c4f6cab0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="7c98384d-7135-4b9e-a29a-9571ab03ffb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="09973817-abd6-469c-a884-7c7eeb38b2e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="2ca68eb0-dc53-4085-8bbc-24d54044471d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="8ecbe10f-4073-4988-9570-1d44153e1fad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="943cc145-0550-4ecf-b8f6-6414b52f9148")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="c8e75afa-a218-4bce-8f4e-185f81d24b72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="c2cea135-87aa-406b-93fe-0624a90b4b69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="e534c2af-a747-4e03-8490-96e5d7b72d41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="3b24889d-dade-423e-af40-cc6396ac7cea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="9ab9e3a7-51c8-4bd7-960a-807d9b9fcdc0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="f9f85a6a-ce2a-4e1c-8a64-383ab75ed7cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="6a687368-0aaf-4936-868f-691b50bc6712")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="21bed66a-0115-4698-a677-58301d12cae3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="755ebcf1-43e6-42e8-8e81-71eedab60739")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="8de1596c-7a8c-4dbc-ae44-db65a32e43ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="b11835a6-c230-43d0-bff6-3dcfaa0563bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="6cda3407-882e-49a9-b797-7536000b7a25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="6047007a-c113-471b-903d-4f28a2a78c12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="ef3c3014-ea03-4ff9-90b1-23940c80a86d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="44e1585d-f854-40ac-a369-6067195d62da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="93de436b-201a-4a8d-884a-61b66a0c77b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="2497969b-6b83-49dc-9d2b-6ca5077537b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="513f2dd1edd602b60f89fa3d16aaa373", element="8c40ced6-b427-433b-bfa5-d8ef9b4fad26")>]

# %%
len(block_)
# Out:
# 31

# %%
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-medium udlite-btn-secondary udlite-btn-round udlite-heading-sm udlite-btn-icon udlite-btn-icon-medium udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'App Development':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()
time.sleep(10)
block_=driver.find_elements_by_class_name('course-card--container--3w8Zm.course-card--large--1BVxY')

time.sleep(3)

info=[]
for i in range(1):
    block_=driver.find_elements_by_class_name('course-card--container--3w8Zm.course-card--large--1BVxY')
    for j in block_:
            content=[]
            try:
                title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
                content.append(title.text)
            except:
                content.append('Not Available')
            try:
                tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
                content.append(tagline.text)
            except:
                content.append('Not Available')
            try:
                instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
                content.append(instructor.text)
            except:
                content.append('Not Available')
            try:
                rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
                content.append(rating.text)
            except:
                content.append('Not Available')
            try:
                bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
                content.append('Bestseller')
            except:
                content.append('Not Available')
            try:
                reviews=j.find_element_by_class_name('udlite-text-xs.course-card--reviews-text--12UpL')
                content.append(reviews.text)
            except:
                content.append('Not Available')
            try:
                otherinfo=j.find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')
                content.append(otherinfo.text)
            except:
                content.append('Not Available')
            try:
                otherinfo=j.find_element_by_class_name('udlite-custom-focus-visible.browse-course-card--link--3KIkQ')
                content.append(otherinfo.text)
            except:
                content.append('Not Available')
            info.append(content)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(4)
    driver.find_element_by_class_name(next_link).click()
    time.sleep(10)
    
driver.quit()

# %%
len(info)
# Out:
# 23

# %%
info
# Out:
# [['iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.8',
#   'Bestseller',
#   '(52,112)',
#   '59.5 total hours\n578 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 11 & Swift 4 - The Complete iOS App Development Bootcamp',
#   'Learn iOS 11 App Development From Beginning to End. Using Xcode 9 and Swift 4.',
#   'Dr. Angela Yu',
#   '4.7',
#   'Not Available',
#   '(31,305)',
#   '49.5 total hours\n478 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Masterclass using Kotlin',
#   'Learn Kotlin Android App Development And Become an Android Developer. Incl.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy, David Reidy",
#   '4.4',
#   'Not Available',
#   '(3,773)',
#   '59.5 total hours\n364 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(274)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['The Complete Android App Development',
#   'Learn how to make online games, and apps like Twitter, Pokémon ,Tic Tac Toy, and Find my phone using',
#   'Hussein Alrubaye',
#   '4.2',
#   'Not Available',
#   '(2,891)',
#   '22 total hours\n150 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android N Developer Course',
#   'Learn Android App Development with Android 7 Nougat by building real apps including Uber, Whatsapp and',
#   'Rob Percival, Marc Stock, Codestars by Rob Percival',
#   '4.4',
#   'Not Available',
#   '(27,038)',
#   '32.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['Flutter & Dart - The Complete Flutter App Development Course',
#   "Build Flutter iOS and Android Apps with a Single Codebase - Learn Google's Flutter Mobile Development",
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.5',
#   'Not Available',
#   '(3,845)',
#   '26 total hours\n358 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android Oreo Developer Course - Build 23 Apps!',
#   'Learn Android O App Development using Java & Kotlin - build real apps including Super Mario Run, Whatsapp',
#   'Rob Percival, Nick Walter, Codestars by Rob Percival',
#   '4.5',
#   'Bestseller',
#   '(13,919)',
#   '37.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Java Masterclass - Become an App Developer',
#   'Improve your career options by learning Android app Development.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy",
#   '4.5',
#   'Not Available',
#   '(8,689)',
#   '60.5 total hours\n338 lectures\nAll Levels',
#   'Not Available'],
#  ['Android O & Java - The Complete Android Development Bootcamp',
#   'Learn Android O app development from beginning to end.',
#   'Philipp Muellauer',
#   '4.5',
#   'Not Available',
#   '(6,953)',
#   '21 total hours\n289 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android App Development Masterclass: Build Apps',
#   'Create Real World Applications using Java and Become A Professional Android App Developer From Scratch',
#   'Meisam Mansourzadeh, Joe Parys',
#   '4.4',
#   'Not Available',
#   '(596)',
#   '39.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development with PhoneGap',
#   'Create Apps for iOS and Android with HTML5 and Javascript',
#   'Framework Television Inc.',
#   '4.4',
#   'Bestseller',
#   '(512)',
#   '5.5 total hours\n61 lectures\nIntermediate',
#   'Not Available'],
#  ['State of the Art Android App Development in Kotlin',
#   'Using Kotlin, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.7',
#   'Not Available',
#   '(223)',
#   '6.5 total hours\n51 lectures\nAll Levels',
#   'Not Available'],
#  ['SwiftUI Masterclass: iOS 14 App Development with Swift 5',
#   'The Complete iOS 14 App Development Course with SwiftUI 2 From Beginner to Advanced App Developer with',
#   'Robert Petras',
#   '4.5',
#   'Bestseller',
#   '(637)',
#   '20.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development using Kotlin',
#   'Develop Android apps in Kotlin and publish it to Play Store',
#   'Smartherd Developers',
#   '4.3',
#   'Not Available',
#   '(629)',
#   '3.5 total hours\n27 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Flutter App Development Course for Android, iOS',
#   'A Complete Guide to the Flutter Framework for building native iOS and Android apps with single code base',
#   'Smartherd Developers',
#   '4.1',
#   'Not Available',
#   '(1,152)',
#   '4.5 total hours\n33 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android & Java Developer Course - Build 21 Apps',
#   'Learn Android Development, Java & Android Studio from Scratch in 5 Weeks. Build a Diary App & more',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher, Fahd Sheraz',
#   '4.4',
#   'Not Available',
#   '(6,140)',
#   '34.5 total hours\n229 lectures\nAll Levels',
#   'Not Available'],
#  ['To-Do App & Clean Architecture -Android Development - Kotlin',
#   'Develop a Fully Functional To-Do app in Kotlin - ROOM, Navigation Component, LiveData, ViewModel, Data',
#   'Stefan Jovanovic',
#   '4.8',
#   'Not Available',
#   '(110)',
#   '4 total hours\n50 lectures\nIntermediate',
#   'Not Available'],
#  ['The complete Java Android App development Bootcamp 2020',
#   'Learn Android development fundamentals and start creating your own Android applications',
#   'Maid Rondić',
#   '4.4',
#   'Not Available',
#   '(178)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development For Beginners: Make a full app!',
#   'Become an App Developer!',
#   'Nick Marcenelle Perez',
#   '4.2',
#   'Not Available',
#   '(567)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development Bootcamp 2020 - Android 10 (Q)',
#   'Android App Development for complete beginners, learn Java & Kotlin, make real working apps, become an',
#   'Vin Norman',
#   '4.7',
#   'Not Available',
#   '(111)',
#   '17.5 total hours\n102 lectures\nAll Levels',
#   'Not Available']]

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-medium udlite-btn-secondary udlite-btn-round udlite-heading-sm udlite-btn-icon udlite-btn-icon-medium udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'App Development':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()
time.sleep(10)
block_=driver.find_elements_by_class_name('course-card--container--3w8Zm.course-card--large--1BVxY')

time.sleep(3)

info=[]
for i in range(10):
    block_=driver.find_elements_by_class_name('popper--popper--19faV.popper--popper-hover--4YJ5J')
    for j in block_:
            content=[]
            try:
                title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
                content.append(title.text)
            except:
                content.append('Not Available')
            try:
                tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
                content.append(tagline.text)
            except:
                content.append('Not Available')
            try:
                instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
                content.append(instructor.text)
            except:
                content.append('Not Available')
            try:
                rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
                content.append(rating.text)
            except:
                content.append('Not Available')
            try:
                bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
                content.append('Bestseller')
            except:
                content.append('Not Available')
            try:
                reviews=j.find_element_by_class_name('udlite-text-xs.course-card--reviews-text--12UpL')
                content.append(reviews.text)
            except:
                content.append('Not Available')
            try:
                otherinfo=j.find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')
                content.append(otherinfo.text)
            except:
                content.append('Not Available')
            try:
                otherinfo=j.find_element_by_class_name('')
                content.append(otherinfo.text)
            except:
                content.append('Not Available')
            
            info.append(content)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(4)
    driver.find_element_by_class_name(next_link).click()
    time.sleep(10)
    
driver.quit()

# %%
info
# Out:
# [['iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.8',
#   'Bestseller',
#   '(52,220)',
#   '59.5 total hours\n578 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 11 & Swift 4 - The Complete iOS App Development Bootcamp',
#   'Learn iOS 11 App Development From Beginning to End. Using Xcode 9 and Swift 4.',
#   'Dr. Angela Yu',
#   '4.7',
#   'Not Available',
#   '(31,308)',
#   '49.5 total hours\n478 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Masterclass using Kotlin',
#   'Learn Kotlin Android App Development And Become an Android Developer. Incl.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy, David Reidy",
#   '4.4',
#   'Not Available',
#   '(3,780)',
#   '59.5 total hours\n364 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['The Complete Android Oreo Developer Course - Build 23 Apps!',
#   'Learn Android O App Development using Java & Kotlin - build real apps including Super Mario Run, Whatsapp',
#   'Rob Percival, Nick Walter, Codestars by Rob Percival',
#   '4.4',
#   'Bestseller',
#   '(13,961)',
#   '37.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android App Development',
#   'Learn how to make online games, and apps like Twitter, Pokémon ,Tic Tac Toy, and Find my phone using',
#   'Hussein Alrubaye',
#   '4.2',
#   'Not Available',
#   '(2,891)',
#   '22 total hours\n150 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android N Developer Course',
#   'Learn Android App Development with Android 7 Nougat by building real apps including Uber, Whatsapp and',
#   'Rob Percival, Marc Stock, Codestars by Rob Percival',
#   '4.4',
#   'Not Available',
#   '(27,050)',
#   '32.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['Flutter & Dart - The Complete Flutter App Development Course',
#   "Build Flutter iOS and Android Apps with a Single Codebase: Learn Google's Flutter Mobile Development",
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.5',
#   'Not Available',
#   '(3,849)',
#   '26 total hours\n358 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Java Masterclass - Become an App Developer',
#   'Improve your career options by learning Android app Development.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy",
#   '4.5',
#   'Not Available',
#   '(8,707)',
#   '60.5 total hours\n338 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android App Development Masterclass: Build Apps',
#   'Create Real World Applications using Java and Become A Professional Android App Developer From Scratch',
#   'Meisam Mansourzadeh, Joe Parys',
#   '4.5',
#   'Not Available',
#   '(600)',
#   '39.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development with PhoneGap',
#   'Create Apps for iOS and Android with HTML5 and Javascript',
#   'Framework Television Inc.',
#   '4.4',
#   'Bestseller',
#   '(512)',
#   '5.5 total hours\n61 lectures\nIntermediate',
#   'Not Available'],
#  ['Android O & Java - The Complete Android Development Bootcamp',
#   'Learn Android O app development from beginning to end.',
#   'Philipp Muellauer',
#   '4.5',
#   'Not Available',
#   '(6,958)',
#   '21 total hours\n289 lectures\nAll Levels',
#   'Not Available'],
#  ['SwiftUI Masterclass: iOS 14 App Development with Swift 5',
#   'The Complete iOS 14 App Development Course with SwiftUI 2 From Beginner to Advanced App Developer with',
#   'Robert Petras',
#   '4.5',
#   'Bestseller',
#   '(654)',
#   '20.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['State of the Art Android App Development in Kotlin',
#   'Using Kotlin, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.7',
#   'Not Available',
#   '(223)',
#   '6.5 total hours\n51 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development using Kotlin',
#   'Develop Android apps in Kotlin and publish it to Play Store',
#   'Smartherd Developers',
#   '4.2',
#   'Not Available',
#   '(630)',
#   '3.5 total hours\n27 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Flutter App Development Course for Android, iOS',
#   'A Complete Guide to the Flutter Framework for building native iOS and Android apps with single code base',
#   'Smartherd Developers',
#   '4.1',
#   'Not Available',
#   '(1,153)',
#   '4.5 total hours\n33 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android & Java Developer Course - Build 21 Apps',
#   'Learn Android Development, Java & Android Studio from Scratch in 5 Weeks. Build a Diary App & more',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher, Fahd Sheraz',
#   '4.4',
#   'Not Available',
#   '(6,152)',
#   '34.5 total hours\n229 lectures\nAll Levels',
#   'Not Available'],
#  ['To-Do App & Clean Architecture -Android Development - Kotlin',
#   'Develop a Fully Functional To-Do app in Kotlin - ROOM, Navigation Component, LiveData, ViewModel, Data',
#   'Stefan Jovanovic',
#   '4.8',
#   'Not Available',
#   '(112)',
#   '4 total hours\n50 lectures\nIntermediate',
#   'Not Available'],
#  ['The complete Java Android App development Bootcamp 2020',
#   'Learn Android development fundamentals and start creating your own Android applications',
#   'Maid Rondić',
#   '4.4',
#   'Not Available',
#   '(180)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development For Beginners: Make a full app!',
#   'Become an App Developer!',
#   'Nick Marcenelle',
#   '4.2',
#   'Not Available',
#   '(567)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development. LIVE and in REAL TIME.',
#   'Android App Development Sessions are LIVE & UNEDITED.',
#   'Grant Klimaytys',
#   '4.9',
#   'Not Available',
#   '(4)',
#   '22 total hours\n45 lectures\nIntermediate',
#   'Not Available'],
#  ['Modern Android App Development Bootcamp With Kotlin 2020',
#   'Learn Android App Development With Kotlin From the Beginning All the Way to Advanced Topic With the Most',
#   'Abd Alwahab',
#   '4.3',
#   'Not Available',
#   '(517)',
#   '35.5 total hours\n274 lectures\nAll Levels',
#   'Not Available'],
#  ['Testing iOS Apps - Behavior Driven Development Using Swift',
#   'Learn Unit Testing, Test Driven Development and Behavior Driven Development in iOS Using Swift Language',
#   'Mohammad Azam',
#   '4.6',
#   'Not Available',
#   '(48)',
#   '7.5 total hours\n69 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Bootcamp 2020 - Android 10 (Q)',
#   'Android App Development for complete beginners, learn Java & Kotlin, make real working apps, become an',
#   'Vin Norman',
#   '4.7',
#   'Not Available',
#   '(113)',
#   '18 total hours\n105 lectures\nAll Levels',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['iOS 12 Swift 4.2 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.5',
#   'Not Available',
#   '(321)',
#   '55.5 total hours\n525 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 10 iPhone App Development: Learn the Basics in 2 hours',
#   'Build a fully functioning App and run it on your own personal iPhone',
#   'Michael Harrison',
#   '4.6',
#   'Not Available',
#   '(201)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development For Beginners',
#   'Step by step android development and Java tutorials included',
#   'Nazir Hakim',
#   '4.1',
#   'Not Available',
#   '(115)',
#   '3.5 total hours\n31 lectures\nBeginner',
#   'Not Available'],
#  ['Learning Path: Android: Test-Driven Android App Development',
#   'See the first steps to building fast and dynamic Android apps employing test-driven development',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(47)',
#   '10 total hours\n70 lectures\nBeginner',
#   'Not Available'],
#  ['Mobile App Development with Android (2015)',
#   "You'll create a real world social networking application! All of Android's core concepts in a production level project!",
#   '3D BUZZ Programming and Digital Art training',
#   '4.1',
#   'Not Available',
#   '(228)',
#   '40.5 total hours\n91 lectures\nIntermediate',
#   'Not Available'],
#  ['iOS Development - Create 4 Quiz Apps with Swift 3 & iOS 10',
#   'In this course we will develop 4 different quiz apps together and go into great detail for every step',
#   'Johannes Ruof, Timothy Meixner',
#   '4.2',
#   'Not Available',
#   '(127)',
#   '5 total hours\n31 lectures\nIntermediate',
#   'Not Available'],
#  ['Introduction to Programming and App Development',
#   'for Android and iOS',
#   'Hesam Samimi',
#   '3.7',
#   'Not Available',
#   '(121)',
#   '19.5 total hours\n69 lectures\nAll Levels',
#   'Not Available'],
#  ['Android P& Kotlin -Complete Android App Development Bootcamp',
#   'Learn Android Development from beginning to End Using Android Studio 3 and Android P',
#   'Bita Mirshafiee',
#   '3.8',
#   'Not Available',
#   '(207)',
#   '26.5 total hours\n248 lectures\nAll Levels',
#   'Not Available'],
#  ['Intermediate Mobile App Development (Swift 3, iPhone iOS10)',
#   "Gain the proficiency to start a career as an iOS developer with Swift 3 & Xcode 8 (learn 10 different iPhone API's)",
#   'Dee Aliyu Odumosu',
#   '4.8',
#   'Not Available',
#   '(15)',
#   '5.5 total hours\n83 lectures\nIntermediate',
#   'Not Available'],
#  ['Beginners Android App Development Course Stepwise-Classroom',
#   'Here is detailed android app development course for true learners.',
#   'codekul Simplest way of Learning Programming, Aniruddha Kudalkar',
#   '4.3',
#   'Not Available',
#   '(109)',
#   '19.5 total hours\n104 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 9 App Development For Beginners',
#   'Get started developing Apple apps with iOS 9 and Xcode 7.',
#   'Stone River eLearning',
#   '4.6',
#   'Not Available',
#   '(76)',
#   '7 total hours\n62 lectures\nAll Levels',
#   'Not Available'],
#  ['State of the Art Android app development in Java',
#   'Using Java, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.6',
#   'Not Available',
#   '(17)',
#   '7.5 total hours\n55 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 10 & Swift 3: From Beginner to Paid Professional™',
#   'The most comprehensive course on iOS development - become a master of app development',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.3',
#   'Not Available',
#   '(13,624)',
#   '71 total hours\n266 lectures\nAll Levels',
#   'Not Available'],
#  ['Intro to Shopify App Development with React, Node & GraphQL',
#   'Learn Shopify App Development with React, Node.js, Koa, GraphQL, Apollo, Next.js, Polaris, Shopify ScriptTag',
#   'Working With Shopify',
#   '4.0',
#   'Not Available',
#   '(227)',
#   '4 total hours\n31 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Development: Make Apps without Coding or Experience',
#   'Create a Fully Functional Professional Mobile App without Coding or Experience and in less than a day',
#   'Educational Engineering Team, Ashraf Said',
#   '3.6',
#   'Not Available',
#   '(498)',
#   '1 total hour\n16 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development: Make iOS & Android Apps Without Code',
#   'Quickly produce quality iOS and Android apps without learning any code.',
#   'Cameron Wills',
#   '3.7',
#   'Not Available',
#   '(133)',
#   '1.5 total hours\n20 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development: Create a Spotify Clone',
#   'Stream your music collection and learn how to play and control music on Android',
#   'Grant Klimaytys',
#   '3.8',
#   'Not Available',
#   '(132)',
#   '6 total hours\n58 lectures\nAll Levels',
#   'Not Available'],
#  ['Android & iOS Development - How To Hire a Good App Developer',
#   '10 Steps To Bring Your App Idea To Life Without Writing Code!',
#   'Dante Varnado Moore',
#   '4.7',
#   'Not Available',
#   '(6)',
#   '1 total hour\n15 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS Development Crash Course - Beginners to Publishing App',
#   'Create iOS Apps and Publish it to App Store.',
#   'Shaping Edge, Three Millennials',
#   '4.7',
#   'Not Available',
#   '(19)',
#   '3 total hours\n15 lectures\nAll Levels',
#   'Not Available'],
#  ['Android app Development Bootcamp Java and kotlin',
#   'Learn Core Java & Kotlin and make gaming Apps using UNITY 3D, also learn how to make backend applications',
#   'Mohammed Khan, Mohammed Khan',
#   '4.4',
#   'Not Available',
#   '(39)',
#   '22 total hours\n106 lectures\nAll Levels',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Mobile App Development for Beginners (Swift 3, iPhone iOS10)',
#   'iPhone (iOS 10) app development. The complete development course.',
#   'Dee Aliyu Odumosu',
#   '4.4',
#   'Not Available',
#   '(236)',
#   '33 total hours\n327 lectures\nBeginner',
#   'Not Available'],
#  ['Complete Flutter development - build 14 ios and android apps',
#   'Includes API handling, database projects, Firebase and BLOC',
#   'Igneus Technologies',
#   '4.6',
#   'Not Available',
#   '(152)',
#   '19 total hours\n118 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete iOS11 Swift4 Development Course - Build 28 Apps',
#   'Use Xcode 9 & Swift 4 to make great apps.',
#   'Dee Aliyu Odumosu',
#   '4.0',
#   'Not Available',
#   '(347)',
#   '43 total hours\n512 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development Course Build 5 Real Android App',
#   'In This Android Course You Will Build Job Portal Android App, Expense Manager Android App,Online Store',
#   'Yazdani Chowdhury',
#   '3.7',
#   'Not Available',
#   '(145)',
#   '14.5 total hours\n126 lectures\nAll Levels',
#   'Not Available'],
#  ['Project-Based iOS 10 App Development - Build a Real App',
#   'Become a professional iOS App Developer by building beautiful Real-World apps',
#   'Sebastian Dobrincu',
#   '4.6',
#   'Not Available',
#   '(10)',
#   '1 total hour\n14 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS App Development For Complete & Utter Coding Beginners',
#   'iOS App Development Made Simple for Non Coders. No Experience Needed. Level Up Your Skills Today.',
#   'Grant Klimaytys',
#   '4.6',
#   'Not Available',
#   '(47)',
#   '2.5 total hours\n23 lectures\nBeginner',
#   'Not Available'],
#  ['iOS Development - App Monetization for Swift 3 & iOS 10',
#   'We learn about AdMob, the Facebook Audience Network, In App Purchases and other ways to monetize our',
#   'Johannes Ruof, Timothy Meixner',
#   '4.5',
#   'Not Available',
#   '(48)',
#   '3.5 total hours\n25 lectures\nIntermediate',
#   'Not Available'],
#  ['The Complete Android 10 & Kotlin Development Masterclass',
#   'Learn Android 10 App Development From Beginner to Advanced Developer.',
#   'Denis Panjuta, Tutorials.eu by Denis Panjuta',
#   '4.6',
#   'Bestseller',
#   '(1,818)',
#   '45.5 total hours\n289 lectures\nAll Levels',
#   'Not Available'],
#  ['Running a Mobile App Dev Business: The Complete Guide',
#   'Learn how to start and grow a mobile app development business. Get up & running in less than 1 week.',
#   'Evan Kimbrell',
#   '4.7',
#   'Bestseller',
#   '(1,047)',
#   '17 total hours\n91 lectures\nAll Levels',
#   'Not Available'],
#  ['Hybrid Mobile App Development with Ionic',
#   'Leveraging AngularJS, CSS, HTML5, and Apache Cordova in the Ionic Framework',
#   'Infinite Skills',
#   '3.7',
#   'Not Available',
#   '(60)',
#   '3 total hours\n52 lectures\nAll Levels',
#   'Not Available'],
#  ['How To Use Git Branches To Speed Up Android App Development',
#   'Learn How To Use Git Branching Model Effectively To Make You Develop Android Apps Easier And Faster',
#   'Skill Centric',
#   '4.3',
#   'Not Available',
#   '(10)',
#   '1 total hour\n29 lectures\nIntermediate',
#   'Not Available'],
#  ['Professional iOS App Development with Swift',
#   'Learn how to build a fully customised iOS app from scratch in 10 steps',
#   'Brian Advent',
#   '4.5',
#   'Not Available',
#   '(77)',
#   '4 total hours\n37 lectures\nIntermediate',
#   'Not Available'],
#  ['How to make a Social Networking app -Android App Development',
#   'Take your first step towards your next big idea by learning social networking android app development',
#   'Kapil Bhattarai',
#   '4.3',
#   'Not Available',
#   '(93)',
#   '19.5 total hours\n179 lectures\nAll Levels',
#   'Not Available'],
#  ['Xamarin Android - A Master Guide to App Development in C#',
#   'Complete Xamarin.Android Reference for Building Apps in C#.',
#   'Grant Klimaytys',
#   '4.4',
#   'Not Available',
#   '(360)',
#   '7.5 total hours\n77 lectures\nAll Levels',
#   'Not Available'],
#  ['Learning App Development in iOS 8',
#   'Learn the skills required to become a iOS developer. An easy to follow course that teaches key fundamental skills',
#   'Infinite Skills',
#   '4.6',
#   'Not Available',
#   '(6)',
#   '6.5 total hours\n70 lectures\nAll Levels',
#   'Not Available'],
#  ['Android app development for beginners (with Kotlin)',
#   'Kotlin Android Apps Development (Beginner to advanced)',
#   'Beh Kh.',
#   '4.5',
#   'Not Available',
#   '(64)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 12 & Swift 5 - App Design, UI/UX plus Development',
#   'The three-in-one course that teaches app design, UI/UX and iOS development.',
#   'Gwinyai Nyatsoka',
#   '4.3',
#   'Bestseller',
#   '(748)',
#   '80.5 total hours\n493 lectures\nBeginner',
#   'Not Available'],
#  ['Flutter & Dart Development For Building iOS and Android Apps',
#   'Flutter is created by Google and is the future of all iOS and Android applications. It is powered by the Dart language',
#   'Frahaan Hussain',
#   '4.6',
#   'Not Available',
#   '(499)',
#   '10 total hours\n125 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete iOS 10 & Swift 3 Developer Course',
#   'Learn iOS App Development by building 21 iOS apps using Swift 3 & Xcode 8.',
#   'Rob Percival, Codestars by Rob Percival',
#   '4.5',
#   'Not Available',
#   '(10,764)',
#   '30 total hours\n222 lectures\nAll Levels',
#   'Not Available'],
#  ['Windows Phone Mobile App Development',
#   'Learn how to create mobile apps for the Windows Store. Real-life project examples.',
#   'Tiffany Ford',
#   '4.3',
#   'Not Available',
#   '(14)',
#   '2 total hours\n18 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Learn Android App Development & Promote Your App like a Pro',
#   'Learn how to create a Productivity Android App and how to rank #1 in Play Store and get 1,000,000 downloads',
#   'Val Okafor, Alex Genadinik Teaching Assistant',
#   '4.1',
#   'Not Available',
#   '(46)',
#   '14.5 total hours\n111 lectures\nBeginner',
#   'Not Available'],
#  ['Unity Android Game & App Development - Build 10 Games & Apps',
#   'Learn Android Game Development With Unity & Android App Development With MIT App Inventor, Build 10 Android',
#   'Raja Biswas, Charger Games',
#   '3.6',
#   'Not Available',
#   '(222)',
#   '22 total hours\n147 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development with Titanium Studio by Jason Foster',
#   "Develop apps for Android, Blackberry, iOS, and HTML using a single code base with Titanium Studio's classic",
#   'Jason Foster',
#   '4.4',
#   'Not Available',
#   '(31)',
#   '9 total hours\n62 lectures\nAll Levels',
#   'Not Available'],
#  ['Learn Android App Development using Java from Scratch',
#   'Hands on Projects included',
#   'Shubham Garg',
#   '4.5',
#   'Not Available',
#   '(6)',
#   '1.5 total hours\n5 lectures\nBeginner',
#   'Not Available'],
#  ['Android Q App Development Mastery Course - Build 20+ Apps',
#   'Complete Android App Development Course using Java & Android Studio.',
#   'Kapil Bhattarai',
#   '4.5',
#   'Not Available',
#   '(30)',
#   '20.5 total hours\n190 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Development for Beginners: Your first app in 2 hours',
#   'Learn Android app development step-by-step from hands-on senior android developer',
#   'Vadims Savjolovs',
#   '3.9',
#   'Not Available',
#   '(134)',
#   '2 total hours\n37 lectures\nBeginner',
#   'Not Available'],
#  ['Learn Mobile App Development with Ionic Framework',
#   'Create professional mobile apps using the Ionic Framework',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '4.3',
#   'Not Available',
#   '(71)',
#   '3.5 total hours\n31 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Studio Masterclass - APP DEVELOPMENT COURSE',
#   'Learn Android App Development using ANDROID STUDIO & JAVA JDK .',
#   'Sagar Kundu',
#   '4.4',
#   'Not Available',
#   '(52)',
#   '10.5 total hours\n52 lectures\nBeginner',
#   'Not Available'],
#  ['Mixed Language App Development with Objective-C and Swift',
#   'Effective Development for Cocoa and Cocoa Touch with Xcode',
#   'Infinite Skills',
#   '4.3',
#   'Not Available',
#   '(9)',
#   '7 total hours\n89 lectures\nIntermediate',
#   'Not Available'],
#  ['Low-code app development on the Creatio platform',
#   'Learn to create applications without programming skills with low-code platform',
#   'Creatio (formerly bpm’online)',
#   '4.5',
#   'Not Available',
#   '(60)',
#   '8.5 total hours\n56 lectures\nBeginner',
#   'Not Available'],
#  ['Android and Apple App Development: Beginner to Pro',
#   'Never developed an app before? Learn Android and Apple development, learn Java and Swift.',
#   'Stone River eLearning',
#   '4.5',
#   'Not Available',
#   '(50)',
#   '42 total hours\n504 lectures\nAll Levels',
#   'Not Available'],
#  ['How To Make An Android App Without Knowing Development',
#   'Learn A Simple And Efficient Method For Android Apps Development Without Knowing How To Code.',
#   'Sorin Constantin, Emily S. Lima',
#   '4.3',
#   'Not Available',
#   '(54)',
#   '3 total hours\n14 lectures\nAll Levels',
#   'Not Available'],
#  ['Learning Android Apps Development from Scratch',
#   'Learn how to create your first Android Application and Publish it to google play store. With all the details from A to Z',
#   'Sarah Alenzei',
#   '3.9',
#   'Not Available',
#   '(14)',
#   '2.5 total hours\n16 lectures\nAll Levels',
#   'Not Available'],
#  ['Learn Javascript Web App Development -Build A Calculator App',
#   'Javascript for Front End Web Development - Build Your Own Calculator App Using Javascript, HTML5 & CSS',
#   'DigiFisk (Programming is fun)',
#   '4.7',
#   'Not Available',
#   '(99)',
#   '4 total hours\n35 lectures\nAll Levels',
#   'Not Available'],
#  ["Learn Apple's IOS App Development with Swift from scratch",
#   "An absolute beginner's quick introduction to creating apps for Apple's devices",
#   'Bluelime Learning Solutions',
#   '3.9',
#   'Not Available',
#   '(13)',
#   '3 total hours\n31 lectures\nBeginner',
#   'Not Available'],
#  ['Android Development Course Build TopNote App Using Firebase',
#   'Build Complete Android App With Firebase Database, Learn How To Develop Complex Android App, Become Master',
#   'Yazdani Chowdhury',
#   '4.2',
#   'Not Available',
#   '(16)',
#   '3 total hours\n13 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development using Android Studio - Advance',
#   'Learn Mobile App Development on Android Platform using Android SDK, Integration with Back End, Sample',
#   'Sisoft Learning',
#   '4.2',
#   'Not Available',
#   '(65)',
#   '17.5 total hours\n102 lectures\nAll Levels',
#   'Not Available'],
#  ['Xamarin iOS - A Master Guide to App Development in C#',
#   'Complete Xamarin.iOS Reference for Building iOS Apps in C#.',
#   'Grant Klimaytys',
#   '4.0',
#   'Not Available',
#   '(271)',
#   '7.5 total hours\n95 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS App Development With Corona SDK - Mobile Apps Made Easy',
#   'Learn how to create mobile apps for iOS and Android the easy way.',
#   'Infinite Skills',
#   '4.4',
#   'Not Available',
#   '(26)',
#   '4 total hours\n39 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS app development for absolute beginners!',
#   'iOS app development made easy! Navigate Xcode, swift, gain confidence in mobile development!',
#   'Yehuda Oren Cohen',
#   '4.2',
#   'Not Available',
#   '(64)',
#   '1.5 total hours\n12 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Advanced Table View iOS App Development with Swift & Xcode',
#   'Learn Programmatic Auto Layout, UITableView, Protocols & Delegates, Custom Cells, NSAttributedString, UIKit & Swift.',
#   'Max Nelson',
#   '4.1',
#   'Not Available',
#   '(49)',
#   '6 total hours\n60 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App & Game Development :Build 6 Android Apps & Games',
#   'Android App Development Without Coding For Beginners Build Android Apps With Appinventor 2 Learn Android',
#   'Raja Biswas, Charger Games',
#   '4.1',
#   'Not Available',
#   '(58)',
#   '2.5 total hours\n50 lectures\nBeginner',
#   'Not Available'],
#  ['IONIC 4 App Development to Deployment',
#   'Once Done with Development we will publish app to Stores.',
#   'Awais Jamil',
#   '4.6',
#   'Not Available',
#   '(8)',
#   '3 total hours\n24 lectures\nIntermediate',
#   'Not Available'],
#  ['App Development Without Coding Masterclass - Level 101',
#   'In this masterclass course students will learn how to build mobile and web applications without coding.',
#   'Mark Piller',
#   '4.5',
#   'Not Available',
#   '(4)',
#   '6.5 total hours\n32 lectures\nBeginner',
#   'Not Available'],
#  ['Cross-platform Desktop App Development for Windows Mac Linux',
#   'Create a multiplatform desktop applications which runs on Mac, Windows and Linux with one single code base',
#   'Adria Jimenez',
#   '4.7',
#   'Not Available',
#   '(46)',
#   '7 total hours\n67 lectures\nIntermediate',
#   'Not Available'],
#  ['Android Development: Android App Development From Scratch',
#   'Learn Android App development with Android Oreo. Use Android Studio like a pro.',
#   'Oak Academy',
#   '4.0',
#   'Not Available',
#   '(86)',
#   '18 total hours\n130 lectures\nBeginner',
#   'Not Available'],
#  ['Learn Android App Development and How to Build Apps with AWS',
#   'Learn the Fundamentals of Android App Development and how to build Android Apps with Amazon Web Services',
#   'Matrix Tech',
#   '4.1',
#   'Not Available',
#   '(60)',
#   '7 total hours\n46 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 13 & Swift 5—The Complete iOS App Development Course',
#   'Master iOS development in iOS 13 with Swift 5.',
#   'Josh Arnold',
#   '4.2',
#   'Not Available',
#   '(7)',
#   '5 total hours\n29 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development: Easy and Quick Programming',
#   'App development. Programming Language',
#   'Stone River eLearning',
#   '4.1',
#   'Not Available',
#   '(43)',
#   '9 total hours\n121 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development with Kotlin',
#   'Using Kotlin, build an Android application from scratch, style it, and publish it on Google Play Store',
#   'Packt Publishing',
#   '5.0',
#   'Not Available',
#   '(2)',
#   '3 total hours\n28 lectures\nBeginner',
#   'Not Available'],
#  ['Mobile App development for beginners - Android and Apple',
#   'Create and deploy an app to a device',
#   'Bluelime Learning Solutions',
#   '3.7',
#   'Not Available',
#   '(31)',
#   '6.5 total hours\n60 lectures\nBeginner',
#   'Not Available'],
#  ['Apple TV App & Game Development for tvOS',
#   'Everything you need to know to build apps and games for the Apple TV on tvOS including TVML, Swift, and',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.6',
#   'Not Available',
#   '(389)',
#   '16 total hours\n83 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development with Dependencies',
#   'A Complete Course on Android App Development with Android Dependencies',
#   'The Apps Firm',
#   '3.8',
#   'Not Available',
#   '(27)',
#   '1.5 total hours\n32 lectures\nIntermediate',
#   'Not Available'],
#  ['Android project base app development course build (Real App)',
#   'this android course you will build real world project.you will learn how to build advanced android app',
#   'Yazdani Chowdhury',
#   '3.6',
#   'Not Available',
#   '(83)',
#   '5 total hours\n44 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android R + Java Developer Course™ : 2020',
#   "In this course, you'll learn Android Development and get to build your own Android R apps by using Java",
#   'Morteza Kordi',
#   '4.5',
#   'Not Available',
#   '(3,675)',
#   '167 total hours\n678 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development: Mobile App Development & Java',
#   'Android App Development & Java Programming: Mobile App Development & Design, Build Android Apps, Android',
#   'Easy Learn',
#   '2.8',
#   'Not Available',
#   '(177)',
#   '4.5 total hours\n29 lectures\nAll Levels',
#   'Not Available'],
#  ['SwiftUI Development - iOS 13 & Swift 5 App Development',
#   'Learn iOS app development with SwiftUI using MVVM Architecture, REST API, Observer Pattern, View composing',
#   'Gaurav Parvadiya',
#   '4.1',
#   'Not Available',
#   '(9)',
#   '4 total hours\n36 lectures\nAll Levels',
#   'Not Available'],
#  ['App Development: Tutorial for Building Apps for Businesses',
#   'Creating apps for local businesses is extremely lucrative.',
#   'Ira Turner',
#   '3.6',
#   'Not Available',
#   '(7)',
#   '2 total hours\n26 lectures\nAll Levels',
#   'Not Available'],
#  ['Machine Learning for Android App development Using ML Kit',
#   'Add intelligent features to your Android apps with ML Kit',
#   'Packt Publishing',
#   '3.5',
#   'Not Available',
#   '(20)',
#   '2 total hours\n22 lectures\nIntermediate',
#   'Not Available'],
#  ['How to Outsource your iPhone App Development the Proper Way',
#   'Have you heard all the horror stories from outsourcing? Here are the EXACT steps to do it right - save TIME and MONEY!',
#   'Adarsh Menon',
#   '4.6',
#   'Not Available',
#   '(3)',
#   '4 total hours\n39 lectures\nAll Levels',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Android App Development for Beginners',
#   'Hands-on Android Development course for Beginners - Create your app by the end of the course',
#   'Anu Khanchandani',
#   '3.7',
#   'Not Available',
#   '(8)',
#   '5.5 total hours\n28 lectures\nAll Levels',
#   'Not Available'],
#  ['Business App Development in Dynamics 365 for Non-Programmers',
#   'Build useful apps for mobile and the web using the PowerApp platform from Microsoft',
#   'Packt Publishing',
#   '4.5',
#   'Not Available',
#   '(17)',
#   '3.5 total hours\n28 lectures\nBeginner',
#   'Not Available'],
#  ['Learn App Development with Docker',
#   'The Ultimate Course to Master Development and Management of Web Apps on Docker',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '3.5',
#   'Not Available',
#   '(142)',
#   '4.5 total hours\n23 lectures\nBeginner',
#   'Not Available'],
#  ['Complete Unity® and Android Development: Build Games & Apps',
#   'Learn to code & build beginner Android apps! And make a Legend of Zenda game in Unity®.',
#   'Mammoth Interactive, John Bura',
#   '4.4',
#   'Not Available',
#   '(257)',
#   '40.5 total hours\n402 lectures\nBeginner',
#   'Not Available'],
#  ['Kotlin for Android Development : Develop an App with Kotlin',
#   'Develop a Real World Weather App Using Kotlin for Android Development',
#   'Concept Courses \u206f\u206f\u206f\u206f\u206f, Ted Horyczun',
#   '3.5',
#   'Not Available',
#   '(141)',
#   '1 total hour\n24 lectures\nBeginner',
#   'Not Available'],
#  ['Beginner Introduction to Mobile App development with Xamarin',
#   'Build cross-platform apps for IOS, Android or Windows using Xamarin',
#   'Bluelime Learning Solutions',
#   '3.9',
#   'Not Available',
#   '(43)',
#   '3.5 total hours\n41 lectures\nBeginner',
#   'Not Available'],
#  ['iOS App Development',
#   'Publish your apps to the itunes store!',
#   'Travis .',
#   '4.1',
#   'Not Available',
#   '(3)',
#   '29 total mins\n15 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development & App Design for iOS & Android 2020',
#   'Design and program iOS and Android app with social media (facebook and twitter).',
#   'Invedion ™',
#   '3.2',
#   'Not Available',
#   '(23)',
#   '11.5 total hours\n44 lectures\nAll Levels',
#   'Not Available'],
#  ["I Want to Create an App But Don't Know Where to Start!",
#   'Understand the myriad of app development tools, technologies and frameworks, regardless if you are a',
#   'Gary Kind',
#   '4.3',
#   'Not Available',
#   '(63)',
#   '1 total hour\n11 lectures\nAll Levels',
#   'Not Available'],
#  ['Android N: From Beginner to Paid Professional',
#   'Comprehensive Android Nougat app development',
#   'Mark Wahlbeck, Devslopes by Mark Wahlbeck',
#   '4.0',
#   'Not Available',
#   '(2,203)',
#   '25 total hours\n93 lectures\nAll Levels',
#   'Not Available'],
#  ['Python Django Web Development: To-Do App',
#   'Learn Database Driven Web Development With Django and Python!',
#   'John Elder',
#   '4.6',
#   'Not Available',
#   '(880)',
#   '2 total hours\n34 lectures\nBeginner',
#   'Not Available'],
#  ['Oracle Apex - Web App Development',
#   'Build enterprise apps 20 x faster with 100 x less code.',
#   'Vijay Thapa',
#   '4.3',
#   'Not Available',
#   '(37)',
#   '2 total hours\n14 lectures\nIntermediate',
#   'Not Available'],
#  ['Build Real Android Apps: Android App Development with Java',
#   'Learn Java & Android App development with Android Oreo.',
#   'Oak Academy',
#   '5.0',
#   'Not Available',
#   '(2)',
#   '26 total hours\n201 lectures\nBeginner',
#   'Not Available'],
#  ['Full Stack Web (Angular) and Mobile (Ionic) App Development',
#   'Step by step implementation with Spring Boot 2.1.4, Angular 7, Ionic 4 (ios, android, windows), hibernate, liquibase',
#   'Senol Atac',
#   '4.2',
#   'Not Available',
#   '(5)',
#   '3.5 total hours\n54 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Course',
#   'Learn Android App Development Cours with Android 9 (Pie) Build real Apps like Uber , Whatsapp, Google',
#   'Zeeshan Mehdi',
#   '3.5',
#   'Not Available',
#   '(72)',
#   '15.5 total hours\n49 lectures\nAll Levels',
#   'Not Available'],
#  ['Real World Android App Development Course Build 10 App',
#   'This Android App Development Course is for Developing Expense Manager Android App Note Book Android App',
#   'Yazdani Chowdhury',
#   '3.4',
#   'Not Available',
#   '(34)',
#   '13 total hours\n86 lectures\nAll Levels',
#   'Not Available'],
#  ['Complete Firebase Tutorial for Android App Development',
#   'Learn how to use firebase services for android app development with practical example.',
#   'Janhavi Sawant',
#   '3.4',
#   'Not Available',
#   '(36)',
#   '4.5 total hours\n15 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS Development - Adding In-App Purchasing To iOS Apps',
#   'Learn How To Add In-App Purchasing Into Your iOS Application.',
#   'Infinite Skills',
#   '3.7',
#   'Not Available',
#   '(4)',
#   '1 total hour\n16 lectures\nAll Levels',
#   'Not Available'],
#  ['Create Android & iOS Apps Without Coding',
#   'Amazing Android and iOS App Development Without Coding or programming',
#   'Khalid Hamadeh',
#   '4.0',
#   'Not Available',
#   '(27)',
#   '2 total hours\n31 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development – Making Your First App with Eclipse',
#   'Beginners guide to make an Android app with Eclipse IDE with sound effects, menu, and a splash screen',
#   'Andrew Durtka',
#   '3.7',
#   'Not Available',
#   '(4)',
#   '2 total hours\n22 lectures\nAll Levels',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Decentralized App Development with Blockchain-Novice to Pro!',
#   'Build decentralized gaming application using Ethereum! Blockchain projects which establish security using Hyperledger.',
#   'Packt Publishing',
#   '4.3',
#   'Not Available',
#   '(17)',
#   '12.5 total hours\n116 lectures\nBeginner',
#   'Not Available'],
#  ['Quick Guide to iOS App Development - Novice to Pro!: 4-in-1',
#   'Build a custom web browser, a local Notepad app, and an iTunes movies browser using iOS 11 and Swift',
#   'Packt Publishing',
#   '4.7',
#   'Not Available',
#   '(2)',
#   '14.5 total hours\n137 lectures\nBeginner',
#   'Not Available'],
#  ['Beginner Mobile App Development with Appcelerator Titanium',
#   'Learn to develop native iPhone, Android, Blackberry, and Mobile Web apps with Open Source tools.',
#   'Szymon Machajewski',
#   '3.3',
#   'Not Available',
#   '(19)',
#   '3.5 total hours\n19 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS app development: Swift 5 fundamentals for beginners',
#   'Learn the basics of Swift 5 to create iOS 13 App for the iPad and iPhone today!',
#   'Sam Saunders',
#   '4.5',
#   'Not Available',
#   '(2)',
#   '3.5 total hours\n34 lectures\nBeginner',
#   'Not Available'],
#  ['Java: Enterprise App Development with Java EE 8: 2-in-1',
#   'Get hands-on with Java EE to build modern RESTful web services and enterprise applications with the latest Java EE 8 API',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(52)',
#   '5.5 total hours\n60 lectures\nBeginner',
#   'Not Available'],
#  ['iOS 7 Development - Adding Push Notification To iOS Apps',
#   'Course will guide you through all the necessary steps required to add Push Notification to your iOS Apps',
#   'Pankaj Chhikara',
#   '4.1',
#   'Not Available',
#   '(8)',
#   '1 total hour\n17 lectures\nIntermediate',
#   'Not Available'],
#  ['Mobile App Development – A Practical Lessons',
#   'A Practical Guide to all the Moving Parts involved in Mobile App Development from Pre-Production to Post-Production',
#   'Vijay Kumar',
#   '3.5',
#   'Not Available',
#   '(6)',
#   '6.5 total hours\n32 lectures\nAll Levels',
#   'Not Available'],
#  ['Unity app development: Make a monetized gaming application',
#   'Basic & advanced 3D Game Design with C# Coding. Monetise your games with Ads Suitable for Beginners - Intermediate',
#   'Mohammed Khan, Mohammed Khan',
#   '4.4',
#   'Not Available',
#   '(8)',
#   '4.5 total hours\n23 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Course Build TDS App Using Firebase',
#   'Learn Android Development,Build Complete Android App,Become Master With Android Firebase,Upload Android',
#   'Yazdani Chowdhury',
#   '3.2',
#   'Not Available',
#   '(60)',
#   '2.5 total hours\n13 lectures\nAll Levels',
#   'Not Available'],
#  ['A Practical Guide to App Development with Scala',
#   'Build Scala apps using concurrency and message passing in an Akka framework using Play framework for',
#   'Packt Publishing',
#   '3.8',
#   'Not Available',
#   '(16)',
#   '6 total hours\n42 lectures\nBeginner',
#   'Not Available'],
#  ['Flutter App Development For Beginners',
#   'The complete step by step app development manual for Flutter',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '3.9',
#   'Not Available',
#   '(5)',
#   '6 total hours\n37 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development For Beginners With FREE Software',
#   'Android App Development Basics With FREE Android Learner Software',
#   'Bhuvanesh S',
#   '2.9',
#   'Not Available',
#   '(44)',
#   '30 total mins\n17 lectures\nAll Levels',
#   'Not Available'],
#  ['Learn Flutter and Dart: Complete App Development Projects',
#   'Learn all about creating apps with code in more detail than any YouTube tutorial.',
#   'Mammoth Interactive, John Bura',
#   '3.9',
#   'Not Available',
#   '(15)',
#   '7.5 total hours\n52 lectures\nBeginner',
#   'Not Available'],
#  ['How to Make a Freaking iPhone App - iOS 10 and Swift 3',
#   'iPhone App Development from scratch. Learn how to make iOS apps using Xcode 8.',
#   'Nick Walter',
#   '4.7',
#   'Not Available',
#   '(1,184)',
#   '16 total hours\n158 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development with REST API Creation & Integration',
#   'Build REST APIs using any technology you are comfortable with - PHP, .Net, Java',
#   'Rohit Toshniwal',
#   '5.0',
#   'Not Available',
#   '(1)',
#   '3 total hours\n17 lectures\nAll Levels',
#   'Not Available'],
#  ['Configuring SharePoint 2013 Server for Apps Development',
#   'Configure SharePoint 2013 Server for Apps Development in Easy Steps',
#   'Kameswara Sarma Uppuluri',
#   '4.2',
#   'Not Available',
#   '(23)',
#   '1 total hour\n28 lectures\nAll Levels',
#   'Not Available'],
#  ['App Development with ASP .NET Core MVC',
#   'Learn to build and run your first application with the latest ASP.NET Core MVC',
#   'Packt Publishing',
#   '4.3',
#   'Not Available',
#   '(10)',
#   '13.5 total hours\n101 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development Essential Training',
#   'Android Development from Scratch for Beginners',
#   'QScutter Tutorials',
#   '3.0',
#   'Not Available',
#   '(3)',
#   '4 total hours\n50 lectures\nBeginner',
#   'Not Available'],
#  ['Android Office Task Management App Using Firebase(Real App)',
#   'Learn Android App Development, Build Complex Android App, Learn Android Firebase Database and Build Complete',
#   'Yazdani Chowdhury',
#   '4.1',
#   'Not Available',
#   '(143)',
#   '2.5 total hours\n24 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android 11 Developer Course - Mastering Android',
#   'Learn Android App Development from Zero to Hero - Build 50+ Apps from scratch - Become a real developer',
#   'Abbass Masri',
#   '4.4',
#   'Not Available',
#   '(241)',
#   '38 total hours\n181 lectures\nAll Levels',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Dart & Flutter: The Complete Mobile Apps Development Course',
#   'A Complete Guide to the Dart & Flutter Framework for building beautiful native apps on iOS and Android',
#   'Packt Publishing',
#   '3.5',
#   'Not Available',
#   '(12)',
#   '17 total hours\n104 lectures\nBeginner',
#   'Not Available'],
#  ['Android Development Course: Learn Android Oreo From Scratch',
#   'It has never been easier to learn Android App Development with Oreo',
#   'Oak Academy',
#   '4.4',
#   'Not Available',
#   '(16)',
#   '11.5 total hours\n54 lectures\nAll Levels',
#   'Not Available'],
#  ['Windows IoT App Development',
#   'Learn how to develop IoT applications on Windows IoT',
#   'Amr Swalha',
#   '3.7',
#   'Not Available',
#   '(21)',
#   '2 total hours\n22 lectures\nBeginner',
#   'Not Available'],
#  ['AWS: Serverless App Development with AWS: 3-in-1',
#   'Conquer the world of serverless application development to master production -ready and secure applications',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(19)',
#   '7 total hours\n65 lectures\nIntermediate',
#   'Not Available'],
#  ['Learn Android the Easy Way: Build a Real App',
#   'Learn the Fundamentals of Android App Development and how to build TaskNote App',
#   'SunLight Team',
#   '4.7',
#   'Not Available',
#   '(28)',
#   '4.5 total hours\n9 lectures\nBeginner',
#   'Not Available'],
#  ['Learn React Native - Cross Platform App Development',
#   'Creative React Native course for beginners, Learn by making Rock Paper Scissors game',
#   'Shivam Kumar',
#   '3.5',
#   'Not Available',
#   '(25)',
#   '1 total hour\n19 lectures\nBeginner',
#   'Not Available'],
#  ['Complete Android app Development Course - Without Coding',
#   'Learn about App inventer, thunkable, appybuilder, makeroid, droidmaker, kodular. how tp make apps for',
#   'Shivendra Singh',
#   '2.6',
#   'Not Available',
#   '(8)',
#   '1 total hour\n30 lectures\nIntermediate',
#   'Not Available'],
#  ['The Complete iOS Development Course. Swift Programming A-Z',
#   'Best Swift Course Ever | Learn All Untold Secrets | Build +60 Apps | Complete iOS Swift Developer Course',
#   'Akhmed Idigov',
#   '4.4',
#   'Not Available',
#   '(530)',
#   '44.5 total hours\n329 lectures\nBeginner',
#   'Not Available'],
#  ['Apple Watch App Development for Beginners (SWIFT)',
#   'Understand & Use the Fundamentals of Apple Watch App Development',
#   'Afraz Siddiqui',
#   '5.0',
#   'Not Available',
#   '(1)',
#   '1 total hour\n8 lectures\nBeginner',
#   'Not Available'],
#  ['Build your first iOS App in Swift',
#   'iOS Application Development for Beginners',
#   'Zeph Cohen',
#   '4.8',
#   'Not Available',
#   '(23)',
#   '3.5 total hours\n21 lectures\nBeginner',
#   'Not Available'],
#  ['Unit Testing Swift Mobile App',
#   'Apply Test-Driven Development(TDD) process to iOS mobile app development in Swift',
#   'Sergey Kargopolov',
#   '4.6',
#   'Bestseller',
#   '(178)',
#   '8.5 total hours\n135 lectures\nBeginner',
#   'Not Available'],
#  ['Android Daily Shopping List App Using Firebase(Project base)',
#   'In This Android App Development Course You Will Learn How To Develop DailyShoppingList Android App A',
#   'Yazdani Chowdhury',
#   '3.4',
#   'Not Available',
#   '(151)',
#   '3 total hours\n20 lectures\nIntermediate',
#   'Not Available'],
#  ['Modern App Development with C# 8 and .NET Core 3.0',
#   'Build amazing cross-device and cross-platform applications—web, mobile, and desktop alike with new C# and .NET Core',
#   'Packt Publishing',
#   '3.7',
#   'Not Available',
#   '(18)',
#   '5.5 total hours\n38 lectures\nIntermediate',
#   'Not Available'],
#  ['iOS App Development with Cocos2d (v1 or v2) and Xcode',
#   'Learn to build games or apps for the iPhone or iPad using Xcode and Cocos2d.',
#   'Justin Dike',
#   '3.7',
#   'Not Available',
#   '(5)',
#   '22 total hours\n32 lectures\nAll Levels',
#   'Not Available'],
#  ['Mastering iOS Development - Integrate iOS Apps With iCloud',
#   'Program Your iOS Apps To integrate With iCloud.',
#   'Infinite Skills',
#   '4.0',
#   'Not Available',
#   '(2)',
#   '1.5 total hours\n18 lectures\nAll Levels',
#   'Not Available'],
#  ['Full Stack App Development with Spring 5 and Angular: 3-in-1',
#   'Build amazingly beautiful apps combining the power of two hottest frameworks Angular 6 with Spring 5!',
#   'Packt Publishing',
#   '4.0',
#   'Not Available',
#   '(16)',
#   '8.5 total hours\n82 lectures\nIntermediate',
#   'Not Available'],
#  ['Java: Enterprise App Development with Java 9: 4-in-1',
#   'Build modern and scalable enterprise applications using Java 9 and Java EE 8 to become a professional Java developer!',
#   'Packt Publishing',
#   '3.6',
#   'Not Available',
#   '(5)',
#   '9 total hours\n62 lectures\nBeginner',
#   'Not Available'],
#  ['Introduction to Android Development for beginners',
#   'Create an Android App step by step from scratch',
#   'Bluelime Learning Solutions',
#   '4.2',
#   'Not Available',
#   '(120)',
#   '8 total hours\n70 lectures\nBeginner',
#   'Not Available'],
#  ['Serverless Apps Development with Azure Functions and Node.js',
#   'Build effective, scalable, Node.js applications and deploy them on the cloud',
#   'Packt Publishing',
#   '3.7',
#   'Not Available',
#   '(10)',
#   '6.5 total hours\n62 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Android Developer Course : From Zero to Hero',
#   'Improve your career options by learning Android app Development. Master Android Studio',
#   'SunLight Team',
#   '4.3',
#   'Not Available',
#   '(72)',
#   '4.5 total hours\n36 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['Progressive Web App Development: A Complete Guide: 2-in-1',
#   'Simplify your application development and deployment by creating apps with improved capabilities',
#   'Packt Publishing',
#   '3.9',
#   'Not Available',
#   '(3)',
#   '9.5 total hours\n78 lectures\nBeginner',
#   'Not Available'],
#  ['Android P with Machine Learning apps - 26+ projects in total',
#   'Master Android development with latest tech stack like Firebase, Sqlite, Machine Leaning etc',
#   'Igneus Technologies',
#   '4.5',
#   'Not Available',
#   '(176)',
#   '19.5 total hours\n127 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 12: Learn to Code & Build Real iOS 12 Apps in Swift 4.2',
#   'Master iOS 12 development with Swift 4.2 building full-stack apps in this brand new course. Incl.',
#   'Caleb Stultz, Jonathan Burgoyne',
#   '4.7',
#   'Not Available',
#   '(822)',
#   '52 total hours\n256 lectures\nAll Levels',
#   'Not Available'],
#  ['Kotlin Android Development Masterclass',
#   'Learn Kotlin, Android Development, Android Studio & IntelliJ IDEA from Scratch.',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.1',
#   'Not Available',
#   '(808)',
#   '32.5 total hours\n224 lectures\nAll Levels',
#   'Not Available'],
#  ['Code a Swift iOS To Do List App, UIKit, CoreData, Table View',
#   'Learn Widely Used Concepts and Best Practices Used in Modern Day iOS Development to Hone Your Craft and',
#   'Max Nelson',
#   '4.4',
#   'Not Available',
#   '(149)',
#   '9.5 total hours\n72 lectures\nAll Levels',
#   'Not Available'],
#  ['Complete iOS 10 development Bootcamp',
#   'A complete app design process and development with swift 3, xcode 8, SketchApp and Firebase for ios 10',
#   'Igneus Technologies',
#   '4.1',
#   'Not Available',
#   '(174)',
#   '26.5 total hours\n151 lectures\nAll Levels',
#   'Not Available'],
#  ['Learn to Build a Professional App in Android',
#   'A Hands on Approach to Android App Development for Professionals',
#   'Eduonix Learning Solutions, Eduonix-Tech .',
#   '4.3',
#   'Not Available',
#   '(20)',
#   '3.5 total hours\n17 lectures\nAll Levels',
#   'Not Available'],
#  ['Learning Path: Laravel: Modern App Development with Laravel',
#   'Grasp everything you need to know to get started with Laravel',
#   'Packt Publishing',
#   '4.2',
#   'Not Available',
#   '(6)',
#   '9 total hours\n49 lectures\nIntermediate',
#   'Not Available'],
#  ['Hands-On App Development with Ionic',
#   'This hands-on course teaches you to build reactive, scalable, and dynamic cross-platform apps using Ionic',
#   'Packt Publishing',
#   '4.1',
#   'Not Available',
#   '(2)',
#   '6 total hours\n38 lectures\nBeginner',
#   'Not Available'],
#  ['Make Social Networking App like Instagram - Kotlin, Firebase',
#   'Create Social Network App like Instagram, Facebook & snapchat clone - Android Studio Kotlin Development',
#   'Coding Cafe',
#   '4.2',
#   'Not Available',
#   '(21)',
#   '15 total hours\n34 lectures\nAll Levels',
#   'Not Available'],
#  ["The Android developer's journey",
#   'Android App Development via Android Studio, the Java object-oriented programming language, together with',
#   'Richard Goodman, Codestars by Rob Percival',
#   '4.1',
#   'Not Available',
#   '(154)',
#   '14 total hours\n114 lectures\nBeginner',
#   'Not Available'],
#  ['Make Whatsapp Stickers App in Android Studio - No Coding',
#   'Whatsapp Stickers Android App Development, Without Knowledge of Coding - Android Studio Project',
#   'Shuja Sardar',
#   '4.9',
#   'Not Available',
#   '(4)',
#   '35 total mins\n20 lectures\nAll Levels',
#   'Not Available'],
#  ['Meteor: Full Stack JavaScript, MongoDB & App Development',
#   'Meteor Framework, Full Stack Javascript & Mongodb: App Development, SQL, CSS & HTML, MeteorJS, Front',
#   'Easy Learn',
#   '1.6',
#   'Not Available',
#   '(112)',
#   '4.5 total hours\n44 lectures\nAll Levels',
#   'Not Available'],
#  ['How to Make a Freaking iPhone App - iOS 11 and Swift 4',
#   'iPhone App Development from scratch. Learn how to make iOS apps using Xcode 9.',
#   'Nick Walter',
#   '4.7',
#   'Not Available',
#   '(477)',
#   '16.5 total hours\n143 lectures\nBeginner',
#   'Not Available'],
#  ['LEARNING PATH: Electron: App Development with Electron',
#   'Efficiently build, package, and distribute your Electron applications',
#   'Packt Publishing',
#   '3.3',
#   'Not Available',
#   '(19)',
#   '6 total hours\n55 lectures\nIntermediate',
#   'Not Available'],
#  ['Swift 3 - Master Swift Development From Scratch',
#   'Then learn building iOS10 Apps or Server Side Swift Apps.',
#   'Nikant Vohra',
#   '4.5',
#   'Not Available',
#   '(181)',
#   '6.5 total hours\n63 lectures\nAll Levels',
#   'Not Available'],
#  ['Blockchain Development: Convert An App To A Dapp (2020)',
#   'Learn How To Make A Decentralized Blockchain App Using Ethereum & Solidity From A Centralized MERN App',
#   'Masnad Nehith',
#   '4.6',
#   'Not Available',
#   '(69)',
#   '4 total hours\n78 lectures\nBeginner',
#   'Not Available'],
#  ['The App Developer Bootcamp',
#   'Learn the basics of Swift and Xcode for app development quick and fast.',
#   'Online Training Plus',
#   '4.7',
#   'Not Available',
#   '(20)',
#   '6 total hours\n27 lectures\nBeginner',
#   'Not Available'],
#  ['Beginners Swift Programming For iOS Development',
#   'Learn how to program with iOS Apps with Swift. A easy to follow course for the beginner',
#   'Infinite Skills',
#   '4.7',
#   'Not Available',
#   '(9)',
#   '3 total hours\n49 lectures\nAll Levels',
#   'Not Available'],
#  ['Windows 10 C++ App Development for Startups - C++ Simplified',
#   'Learn C++ From Scratch - Go from zero programming to building 2 Windows 10 C++ apps!',
#   'Augmented Startups, Rajiv Desai',
#   '2.7',
#   'Not Available',
#   '(19)',
#   '3 total hours\n21 lectures\nBeginner',
#   'Not Available'],
#  ['Build Real World Teacher Finder App with Xamarin Forms',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(159)',
#   'Not Available',
#   'Not Available'],
#  ['Build Real World Application with Xamarin Forms Part 2',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.5',
#   'Not Available',
#   '(275)',
#   'Not Available',
#   'Not Available'],
#  ['Learn MVVM in Xamarin Forms and C#',
#   'Not Available',
#   'Asfend Yar Hamid',
#   '4.2',
#   'Not Available',
#   '(285)',
#   'Not Available',
#   'Not Available'],
#  ['The Complete RxJava 2 For Android Development Masterclass',
#   'Architect Android Apps With Rx Java 2 , MVVM, Room DB, Retrofit 2 & Dagger 2.',
#   'Anushka Madusanka',
#   '4.4',
#   'Bestseller',
#   '(561)',
#   '6.5 total hours\n103 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android and IOS App Game Development',
#   'Learn how to make online games without knowing how to code',
#   'Ambioris Martinez',
#   '2.5',
#   'Not Available',
#   '(1)',
#   '5 total hours\n15 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Android Oreo Tutorial - Make 30 Apps',
#   'Android 7.1 development: Become an Android developer, by making more than 30 Android mobile apps.',
#   'Sriyank Siddhartha',
#   '3.7',
#   'Not Available',
#   '(486)',
#   '17.5 total hours\n141 lectures\nAll Levels',
#   'Not Available'],
#  ['Intermediate iOS - Complex and Advanced iPhone Apps',
#   'Use Xcode and Swift 4 to take your app development skills to the next level',
#   'Nick Walter, Mohammad Azam',
#   '4.7',
#   'Not Available',
#   '(159)',
#   '12.5 total hours\n63 lectures\nAll Levels',
#   'Not Available'],
#  ['Swift 4 and iOS 11: Building a Store Front App (App Only)',
#   '*** FREE Update to Swift 4 and iOS 11 *** Swift iOS development: Developing eCommerce type application',
#   'Andi Setiyadi',
#   '4.4',
#   'Not Available',
#   '(23)',
#   '16 total hours\n50 lectures\nBeginner',
#   'Not Available'],
#  ['Web Application Development - Learn by Building 3 Web Apps',
#   'Use the power of HTML5 and jQuery to develop 3 Latest Web Apps!',
#   'Akshay Nagpal',
#   '3.6',
#   'Not Available',
#   '(19)',
#   '1.5 total hours\n29 lectures\nBeginner',
#   'Not Available'],
#  ['Flutter Web Development Course Build Complete FlutterWeb App',
#   'Flutter Web development Course Will Teach You-How To Build Complete Web App Using Flutter,Flutter Web',
#   'Yazdani Chowdhury',
#   '2.7',
#   'Not Available',
#   '(286)',
#   '2 total hours\n10 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Web Developer Course 2.0',
#   'Learn Web Development by building 25 websites and mobile apps using HTML, CSS, Javascript, PHP, Python',
#   'Rob Percival, Codestars by Rob Percival',
#   '4.5',
#   'Not Available',
#   '(63,878)',
#   '30.5 total hours\n309 lectures\nAll Levels',
#   'Not Available'],
#  ['The Ultimate iOS 10, Xcode 8 Developer course. Build 30 apps',
#   'Learn to become a virtuosic developer with the most comprehensive iOS development course ever produced',
#   'Mammoth Interactive, John Bura',
#   '4.4',
#   'Not Available',
#   '(249)',
#   '102.5 total hours\n300 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete iOS SDK Development Course - be job-ready!',
#   'Integrate Facebook, AdMob, Amazon, Google Sign-in and other 3rd party iOS SDKs into your apps Xcode 10',
#   'Codestars by Rob Percival, Rob Percival, Dee Aliyu Odumosu',
#   '4.3',
#   'Not Available',
#   '(41)',
#   '7.5 total hours\n126 lectures\nBeginner',
#   'Not Available'],
#  ['Beast Android Development: Advanced Android UI',
#   'Learn to implement Firebase as your apps back-end.',
#   'Beast Android Development',
#   '3.2',
#   'Not Available',
#   '(172)',
#   '12 total hours\n53 lectures\nIntermediate',
#   'Not Available'],
#  ['Android App Development for Complete Beginners',
#   'A gentle introduction to building your first Android App',
#   'Lee Falin',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '38 total mins\n9 lectures\nBeginner',
#   'Not Available'],
#  ['Introduction to Android Development with Kotlin',
#   'Learn Android development basics with Kotlin by creating an app from scratch that gets data from GitHub',
#   'Linero Tech, Humberto Linero',
#   '4.9',
#   'Not Available',
#   '(3)',
#   '2 total hours\n13 lectures\nBeginner',
#   'Not Available'],
#  ['iOS 14, Swift 5 & SwiftUI - The iOS Development Starter Kit',
#   'Build 12 iOS Apps from scratch & learn the basics of Swift 5, iOS 14 App Development in Xcode 12, and',
#   'Swift Starter Kit',
#   '4.6',
#   'Not Available',
#   '(22)',
#   '7 total hours\n102 lectures\nBeginner',
#   'Not Available'],
#  ['Introduction to App Development & Game Development',
#   'Best way to understand the fundamentals of App & Game Development',
#   'Moonshot Jr',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '1 total hour\n6 lectures\nBeginner',
#   'Not Available'],
#  ['Android N: Professional Android N App Development: 2-in-1',
#   'Learn to build your own exciting Android apps!',
#   'Packt Publishing',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   '7 total hours\n68 lectures\nBeginner',
#   'Not Available'],
#  ['Ruby On Rails Web Development: To-Do List App',
#   'Learn Ruby On Rails The Fast And Easy Way!',
#   'John Elder',
#   '4.3',
#   'Not Available',
#   '(60)',
#   '3 total hours\n40 lectures\nBeginner',
#   'Not Available']]

# %%
len(info)
# Out:
# 230

# %%
import selenium
import pandas
import numpy as np
from selenium import webdriver
import time

DRIVERPATH="chromedriver"
driver=webdriver.Chrome(executable_path=DRIVERPATH)
driver.get('https://www.udemy.com/')

a='udlite-btn udlite-btn-large udlite-btn-ghost udlite-heading-md udlite-btn-icon udlite-btn-icon-large'
a=a.replace(' ','.')
a
time.sleep(5)
next_link='udlite-btn udlite-btn-medium udlite-btn-secondary udlite-btn-round udlite-heading-sm udlite-btn-icon udlite-btn-icon-medium udlite-btn-icon-round pagination--next--5NrLo'
next_link=next_link.replace(' ','.')
time.sleep(3)
e=driver.find_element_by_class_name('udlite-text-input.udlite-text-input-small.udlite-text-sm.udlite-search-form-autocomplete-input.js-header-search-field')
for s in 'App Development':
    e.send_keys(s)
    time.sleep(0.3)
time.sleep(2)
driver.find_element_by_class_name(a).click()
time.sleep(10)
block_=driver.find_elements_by_class_name('popper--popper--19faV.popper--popper-hover--4YJ5J')

time.sleep(3)

info=[]

# %%
len(block_)
# Out:
# 24

# %%
block_=driver.find_elements_by_class_name('popper--popper--19faV.popper--popper-hover--4YJ5J')
for j in block_:
        content=[]
        try:
            title=j.find_element_by_class_name('udlite-focus-visible-target.udlite-heading-md.course-card--course-title--2f7tE')
            content.append(title.text)
        except:
            content.append('Not Available')
        try:
            tagline=j.find_element_by_class_name('udlite-text-sm.course-card--course-headline--yIrRk')
            content.append(tagline.text)
        except:
            content.append('Not Available')
        try:
            instructor=j.find_element_by_class_name('udlite-text-xs.course-card--instructor-list--lIA4f')
            content.append(instructor.text)
        except:
            content.append('Not Available')
        try:
            rating=j.find_element_by_class_name('udlite-heading-sm.star-rating--rating-number--3lVe8')
            content.append(rating.text)
        except:
            content.append('Not Available')
        try:
            bestseller=j.find_element_by_class_name('udlite-badge.udlite-heading-xs.udlite-badge-bestseller')
            content.append('Bestseller')
        except:
            content.append('Not Available')
        try:
            reviews=j.find_element_by_class_name('udlite-text-xs.course-card--reviews-text--12UpL')
            content.append(reviews.text)
        except:
            content.append('Not Available')
        try:
            otherinfo=j.find_element_by_class_name('udlite-text-xs.course-card--row--1OMjg.course-card--course-meta-info--1hHb3')
            content.append(otherinfo.text)
        except:
            content.append('Not Available')
        try:
            links=j.find_element_by_tag_name('a').get_attribute('href')
            content.append(links)
        except:
            content.append('Not Available')

        info.append(content)

# %%
info
# Out:
# [['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available',
#   'Not Available'],
#  ['iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#   'From Beginner to iOS App Developer with Just One Course!',
#   'Dr. Angela Yu',
#   '4.8',
#   'Bestseller',
#   '(52,220)',
#   '59.5 total hours\n578 lectures\nAll Levels',
#   'Not Available'],
#  ['iOS 11 & Swift 4 - The Complete iOS App Development Bootcamp',
#   'Learn iOS 11 App Development From Beginning to End. Using Xcode 9 and Swift 4.',
#   'Dr. Angela Yu',
#   '4.7',
#   'Not Available',
#   '(31,308)',
#   '49.5 total hours\n478 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development Masterclass using Kotlin',
#   'Learn Kotlin Android App Development And Become an Android Developer. Incl.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy, David Reidy",
#   '4.4',
#   'Not Available',
#   '(3,780)',
#   '59.5 total hours\n364 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Android Oreo Developer Course - Build 23 Apps!',
#   'Learn Android O App Development using Java & Kotlin - build real apps including Super Mario Run, Whatsapp',
#   'Rob Percival, Nick Walter, Codestars by Rob Percival',
#   '4.4',
#   'Bestseller',
#   '(13,961)',
#   '37.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android App Development',
#   'Learn how to make online games, and apps like Twitter, Pokémon ,Tic Tac Toy, and Find my phone using',
#   'Hussein Alrubaye',
#   '4.2',
#   'Not Available',
#   '(2,891)',
#   '22 total hours\n150 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android N Developer Course',
#   'Learn Android App Development with Android 7 Nougat by building real apps including Uber, Whatsapp and',
#   'Rob Percival, Marc Stock, Codestars by Rob Percival',
#   '4.4',
#   'Not Available',
#   '(27,050)',
#   '32.5 total hours\n272 lectures\nAll Levels',
#   'Not Available'],
#  ['Flutter & Dart - The Complete Flutter App Development Course',
#   "Build Flutter iOS and Android Apps with a Single Codebase: Learn Google's Flutter Mobile Development",
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher',
#   '4.5',
#   'Not Available',
#   '(3,849)',
#   '26 total hours\n358 lectures\nAll Levels',
#   'Not Available'],
#  ['Android Java Masterclass - Become an App Developer',
#   'Improve your career options by learning Android app Development.',
#   "Tim Buchalka, Jean-Paul Roberts, Tim Buchalka's Learn Programming Academy",
#   '4.5',
#   'Not Available',
#   '(8,707)',
#   '60.5 total hours\n338 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android App Development Masterclass: Build Apps',
#   'Create Real World Applications using Java and Become A Professional Android App Developer From Scratch',
#   'Meisam Mansourzadeh, Joe Parys',
#   '4.5',
#   'Not Available',
#   '(600)',
#   '39.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['Mobile App Development with PhoneGap',
#   'Create Apps for iOS and Android with HTML5 and Javascript',
#   'Framework Television Inc.',
#   '4.4',
#   'Bestseller',
#   '(512)',
#   '5.5 total hours\n61 lectures\nIntermediate',
#   'Not Available'],
#  ['Android O & Java - The Complete Android Development Bootcamp',
#   'Learn Android O app development from beginning to end.',
#   'Philipp Muellauer',
#   '4.5',
#   'Not Available',
#   '(6,958)',
#   '21 total hours\n289 lectures\nAll Levels',
#   'Not Available'],
#  ['SwiftUI Masterclass: iOS 14 App Development with Swift 5',
#   'The Complete iOS 14 App Development Course with SwiftUI 2 From Beginner to Advanced App Developer with',
#   'Robert Petras',
#   '4.5',
#   'Bestseller',
#   '(654)',
#   '20.5 total hours\n116 lectures\nAll Levels',
#   'Not Available'],
#  ['State of the Art Android App Development in Kotlin',
#   'Using Kotlin, MVVM, Dagger2, Navigation, Retrofit and Unit tests',
#   'Catalin Stefan',
#   '4.7',
#   'Not Available',
#   '(223)',
#   '6.5 total hours\n51 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development using Kotlin',
#   'Develop Android apps in Kotlin and publish it to Play Store',
#   'Smartherd Developers',
#   '4.2',
#   'Not Available',
#   '(630)',
#   '3.5 total hours\n27 lectures\nBeginner',
#   'Not Available'],
#  ['The Complete Flutter App Development Course for Android, iOS',
#   'A Complete Guide to the Flutter Framework for building native iOS and Android apps with single code base',
#   'Smartherd Developers',
#   '4.1',
#   'Not Available',
#   '(1,153)',
#   '4.5 total hours\n33 lectures\nAll Levels',
#   'Not Available'],
#  ['The Complete Android & Java Developer Course - Build 21 Apps',
#   'Learn Android Development, Java & Android Studio from Scratch in 5 Weeks. Build a Diary App & more',
#   'Paulo Dichone | Android, Java, Flutter Developer and Teacher, Fahd Sheraz',
#   '4.4',
#   'Not Available',
#   '(6,152)',
#   '34.5 total hours\n229 lectures\nAll Levels',
#   'Not Available'],
#  ['The complete Java Android App development Bootcamp 2020',
#   'Learn Android development fundamentals and start creating your own Android applications',
#   'Maid Rondić',
#   '4.4',
#   'Not Available',
#   '(180)',
#   '13 total hours\n71 lectures\nAll Levels',
#   'Not Available'],
#  ['Android App Development For Beginners: Make a full app!',
#   'Become an App Developer!',
#   'Nick Marcenelle',
#   '4.2',
#   'Not Available',
#   '(567)',
#   '1.5 total hours\n16 lectures\nBeginner',
#   'Not Available'],
#  ['Android App Development. LIVE and in REAL TIME.',
#   'Android App Development Sessions are LIVE & UNEDITED.',
#   'Grant Klimaytys',
#   '4.9',
#   'Not Available',
#   '(4)',
#   '22 total hours\n45 lectures\nIntermediate',
#   'Not Available'],
#  ['Modern Android App Development Bootcamp With Kotlin 2020',
#   'Learn Android App Development With Kotlin From the Beginning All the Way to Advanced Topic With the Most',
#   'Abd Alwahab',
#   '4.3',
#   'Not Available',
#   '(517)',
#   '35.5 total hours\n274 lectures\nAll Levels',
#   'Not Available']]

# %%
info[4]
# Out:
# ['iOS 13 & Swift 5 - The Complete iOS App Development Bootcamp',
#  'From Beginner to iOS App Developer with Just One Course!',
#  'Dr. Angela Yu',
#  '4.8',
#  'Bestseller',
#  '(52,220)',
#  '59.5 total hours\n578 lectures\nAll Levels',
#  'Not Available']

# %%
print(block_[4].find_element_by_tag_name('a').get_attribute('href'))
# Out:
# https://www.udemy.com/course/ios-13-app-development-bootcamp/

# %%
block_[4].find_element_by_tag_name('a').get_attribute('href')
# Out:
# 'https://www.udemy.com/course/ios-13-app-development-bootcamp/'

# %%
block_[5].find_element_by_tag_name('a').get_attribute('href')
